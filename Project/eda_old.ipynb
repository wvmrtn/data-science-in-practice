# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
#  <font size="3">Import libraries</font>

# %%
# import standard libraries
import json
import numpy as np
# import third-party libraries
from geopy.geocoders import Nominatim
import matplotlib
import matplotlib as mpl
from matplotlib.collections import PatchCollection
from matplotlib.patches import Polygon
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import pandas as pd
from IPython.display import display
from scipy import stats
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
# import local libraries

pd.options.display.max_columns = None

# %% [markdown]
# <font size="3">Import data</font>

# %%
movies = pd.read_csv('movies_metadata_cleaned.csv')
#ratings = pd.read_csv('ratings_small.csv')
# Out:
# /Users/williammartin/anaconda3/envs/epfl/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (0,1,2,6,12,30,32,60,62,64,66,68,70,72,74,76,78,80,82,84,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128,129,130,131,132,133,134,143,144,145,146,147,148,149,150,151,152,153,154,155,156,157,158,159,160,161,162,163,164,165,166,167,168,169,170,171,172) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# <font size="3">We observe that there are a lot of columns. This is because some movies have long listings of either genres, production companies, production countries, or spoken languages</font>

# %%
movies
# Out:
#        adult    budget      id    imdb_id original_language  \
# 0      False  30000000     862  tt0114709                en
# 1      False  65000000    8844  tt0113497                en
# 2      False         0   15602  tt0113228                en
# 3      False  16000000   31357  tt0114885                en
# 4      False         0   11862  tt0113041                en
# ...      ...       ...     ...        ...               ...
# 45461  False         0  439050  tt6209470                fa
# 45462  False         0  111109  tt2028550                tl
# 45463  False         0   67758  tt0303758                en
# 45464  False         0  227506  tt0008536                en
# 45465  False         0  461257  tt6980792                en
#
#                     original_title popularity release_date      revenue  \
# 0                        Toy Story    21.9469   1995-10-30  373554033.0
# 1                          Jumanji    17.0155   1995-12-15  262797249.0
# 2                 Grumpier Old Men    11.7129   1995-12-22          0.0
# 3                Waiting to Exhale    3.85949   1995-12-22   81452156.0
# 4      Father of the Bride Part II    8.38752   1995-02-10   76578911.0
# ...                            ...        ...          ...          ...
# 45461                      رگ خواب   0.072051          NaN          0.0
# 45462          Siglo ng Pagluluwal   0.178241   2011-11-17          0.0
# 45463                     Betrayal   0.903007   2003-08-01          0.0
# 45464          Satana likuyushchiy   0.003503   1917-10-21          0.0
# 45465                     Queerama   0.163015   2017-06-09          0.0
#
#        runtime    status                        title  video  vote_average  \
# 0         81.0  Released                    Toy Story  False           7.7
# 1        104.0  Released                      Jumanji  False           6.9
# 2        101.0  Released             Grumpier Old Men  False           6.5
# 3        127.0  Released            Waiting to Exhale  False           6.1
# 4        106.0  Released  Father of the Bride Part II  False           5.7
# ...        ...       ...                          ...    ...           ...
# 45461     90.0  Released                       Subdue  False           4.0
# 45462    360.0  Released          Century of Birthing  False           9.0
# 45463     90.0  Released                     Betrayal  False           3.8
# 45464     87.0  Released             Satan Triumphant  False           0.0
# 45465     75.0  Released                     Queerama  False           0.0
#
#        vote_count  belongs_to_collection_id      belongs_to_collection_name  \
# 0          5415.0                   10194.0            Toy Story Collection
# 1          2413.0                       NaN                             NaN
# 2            92.0                  119050.0       Grumpy Old Men Collection
# 3            34.0                       NaN                             NaN
# 4           173.0                   96871.0  Father of the Bride Collection
# ...           ...                       ...                             ...
# 45461         1.0                       NaN                             NaN
# 45462         3.0                       NaN                             NaN
# 45463         6.0                       NaN                             NaN
# 45464         0.0                       NaN                             NaN
# 45465         0.0                       NaN                             NaN
#
#        genres_id_0 genres_name_0  genres_id_1 genres_name_1  genres_id_2  \
# 0             16.0     Animation         35.0        Comedy      10751.0
# 1             12.0     Adventure         14.0       Fantasy      10751.0
# 2          10749.0       Romance         35.0        Comedy          NaN
# 3             35.0        Comedy         18.0         Drama      10749.0
# 4             35.0        Comedy          NaN           NaN          NaN
# ...            ...           ...          ...           ...          ...
# 45461         18.0         Drama      10751.0        Family          NaN
# 45462         18.0         Drama          NaN           NaN          NaN
# 45463         28.0        Action         18.0         Drama         53.0
# 45464          NaN           NaN          NaN           NaN          NaN
# 45465          NaN           NaN          NaN           NaN          NaN
#
#       genres_name_2  genres_id_3 genres_name_3  genres_id_4 genres_name_4  \
# 0            Family          NaN           NaN          NaN           NaN
# 1            Family          NaN           NaN          NaN           NaN
# 2               NaN          NaN           NaN          NaN           NaN
# 3           Romance          NaN           NaN          NaN           NaN
# 4               NaN          NaN           NaN          NaN           NaN
# ...             ...          ...           ...          ...           ...
# 45461           NaN          NaN           NaN          NaN           NaN
# 45462           NaN          NaN           NaN          NaN           NaN
# 45463      Thriller          NaN           NaN          NaN           NaN
# 45464           NaN          NaN           NaN          NaN           NaN
# 45465           NaN          NaN           NaN          NaN           NaN
#
#        genres_id_5 genres_name_5  genres_id_6 genres_name_6  genres_id_7  \
# 0              NaN           NaN          NaN           NaN          NaN
# 1              NaN           NaN          NaN           NaN          NaN
# 2              NaN           NaN          NaN           NaN          NaN
# 3              NaN           NaN          NaN           NaN          NaN
# 4              NaN           NaN          NaN           NaN          NaN
# ...            ...           ...          ...           ...          ...
# 45461          NaN           NaN          NaN           NaN          NaN
# 45462          NaN           NaN          NaN           NaN          NaN
# 45463          NaN           NaN          NaN           NaN          NaN
# 45464          NaN           NaN          NaN           NaN          NaN
# 45465          NaN           NaN          NaN           NaN          NaN
#
#       genres_name_7  production_companies_id_0  \
# 0               NaN                        3.0
# 1               NaN                      559.0
# 2               NaN                     6194.0
# 3               NaN                      306.0
# 4               NaN                     5842.0
# ...             ...                        ...
# 45461           NaN                        NaN
# 45462           NaN                    19653.0
# 45463           NaN                     6165.0
# 45464           NaN                    88753.0
# 45465           NaN                        NaN
#
#                   production_companies_name_0  production_companies_id_1  \
# 0                     Pixar Animation Studios                        NaN
# 1                            TriStar Pictures                     2550.0
# 2                                Warner Bros.                    19464.0
# 3      Twentieth Century Fox Film Corporation                        NaN
# 4                       Sandollar Productions                     9195.0
# ...                                       ...                        ...
# 45461                                     NaN                        NaN
# 45462                             Sine Olivia                        NaN
# 45463                 American World Pictures                        NaN
# 45464                               Yermoliev                        NaN
# 45465                                     NaN                        NaN
#
#       production_companies_name_1  production_companies_id_2  \
# 0                             NaN                        NaN
# 1                    Teitler Film                    10201.0
# 2                  Lancaster Gate                        NaN
# 3                             NaN                        NaN
# 4             Touchstone Pictures                        NaN
# ...                           ...                        ...
# 45461                         NaN                        NaN
# 45462                         NaN                        NaN
# 45463                         NaN                        NaN
# 45464                         NaN                        NaN
# 45465                         NaN                        NaN
#
#       production_companies_name_2  production_companies_id_3  \
# 0                             NaN                        NaN
# 1       Interscope Communications                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# ...                           ...                        ...
# 45461                         NaN                        NaN
# 45462                         NaN                        NaN
# 45463                         NaN                        NaN
# 45464                         NaN                        NaN
# 45465                         NaN                        NaN
#
#       production_companies_name_3  production_companies_id_4  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# ...                           ...                        ...
# 45461                         NaN                        NaN
# 45462                         NaN                        NaN
# 45463                         NaN                        NaN
# 45464                         NaN                        NaN
# 45465                         NaN                        NaN
#
#       production_companies_name_4  production_companies_id_5  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# ...                           ...                        ...
# 45461                         NaN                        NaN
# 45462                         NaN                        NaN
# 45463                         NaN                        NaN
# 45464                         NaN                        NaN
# 45465                         NaN                        NaN
#
#       production_companies_name_5  production_companies_id_6  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# ...                           ...                        ...
# 45461                         NaN                        NaN
# 45462                         NaN                        NaN
# 45463                         NaN                        NaN
# 45464                         NaN                        NaN
# 45465                         NaN                        NaN
#
#       production_companies_name_6  production_companies_id_7  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# ...                           ...                        ...
# 45461                         NaN                        NaN
# 45462                         NaN                        NaN
# 45463                         NaN                        NaN
# 45464                         NaN                        NaN
# 45465                         NaN                        NaN
#
#       production_companies_name_7  production_companies_id_8  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# ...                           ...                        ...
# 45461                         NaN                        NaN
# 45462                         NaN                        NaN
# 45463                         NaN                        NaN
# 45464                         NaN                        NaN
# 45465                         NaN                        NaN
#
#       production_companies_name_8  production_companies_id_9  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# ...                           ...                        ...
# 45461                         NaN                        NaN
# 45462                         NaN                        NaN
# 45463                         NaN                        NaN
# 45464                         NaN                        NaN
# 45465                         NaN                        NaN
#
#       production_companies_name_9  production_companies_id_10  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
# ...                           ...                         ...
# 45461                         NaN                         NaN
# 45462                         NaN                         NaN
# 45463                         NaN                         NaN
# 45464                         NaN                         NaN
# 45465                         NaN                         NaN
#
#       production_companies_name_10  production_companies_id_11  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 45461                          NaN                         NaN
# 45462                          NaN                         NaN
# 45463                          NaN                         NaN
# 45464                          NaN                         NaN
# 45465                          NaN                         NaN
#
#       production_companies_name_11  production_companies_id_12  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 45461                          NaN                         NaN
# 45462                          NaN                         NaN
# 45463                          NaN                         NaN
# 45464                          NaN                         NaN
# 45465                          NaN                         NaN
#
#       production_companies_name_12  production_companies_id_13  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 45461                          NaN                         NaN
# 45462                          NaN                         NaN
# 45463                          NaN                         NaN
# 45464                          NaN                         NaN
# 45465                          NaN                         NaN
#
#       production_companies_name_13  production_companies_id_14  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 45461                          NaN                         NaN
# 45462                          NaN                         NaN
# 45463                          NaN                         NaN
# 45464                          NaN                         NaN
# 45465                          NaN                         NaN
#
#       production_companies_name_14  production_companies_id_15  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 45461                          NaN                         NaN
# 45462                          NaN                         NaN
# 45463                          NaN                         NaN
# 45464                          NaN                         NaN
# 45465                          NaN                         NaN
#
#       production_companies_name_15  production_companies_id_16  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 45461                          NaN                         NaN
# 45462                          NaN                         NaN
# 45463                          NaN                         NaN
# 45464                          NaN                         NaN
# 45465                          NaN                         NaN
#
#       production_companies_name_16  production_companies_id_17  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 45461                          NaN                         NaN
# 45462                          NaN                         NaN
# 45463                          NaN                         NaN
# 45464                          NaN                         NaN
# 45465                          NaN                         NaN
#
#       production_companies_name_17  production_companies_id_18  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 45461                          NaN                         NaN
# 45462                          NaN                         NaN
# 45463                          NaN                         NaN
# 45464                          NaN                         NaN
# 45465                          NaN                         NaN
#
#       production_companies_name_18  production_companies_id_19  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 45461                          NaN                         NaN
# 45462                          NaN                         NaN
# 45463                          NaN                         NaN
# 45464                          NaN                         NaN
# 45465                          NaN                         NaN
#
#       production_companies_name_19  production_companies_id_20  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 45461                          NaN                         NaN
# 45462                          NaN                         NaN
# 45463                          NaN                         NaN
# 45464                          NaN                         NaN
# 45465                          NaN                         NaN
#
#       production_companies_name_20  production_companies_id_21  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 45461                          NaN                         NaN
# 45462                          NaN                         NaN
# 45463                          NaN                         NaN
# 45464                          NaN                         NaN
# 45465                          NaN                         NaN
#
#       production_companies_name_21  production_companies_id_22  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 45461                          NaN                         NaN
# 45462                          NaN                         NaN
# 45463                          NaN                         NaN
# 45464                          NaN                         NaN
# 45465                          NaN                         NaN
#
#       production_companies_name_22  production_companies_id_23  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 45461                          NaN                         NaN
# 45462                          NaN                         NaN
# 45463                          NaN                         NaN
# 45464                          NaN                         NaN
# 45465                          NaN                         NaN
#
#       production_companies_name_23  production_companies_id_24  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 45461                          NaN                         NaN
# 45462                          NaN                         NaN
# 45463                          NaN                         NaN
# 45464                          NaN                         NaN
# 45465                          NaN                         NaN
#
#       production_companies_name_24  production_companies_id_25  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 45461                          NaN                         NaN
# 45462                          NaN                         NaN
# 45463                          NaN                         NaN
# 45464                          NaN                         NaN
# 45465                          NaN                         NaN
#
#       production_companies_name_25 production_countries_iso_3166_1_0  \
# 0                              NaN                                US
# 1                              NaN                                US
# 2                              NaN                                US
# 3                              NaN                                US
# 4                              NaN                                US
# ...                            ...                               ...
# 45461                          NaN                                IR
# 45462                          NaN                                PH
# 45463                          NaN                                US
# 45464                          NaN                                RU
# 45465                          NaN                                GB
#
#       production_countries_name_0 production_countries_iso_3166_1_1  \
# 0        United States of America                               NaN
# 1        United States of America                               NaN
# 2        United States of America                               NaN
# 3        United States of America                               NaN
# 4        United States of America                               NaN
# ...                           ...                               ...
# 45461                        Iran                               NaN
# 45462                 Philippines                               NaN
# 45463    United States of America                               NaN
# 45464                      Russia                               NaN
# 45465              United Kingdom                               NaN
#
#       production_countries_name_1 production_countries_iso_3166_1_2  \
# 0                             NaN                               NaN
# 1                             NaN                               NaN
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                             NaN                               NaN
# ...                           ...                               ...
# 45461                         NaN                               NaN
# 45462                         NaN                               NaN
# 45463                         NaN                               NaN
# 45464                         NaN                               NaN
# 45465                         NaN                               NaN
#
#       production_countries_name_2 production_countries_iso_3166_1_3  \
# 0                             NaN                               NaN
# 1                             NaN                               NaN
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                             NaN                               NaN
# ...                           ...                               ...
# 45461                         NaN                               NaN
# 45462                         NaN                               NaN
# 45463                         NaN                               NaN
# 45464                         NaN                               NaN
# 45465                         NaN                               NaN
#
#       production_countries_name_3 production_countries_iso_3166_1_4  \
# 0                             NaN                               NaN
# 1                             NaN                               NaN
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                             NaN                               NaN
# ...                           ...                               ...
# 45461                         NaN                               NaN
# 45462                         NaN                               NaN
# 45463                         NaN                               NaN
# 45464                         NaN                               NaN
# 45465                         NaN                               NaN
#
#       production_countries_name_4 production_countries_iso_3166_1_5  \
# 0                             NaN                               NaN
# 1                             NaN                               NaN
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                             NaN                               NaN
# ...                           ...                               ...
# 45461                         NaN                               NaN
# 45462                         NaN                               NaN
# 45463                         NaN                               NaN
# 45464                         NaN                               NaN
# 45465                         NaN                               NaN
#
#       production_countries_name_5 production_countries_iso_3166_1_6  \
# 0                             NaN                               NaN
# 1                             NaN                               NaN
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                             NaN                               NaN
# ...                           ...                               ...
# 45461                         NaN                               NaN
# 45462                         NaN                               NaN
# 45463                         NaN                               NaN
# 45464                         NaN                               NaN
# 45465                         NaN                               NaN
#
#       production_countries_name_6 production_countries_iso_3166_1_7  \
# 0                             NaN                               NaN
# 1                             NaN                               NaN
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                             NaN                               NaN
# ...                           ...                               ...
# 45461                         NaN                               NaN
# 45462                         NaN                               NaN
# 45463                         NaN                               NaN
# 45464                         NaN                               NaN
# 45465                         NaN                               NaN
#
#       production_countries_name_7 production_countries_iso_3166_1_8  \
# 0                             NaN                               NaN
# 1                             NaN                               NaN
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                             NaN                               NaN
# ...                           ...                               ...
# 45461                         NaN                               NaN
# 45462                         NaN                               NaN
# 45463                         NaN                               NaN
# 45464                         NaN                               NaN
# 45465                         NaN                               NaN
#
#       production_countries_name_8 production_countries_iso_3166_1_9  \
# 0                             NaN                               NaN
# 1                             NaN                               NaN
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                             NaN                               NaN
# ...                           ...                               ...
# 45461                         NaN                               NaN
# 45462                         NaN                               NaN
# 45463                         NaN                               NaN
# 45464                         NaN                               NaN
# 45465                         NaN                               NaN
#
#       production_countries_name_9 production_countries_iso_3166_1_10  \
# 0                             NaN                                NaN
# 1                             NaN                                NaN
# 2                             NaN                                NaN
# 3                             NaN                                NaN
# 4                             NaN                                NaN
# ...                           ...                                ...
# 45461                         NaN                                NaN
# 45462                         NaN                                NaN
# 45463                         NaN                                NaN
# 45464                         NaN                                NaN
# 45465                         NaN                                NaN
#
#       production_countries_name_10 production_countries_iso_3166_1_11  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
# ...                            ...                                ...
# 45461                          NaN                                NaN
# 45462                          NaN                                NaN
# 45463                          NaN                                NaN
# 45464                          NaN                                NaN
# 45465                          NaN                                NaN
#
#       production_countries_name_11 production_countries_iso_3166_1_12  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
# ...                            ...                                ...
# 45461                          NaN                                NaN
# 45462                          NaN                                NaN
# 45463                          NaN                                NaN
# 45464                          NaN                                NaN
# 45465                          NaN                                NaN
#
#       production_countries_name_12 production_countries_iso_3166_1_13  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
# ...                            ...                                ...
# 45461                          NaN                                NaN
# 45462                          NaN                                NaN
# 45463                          NaN                                NaN
# 45464                          NaN                                NaN
# 45465                          NaN                                NaN
#
#       production_countries_name_13 production_countries_iso_3166_1_14  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
# ...                            ...                                ...
# 45461                          NaN                                NaN
# 45462                          NaN                                NaN
# 45463                          NaN                                NaN
# 45464                          NaN                                NaN
# 45465                          NaN                                NaN
#
#       production_countries_name_14 production_countries_iso_3166_1_15  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
# ...                            ...                                ...
# 45461                          NaN                                NaN
# 45462                          NaN                                NaN
# 45463                          NaN                                NaN
# 45464                          NaN                                NaN
# 45465                          NaN                                NaN
#
#       production_countries_name_15 production_countries_iso_3166_1_16  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
# ...                            ...                                ...
# 45461                          NaN                                NaN
# 45462                          NaN                                NaN
# 45463                          NaN                                NaN
# 45464                          NaN                                NaN
# 45465                          NaN                                NaN
#
#       production_countries_name_16 production_countries_iso_3166_1_17  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
# ...                            ...                                ...
# 45461                          NaN                                NaN
# 45462                          NaN                                NaN
# 45463                          NaN                                NaN
# 45464                          NaN                                NaN
# 45465                          NaN                                NaN
#
#       production_countries_name_17 production_countries_iso_3166_1_18  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
# ...                            ...                                ...
# 45461                          NaN                                NaN
# 45462                          NaN                                NaN
# 45463                          NaN                                NaN
# 45464                          NaN                                NaN
# 45465                          NaN                                NaN
#
#       production_countries_name_18 production_countries_iso_3166_1_19  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
# ...                            ...                                ...
# 45461                          NaN                                NaN
# 45462                          NaN                                NaN
# 45463                          NaN                                NaN
# 45464                          NaN                                NaN
# 45465                          NaN                                NaN
#
#       production_countries_name_19 production_countries_iso_3166_1_20  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
# ...                            ...                                ...
# 45461                          NaN                                NaN
# 45462                          NaN                                NaN
# 45463                          NaN                                NaN
# 45464                          NaN                                NaN
# 45465                          NaN                                NaN
#
#       production_countries_name_20 production_countries_iso_3166_1_21  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
# ...                            ...                                ...
# 45461                          NaN                                NaN
# 45462                          NaN                                NaN
# 45463                          NaN                                NaN
# 45464                          NaN                                NaN
# 45465                          NaN                                NaN
#
#       production_countries_name_21 production_countries_iso_3166_1_22  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
# ...                            ...                                ...
# 45461                          NaN                                NaN
# 45462                          NaN                                NaN
# 45463                          NaN                                NaN
# 45464                          NaN                                NaN
# 45465                          NaN                                NaN
#
#       production_countries_name_22 production_countries_iso_3166_1_23  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
# ...                            ...                                ...
# 45461                          NaN                                NaN
# 45462                          NaN                                NaN
# 45463                          NaN                                NaN
# 45464                          NaN                                NaN
# 45465                          NaN                                NaN
#
#       production_countries_name_23 production_countries_iso_3166_1_24  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
# ...                            ...                                ...
# 45461                          NaN                                NaN
# 45462                          NaN                                NaN
# 45463                          NaN                                NaN
# 45464                          NaN                                NaN
# 45465                          NaN                                NaN
#
#       production_countries_name_24 spoken_languages_iso_639_1_0  \
# 0                              NaN                           en
# 1                              NaN                           en
# 2                              NaN                           en
# 3                              NaN                           en
# 4                              NaN                           en
# ...                            ...                          ...
# 45461                          NaN                           fa
# 45462                          NaN                           tl
# 45463                          NaN                           en
# 45464                          NaN                          NaN
# 45465                          NaN                           en
#
#       spoken_languages_name_0 spoken_languages_iso_639_1_1  \
# 0                     English                          NaN
# 1                     English                           fr
# 2                     English                          NaN
# 3                     English                          NaN
# 4                     English                          NaN
# ...                       ...                          ...
# 45461                   فارسی                          NaN
# 45462                     NaN                          NaN
# 45463                 English                          NaN
# 45464                     NaN                          NaN
# 45465                 English                          NaN
#
#       spoken_languages_name_1 spoken_languages_iso_639_1_2  \
# 0                         NaN                          NaN
# 1                    Français                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
# ...                       ...                          ...
# 45461                     NaN                          NaN
# 45462                     NaN                          NaN
# 45463                     NaN                          NaN
# 45464                     NaN                          NaN
# 45465                     NaN                          NaN
#
#       spoken_languages_name_2 spoken_languages_iso_639_1_3  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
# ...                       ...                          ...
# 45461                     NaN                          NaN
# 45462                     NaN                          NaN
# 45463                     NaN                          NaN
# 45464                     NaN                          NaN
# 45465                     NaN                          NaN
#
#       spoken_languages_name_3 spoken_languages_iso_639_1_4  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
# ...                       ...                          ...
# 45461                     NaN                          NaN
# 45462                     NaN                          NaN
# 45463                     NaN                          NaN
# 45464                     NaN                          NaN
# 45465                     NaN                          NaN
#
#       spoken_languages_name_4 spoken_languages_iso_639_1_5  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
# ...                       ...                          ...
# 45461                     NaN                          NaN
# 45462                     NaN                          NaN
# 45463                     NaN                          NaN
# 45464                     NaN                          NaN
# 45465                     NaN                          NaN
#
#       spoken_languages_name_5 spoken_languages_iso_639_1_6  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
# ...                       ...                          ...
# 45461                     NaN                          NaN
# 45462                     NaN                          NaN
# 45463                     NaN                          NaN
# 45464                     NaN                          NaN
# 45465                     NaN                          NaN
#
#       spoken_languages_name_6 spoken_languages_iso_639_1_7  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
# ...                       ...                          ...
# 45461                     NaN                          NaN
# 45462                     NaN                          NaN
# 45463                     NaN                          NaN
# 45464                     NaN                          NaN
# 45465                     NaN                          NaN
#
#       spoken_languages_name_7 spoken_languages_iso_639_1_8  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
# ...                       ...                          ...
# 45461                     NaN                          NaN
# 45462                     NaN                          NaN
# 45463                     NaN                          NaN
# 45464                     NaN                          NaN
# 45465                     NaN                          NaN
#
#       spoken_languages_name_8 spoken_languages_iso_639_1_9  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
# ...                       ...                          ...
# 45461                     NaN                          NaN
# 45462                     NaN                          NaN
# 45463                     NaN                          NaN
# 45464                     NaN                          NaN
# 45465                     NaN                          NaN
#
#       spoken_languages_name_9 spoken_languages_iso_639_1_10  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
# ...                       ...                           ...
# 45461                     NaN                           NaN
# 45462                     NaN                           NaN
# 45463                     NaN                           NaN
# 45464                     NaN                           NaN
# 45465                     NaN                           NaN
#
#       spoken_languages_name_10 spoken_languages_iso_639_1_11  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
# ...                        ...                           ...
# 45461                      NaN                           NaN
# 45462                      NaN                           NaN
# 45463                      NaN                           NaN
# 45464                      NaN                           NaN
# 45465                      NaN                           NaN
#
#       spoken_languages_name_11 spoken_languages_iso_639_1_12  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
# ...                        ...                           ...
# 45461                      NaN                           NaN
# 45462                      NaN                           NaN
# 45463                      NaN                           NaN
# 45464                      NaN                           NaN
# 45465                      NaN                           NaN
#
#       spoken_languages_name_12 spoken_languages_iso_639_1_13  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
# ...                        ...                           ...
# 45461                      NaN                           NaN
# 45462                      NaN                           NaN
# 45463                      NaN                           NaN
# 45464                      NaN                           NaN
# 45465                      NaN                           NaN
#
#       spoken_languages_name_13 spoken_languages_iso_639_1_14  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
# ...                        ...                           ...
# 45461                      NaN                           NaN
# 45462                      NaN                           NaN
# 45463                      NaN                           NaN
# 45464                      NaN                           NaN
# 45465                      NaN                           NaN
#
#       spoken_languages_name_14 spoken_languages_iso_639_1_15  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
# ...                        ...                           ...
# 45461                      NaN                           NaN
# 45462                      NaN                           NaN
# 45463                      NaN                           NaN
# 45464                      NaN                           NaN
# 45465                      NaN                           NaN
#
#       spoken_languages_name_15 spoken_languages_iso_639_1_16  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
# ...                        ...                           ...
# 45461                      NaN                           NaN
# 45462                      NaN                           NaN
# 45463                      NaN                           NaN
# 45464                      NaN                           NaN
# 45465                      NaN                           NaN
#
#       spoken_languages_name_16 spoken_languages_iso_639_1_17  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
# ...                        ...                           ...
# 45461                      NaN                           NaN
# 45462                      NaN                           NaN
# 45463                      NaN                           NaN
# 45464                      NaN                           NaN
# 45465                      NaN                           NaN
#
#       spoken_languages_name_17 spoken_languages_iso_639_1_18  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
# ...                        ...                           ...
# 45461                      NaN                           NaN
# 45462                      NaN                           NaN
# 45463                      NaN                           NaN
# 45464                      NaN                           NaN
# 45465                      NaN                           NaN
#
#       spoken_languages_name_18
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 45461                      NaN
# 45462                      NaN
# 45463                      NaN
# 45464                      NaN
# 45465                      NaN
#
# [45466 rows x 173 columns]

# %%
# number of movies at the beginning
start_num_rows = np.shape(movies)[0]
start_num_cols = np.shape(movies)[1]
print('Our dataset has {} entries and {} columns'.format(start_num_rows, start_num_cols))
# Out:
# Our dataset has 45466 entries and 173 columns

# %% [markdown]
# <font size="3">The tremendous number of columns come from the initial cleaning of the dataset, where we have expanded cells that had more than one possible value.</font>

# %% [markdown]
# ## Further cleaning

# %%
# make sure 'adult' column only has True or False
unique_adult = list(movies['adult'].unique())
print('Unique values in \'adult\' columns:')
for elt in unique_adult:
    print('> {} (type {})'.format(elt, type(elt)))
# there are some inconsistencies (some long strings and stringified booleans)
adult_todrop = [elt for elt in unique_adult if elt != False and elt != True and elt != 'False' and elt != 'True']
# Out:
# Unique values in 'adult' columns:
# > False (type <class 'bool'>)
# > False (type <class 'str'>)
# > True (type <class 'str'>)
# >  - Written by Ørnås (type <class 'str'>)
# >  Rune Balot goes to a casino connected to the October corporation to try to wrap up her case once and for all. (type <class 'str'>)
# >  Avalanche Sharks tells the story of a bikini contest that turns into a horrifying affair when it is hit by a shark avalanche. (type <class 'str'>)
# > True (type <class 'bool'>)

# %%
# take a look at strange rows in unique_adult
adult_todrop = movies[movies['adult'].isin(adult_todrop)]
adult_todrop
# Out:
#                                                    adult  \
# 19730                                 - Written by Ørnås
# 29503   Rune Balot goes to a casino connected to the ...
# 35587   Avalanche Sharks tells the story of a bikini ...
#
#                                  budget          id imdb_id original_language  \
# 19730  /ff9qCepilowshEtG2GYWwzt2bs4.jpg  1997-08-20       0             104.0
# 29503  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg  2012-09-29       0              68.0
# 35587  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg  2014-01-01       0              82.0
#
#                                  original_title             popularity  \
# 19730  [{'iso_639_1': 'en', 'name': 'English'}]                    NaN
# 29503      [{'iso_639_1': 'ja', 'name': '日本語'}]                    NaN
# 35587  [{'iso_639_1': 'en', 'name': 'English'}]  Beware Of Frost Bites
#
#       release_date  revenue  runtime status title video  vote_average  \
# 19730            1      NaN      NaN    NaN   NaN   NaN           NaN
# 29503           12      NaN      NaN    NaN   NaN   NaN           NaN
# 35587           22      NaN      NaN    NaN   NaN   NaN           NaN
#
#        vote_count  belongs_to_collection_id belongs_to_collection_name  \
# 19730         NaN                       NaN                        NaN
# 29503         NaN                       NaN                        NaN
# 35587         NaN                       NaN                        NaN
#
#        genres_id_0         genres_name_0  genres_id_1  \
# 19730      11176.0  Carousel Productions      11602.0
# 29503       2883.0               Aniplex       7759.0
# 35587      17161.0         Odyssey Media      18012.0
#
#                    genres_name_1  genres_id_2  \
# 19730  Vision View Entertainment      29812.0
# 29503                    GoHands       7760.0
# 35587         Pulser Productions      18013.0
#
#                           genres_name_2  genres_id_3  \
# 19730  Telescene Film Group Productions          NaN
# 29503                         BROSTA TV       7761.0
# 35587                       Rogue State      23822.0
#
#                                genres_name_3  genres_id_4     genres_name_4  \
# 19730                                    NaN          NaN               NaN
# 29503  Mardock Scramble Production Committee      33751.0  Sentai Filmworks
# 35587                             The Cartel          NaN               NaN
#
#        genres_id_5 genres_name_5  genres_id_6 genres_name_6  genres_id_7  \
# 19730          NaN           NaN          NaN           NaN          NaN
# 29503          NaN           NaN          NaN           NaN          NaN
# 35587          NaN           NaN          NaN           NaN          NaN
#
#       genres_name_7  production_companies_id_0 production_companies_name_0  \
# 19730           NaN                        NaN                         NaN
# 29503           NaN                        NaN                         NaN
# 35587           NaN                        NaN                         NaN
#
#        production_companies_id_1 production_companies_name_1  \
# 19730                        NaN                         NaN
# 29503                        NaN                         NaN
# 35587                        NaN                         NaN
#
#        production_companies_id_2 production_companies_name_2  \
# 19730                        NaN                         NaN
# 29503                        NaN                         NaN
# 35587                        NaN                         NaN
#
#        production_companies_id_3 production_companies_name_3  \
# 19730                        NaN                         NaN
# 29503                        NaN                         NaN
# 35587                        NaN                         NaN
#
#        production_companies_id_4 production_companies_name_4  \
# 19730                        NaN                         NaN
# 29503                        NaN                         NaN
# 35587                        NaN                         NaN
#
#        production_companies_id_5 production_companies_name_5  \
# 19730                        NaN                         NaN
# 29503                        NaN                         NaN
# 35587                        NaN                         NaN
#
#        production_companies_id_6 production_companies_name_6  \
# 19730                        NaN                         NaN
# 29503                        NaN                         NaN
# 35587                        NaN                         NaN
#
#        production_companies_id_7 production_companies_name_7  \
# 19730                        NaN                         NaN
# 29503                        NaN                         NaN
# 35587                        NaN                         NaN
#
#        production_companies_id_8 production_companies_name_8  \
# 19730                        NaN                         NaN
# 29503                        NaN                         NaN
# 35587                        NaN                         NaN
#
#        production_companies_id_9 production_companies_name_9  \
# 19730                        NaN                         NaN
# 29503                        NaN                         NaN
# 35587                        NaN                         NaN
#
#        production_companies_id_10 production_companies_name_10  \
# 19730                         NaN                          NaN
# 29503                         NaN                          NaN
# 35587                         NaN                          NaN
#
#        production_companies_id_11 production_companies_name_11  \
# 19730                         NaN                          NaN
# 29503                         NaN                          NaN
# 35587                         NaN                          NaN
#
#        production_companies_id_12 production_companies_name_12  \
# 19730                         NaN                          NaN
# 29503                         NaN                          NaN
# 35587                         NaN                          NaN
#
#        production_companies_id_13 production_companies_name_13  \
# 19730                         NaN                          NaN
# 29503                         NaN                          NaN
# 35587                         NaN                          NaN
#
#        production_companies_id_14 production_companies_name_14  \
# 19730                         NaN                          NaN
# 29503                         NaN                          NaN
# 35587                         NaN                          NaN
#
#        production_companies_id_15 production_companies_name_15  \
# 19730                         NaN                          NaN
# 29503                         NaN                          NaN
# 35587                         NaN                          NaN
#
#        production_companies_id_16 production_companies_name_16  \
# 19730                         NaN                          NaN
# 29503                         NaN                          NaN
# 35587                         NaN                          NaN
#
#        production_companies_id_17 production_companies_name_17  \
# 19730                         NaN                          NaN
# 29503                         NaN                          NaN
# 35587                         NaN                          NaN
#
#        production_companies_id_18 production_companies_name_18  \
# 19730                         NaN                          NaN
# 29503                         NaN                          NaN
# 35587                         NaN                          NaN
#
#        production_companies_id_19 production_companies_name_19  \
# 19730                         NaN                          NaN
# 29503                         NaN                          NaN
# 35587                         NaN                          NaN
#
#        production_companies_id_20 production_companies_name_20  \
# 19730                         NaN                          NaN
# 29503                         NaN                          NaN
# 35587                         NaN                          NaN
#
#        production_companies_id_21 production_companies_name_21  \
# 19730                         NaN                          NaN
# 29503                         NaN                          NaN
# 35587                         NaN                          NaN
#
#        production_companies_id_22 production_companies_name_22  \
# 19730                         NaN                          NaN
# 29503                         NaN                          NaN
# 35587                         NaN                          NaN
#
#        production_companies_id_23 production_companies_name_23  \
# 19730                         NaN                          NaN
# 29503                         NaN                          NaN
# 35587                         NaN                          NaN
#
#        production_companies_id_24 production_companies_name_24  \
# 19730                         NaN                          NaN
# 29503                         NaN                          NaN
# 35587                         NaN                          NaN
#
#        production_companies_id_25 production_companies_name_25  \
# 19730                         NaN                          NaN
# 29503                         NaN                          NaN
# 35587                         NaN                          NaN
#
#       production_countries_iso_3166_1_0 production_countries_name_0  \
# 19730                               NaN                         NaN
# 29503                               NaN                         NaN
# 35587                               NaN                         NaN
#
#       production_countries_iso_3166_1_1 production_countries_name_1  \
# 19730                               NaN                         NaN
# 29503                               NaN                         NaN
# 35587                               NaN                         NaN
#
#       production_countries_iso_3166_1_2 production_countries_name_2  \
# 19730                               NaN                         NaN
# 29503                               NaN                         NaN
# 35587                               NaN                         NaN
#
#       production_countries_iso_3166_1_3 production_countries_name_3  \
# 19730                               NaN                         NaN
# 29503                               NaN                         NaN
# 35587                               NaN                         NaN
#
#       production_countries_iso_3166_1_4 production_countries_name_4  \
# 19730                               NaN                         NaN
# 29503                               NaN                         NaN
# 35587                               NaN                         NaN
#
#       production_countries_iso_3166_1_5 production_countries_name_5  \
# 19730                               NaN                         NaN
# 29503                               NaN                         NaN
# 35587                               NaN                         NaN
#
#       production_countries_iso_3166_1_6 production_countries_name_6  \
# 19730                               NaN                         NaN
# 29503                               NaN                         NaN
# 35587                               NaN                         NaN
#
#       production_countries_iso_3166_1_7 production_countries_name_7  \
# 19730                               NaN                         NaN
# 29503                               NaN                         NaN
# 35587                               NaN                         NaN
#
#       production_countries_iso_3166_1_8 production_countries_name_8  \
# 19730                               NaN                         NaN
# 29503                               NaN                         NaN
# 35587                               NaN                         NaN
#
#       production_countries_iso_3166_1_9 production_countries_name_9  \
# 19730                               NaN                         NaN
# 29503                               NaN                         NaN
# 35587                               NaN                         NaN
#
#       production_countries_iso_3166_1_10 production_countries_name_10  \
# 19730                                NaN                          NaN
# 29503                                NaN                          NaN
# 35587                                NaN                          NaN
#
#       production_countries_iso_3166_1_11 production_countries_name_11  \
# 19730                                NaN                          NaN
# 29503                                NaN                          NaN
# 35587                                NaN                          NaN
#
#       production_countries_iso_3166_1_12 production_countries_name_12  \
# 19730                                NaN                          NaN
# 29503                                NaN                          NaN
# 35587                                NaN                          NaN
#
#       production_countries_iso_3166_1_13 production_countries_name_13  \
# 19730                                NaN                          NaN
# 29503                                NaN                          NaN
# 35587                                NaN                          NaN
#
#       production_countries_iso_3166_1_14 production_countries_name_14  \
# 19730                                NaN                          NaN
# 29503                                NaN                          NaN
# 35587                                NaN                          NaN
#
#       production_countries_iso_3166_1_15 production_countries_name_15  \
# 19730                                NaN                          NaN
# 29503                                NaN                          NaN
# 35587                                NaN                          NaN
#
#       production_countries_iso_3166_1_16 production_countries_name_16  \
# 19730                                NaN                          NaN
# 29503                                NaN                          NaN
# 35587                                NaN                          NaN
#
#       production_countries_iso_3166_1_17 production_countries_name_17  \
# 19730                                NaN                          NaN
# 29503                                NaN                          NaN
# 35587                                NaN                          NaN
#
#       production_countries_iso_3166_1_18 production_countries_name_18  \
# 19730                                NaN                          NaN
# 29503                                NaN                          NaN
# 35587                                NaN                          NaN
#
#       production_countries_iso_3166_1_19 production_countries_name_19  \
# 19730                                NaN                          NaN
# 29503                                NaN                          NaN
# 35587                                NaN                          NaN
#
#       production_countries_iso_3166_1_20 production_countries_name_20  \
# 19730                                NaN                          NaN
# 29503                                NaN                          NaN
# 35587                                NaN                          NaN
#
#       production_countries_iso_3166_1_21 production_countries_name_21  \
# 19730                                NaN                          NaN
# 29503                                NaN                          NaN
# 35587                                NaN                          NaN
#
#       production_countries_iso_3166_1_22 production_countries_name_22  \
# 19730                                NaN                          NaN
# 29503                                NaN                          NaN
# 35587                                NaN                          NaN
#
#       production_countries_iso_3166_1_23 production_countries_name_23  \
# 19730                                NaN                          NaN
# 29503                                NaN                          NaN
# 35587                                NaN                          NaN
#
#       production_countries_iso_3166_1_24 production_countries_name_24  \
# 19730                                NaN                          NaN
# 29503                                NaN                          NaN
# 35587                                NaN                          NaN
#
#       spoken_languages_iso_639_1_0 spoken_languages_name_0  \
# 19730                          NaN                     NaN
# 29503                          NaN                     NaN
# 35587                          NaN                     NaN
#
#       spoken_languages_iso_639_1_1 spoken_languages_name_1  \
# 19730                          NaN                     NaN
# 29503                          NaN                     NaN
# 35587                          NaN                     NaN
#
#       spoken_languages_iso_639_1_2 spoken_languages_name_2  \
# 19730                          NaN                     NaN
# 29503                          NaN                     NaN
# 35587                          NaN                     NaN
#
#       spoken_languages_iso_639_1_3 spoken_languages_name_3  \
# 19730                          NaN                     NaN
# 29503                          NaN                     NaN
# 35587                          NaN                     NaN
#
#       spoken_languages_iso_639_1_4 spoken_languages_name_4  \
# 19730                          NaN                     NaN
# 29503                          NaN                     NaN
# 35587                          NaN                     NaN
#
#       spoken_languages_iso_639_1_5 spoken_languages_name_5  \
# 19730                          NaN                     NaN
# 29503                          NaN                     NaN
# 35587                          NaN                     NaN
#
#       spoken_languages_iso_639_1_6 spoken_languages_name_6  \
# 19730                          NaN                     NaN
# 29503                          NaN                     NaN
# 35587                          NaN                     NaN
#
#       spoken_languages_iso_639_1_7 spoken_languages_name_7  \
# 19730                          NaN                     NaN
# 29503                          NaN                     NaN
# 35587                          NaN                     NaN
#
#       spoken_languages_iso_639_1_8 spoken_languages_name_8  \
# 19730                          NaN                     NaN
# 29503                          NaN                     NaN
# 35587                          NaN                     NaN
#
#       spoken_languages_iso_639_1_9 spoken_languages_name_9  \
# 19730                          NaN                     NaN
# 29503                          NaN                     NaN
# 35587                          NaN                     NaN
#
#       spoken_languages_iso_639_1_10 spoken_languages_name_10  \
# 19730                           NaN                      NaN
# 29503                           NaN                      NaN
# 35587                           NaN                      NaN
#
#       spoken_languages_iso_639_1_11 spoken_languages_name_11  \
# 19730                           NaN                      NaN
# 29503                           NaN                      NaN
# 35587                           NaN                      NaN
#
#       spoken_languages_iso_639_1_12 spoken_languages_name_12  \
# 19730                           NaN                      NaN
# 29503                           NaN                      NaN
# 35587                           NaN                      NaN
#
#       spoken_languages_iso_639_1_13 spoken_languages_name_13  \
# 19730                           NaN                      NaN
# 29503                           NaN                      NaN
# 35587                           NaN                      NaN
#
#       spoken_languages_iso_639_1_14 spoken_languages_name_14  \
# 19730                           NaN                      NaN
# 29503                           NaN                      NaN
# 35587                           NaN                      NaN
#
#       spoken_languages_iso_639_1_15 spoken_languages_name_15  \
# 19730                           NaN                      NaN
# 29503                           NaN                      NaN
# 35587                           NaN                      NaN
#
#       spoken_languages_iso_639_1_16 spoken_languages_name_16  \
# 19730                           NaN                      NaN
# 29503                           NaN                      NaN
# 35587                           NaN                      NaN
#
#       spoken_languages_iso_639_1_17 spoken_languages_name_17  \
# 19730                           NaN                      NaN
# 29503                           NaN                      NaN
# 35587                           NaN                      NaN
#
#       spoken_languages_iso_639_1_18 spoken_languages_name_18
# 19730                           NaN                      NaN
# 29503                           NaN                      NaN
# 35587                           NaN                      NaN

# %% [markdown]
# <font size="3">We observe that the above rows are pretty weird. We drop them.</font>

# %%
movies = movies.drop(index = adult_todrop.index)

# %% [markdown]
# <font size="3">We transform the imdb_id column.</font>

# %%
display(movies[['imdb_id']].head())
movies['imdb_id'] = movies['imdb_id'].str.strip('tt0') # strip all leading tt and 0s
# Out:
#      imdb_id
# 0  tt0114709
# 1  tt0113497
# 2  tt0113228
# 3  tt0114885
# 4  tt0113041

# %% [markdown]
# <font size="3">We continue by converting columns to check for more inconsistencies or errors in the data.</font>

# %%
# convert 'adult' column to bool
movies['adult'] = movies['adult'].astype(bool) # runs without errors
# convert all columns representing ids to int
col_id = movies.filter(regex = '_.*id').columns
movies[col_id] = movies[col_id].fillna(value = -1) # workaround since nans cannot be converted to integers
movies[col_id] = movies[col_id].astype(int) # runs without errors
# convert some columns to float'
col_float = ['budget', 'popularity', 'revenue', 'runtime', 'vote_average', 'vote_count']
movies[col_float] = movies[col_float].astype(float) # runs without errors
# convert 'video' column to bool
movies['video'] = movies['video'].astype(bool) # runs without errors
# convert 'release_date' column to datetime
movies['release_date'] = pd.to_datetime(movies['release_date'])

# %% [markdown]
# <font size="3">We then analyse the NaNs in each columns</font>

# %%
nulls = movies.iloc[:, 0:15].isnull().sum(axis = 0)
display(pd.DataFrame(nulls).T)
# Out:
#    adult  budget  id  imdb_id  original_language  original_title  popularity  \
# 0      0       0   0        0                 11               0           3
#
#    release_date  revenue  runtime  status  title  video  vote_average  \
# 0            87        3      260      84      3      0             3
#
#    vote_count
# 0           3

# %%
todrop = movies[movies['popularity'].isnull()] # these rows are too incomplete, we drop them
display(todrop)
movies = movies.drop(index = todrop.index)
# Out:
#        adult  budget      id  imdb_id original_language    original_title  \
# 19729   True     0.0   82663   113002                en      Midnight Man
# 29502   True     0.0  122662  2423504                ja  マルドゥック・スクランブル 排気
# 35586   True     0.0  249260  2622826                en  Avalanche Sharks
#
#        popularity release_date  revenue  runtime status title  video  \
# 19729         NaN          NaT      NaN      NaN    NaN   NaN   True
# 29502         NaN          NaT      NaN      NaN    NaN   NaN   True
# 35586         NaN          NaT      NaN      NaN    NaN   NaN   True
#
#        vote_average  vote_count  belongs_to_collection_id  \
# 19729           NaN         NaN                        -1
# 29502           NaN         NaN                    122661
# 35586           NaN         NaN                        -1
#
#         belongs_to_collection_name  genres_id_0 genres_name_0  genres_id_1  \
# 19729                          NaN           28        Action           53
# 29502  Mardock Scramble Collection           16     Animation          878
# 35586                          NaN        10770      TV Movie           28
#
#          genres_name_1  genres_id_2 genres_name_2  genres_id_3  \
# 19729         Thriller           18         Drama           -1
# 29502  Science Fiction           -1           NaN           -1
# 35586           Action           27        Horror          878
#
#          genres_name_3  genres_id_4 genres_name_4  genres_id_5 genres_name_5  \
# 19729              NaN           -1           NaN           -1           NaN
# 29502              NaN           -1           NaN           -1           NaN
# 35586  Science Fiction           -1           NaN           -1           NaN
#
#        genres_id_6 genres_name_6  genres_id_7 genres_name_7  \
# 19729           -1           NaN           -1           NaN
# 29502           -1           NaN           -1           NaN
# 35586           -1           NaN           -1           NaN
#
#        production_companies_id_0 production_companies_name_0  \
# 19729                         -1                         NaN
# 29502                         -1                         NaN
# 35586                         -1                         NaN
#
#        production_companies_id_1 production_companies_name_1  \
# 19729                         -1                         NaN
# 29502                         -1                         NaN
# 35586                         -1                         NaN
#
#        production_companies_id_2 production_companies_name_2  \
# 19729                         -1                         NaN
# 29502                         -1                         NaN
# 35586                         -1                         NaN
#
#        production_companies_id_3 production_companies_name_3  \
# 19729                         -1                         NaN
# 29502                         -1                         NaN
# 35586                         -1                         NaN
#
#        production_companies_id_4 production_companies_name_4  \
# 19729                         -1                         NaN
# 29502                         -1                         NaN
# 35586                         -1                         NaN
#
#        production_companies_id_5 production_companies_name_5  \
# 19729                         -1                         NaN
# 29502                         -1                         NaN
# 35586                         -1                         NaN
#
#        production_companies_id_6 production_companies_name_6  \
# 19729                         -1                         NaN
# 29502                         -1                         NaN
# 35586                         -1                         NaN
#
#        production_companies_id_7 production_companies_name_7  \
# 19729                         -1                         NaN
# 29502                         -1                         NaN
# 35586                         -1                         NaN
#
#        production_companies_id_8 production_companies_name_8  \
# 19729                         -1                         NaN
# 29502                         -1                         NaN
# 35586                         -1                         NaN
#
#        production_companies_id_9 production_companies_name_9  \
# 19729                         -1                         NaN
# 29502                         -1                         NaN
# 35586                         -1                         NaN
#
#        production_companies_id_10 production_companies_name_10  \
# 19729                          -1                          NaN
# 29502                          -1                          NaN
# 35586                          -1                          NaN
#
#        production_companies_id_11 production_companies_name_11  \
# 19729                          -1                          NaN
# 29502                          -1                          NaN
# 35586                          -1                          NaN
#
#        production_companies_id_12 production_companies_name_12  \
# 19729                          -1                          NaN
# 29502                          -1                          NaN
# 35586                          -1                          NaN
#
#        production_companies_id_13 production_companies_name_13  \
# 19729                          -1                          NaN
# 29502                          -1                          NaN
# 35586                          -1                          NaN
#
#        production_companies_id_14 production_companies_name_14  \
# 19729                          -1                          NaN
# 29502                          -1                          NaN
# 35586                          -1                          NaN
#
#        production_companies_id_15 production_companies_name_15  \
# 19729                          -1                          NaN
# 29502                          -1                          NaN
# 35586                          -1                          NaN
#
#        production_companies_id_16 production_companies_name_16  \
# 19729                          -1                          NaN
# 29502                          -1                          NaN
# 35586                          -1                          NaN
#
#        production_companies_id_17 production_companies_name_17  \
# 19729                          -1                          NaN
# 29502                          -1                          NaN
# 35586                          -1                          NaN
#
#        production_companies_id_18 production_companies_name_18  \
# 19729                          -1                          NaN
# 29502                          -1                          NaN
# 35586                          -1                          NaN
#
#        production_companies_id_19 production_companies_name_19  \
# 19729                          -1                          NaN
# 29502                          -1                          NaN
# 35586                          -1                          NaN
#
#        production_companies_id_20 production_companies_name_20  \
# 19729                          -1                          NaN
# 29502                          -1                          NaN
# 35586                          -1                          NaN
#
#        production_companies_id_21 production_companies_name_21  \
# 19729                          -1                          NaN
# 29502                          -1                          NaN
# 35586                          -1                          NaN
#
#        production_companies_id_22 production_companies_name_22  \
# 19729                          -1                          NaN
# 29502                          -1                          NaN
# 35586                          -1                          NaN
#
#        production_companies_id_23 production_companies_name_23  \
# 19729                          -1                          NaN
# 29502                          -1                          NaN
# 35586                          -1                          NaN
#
#        production_companies_id_24 production_companies_name_24  \
# 19729                          -1                          NaN
# 29502                          -1                          NaN
# 35586                          -1                          NaN
#
#        production_companies_id_25 production_companies_name_25  \
# 19729                          -1                          NaN
# 29502                          -1                          NaN
# 35586                          -1                          NaN
#
#       production_countries_iso_3166_1_0 production_countries_name_0  \
# 19729                               NaN                         NaN
# 29502                               NaN                         NaN
# 35586                               NaN                         NaN
#
#       production_countries_iso_3166_1_1 production_countries_name_1  \
# 19729                               NaN                         NaN
# 29502                               NaN                         NaN
# 35586                               NaN                         NaN
#
#       production_countries_iso_3166_1_2 production_countries_name_2  \
# 19729                               NaN                         NaN
# 29502                               NaN                         NaN
# 35586                               NaN                         NaN
#
#       production_countries_iso_3166_1_3 production_countries_name_3  \
# 19729                               NaN                         NaN
# 29502                               NaN                         NaN
# 35586                               NaN                         NaN
#
#       production_countries_iso_3166_1_4 production_countries_name_4  \
# 19729                               NaN                         NaN
# 29502                               NaN                         NaN
# 35586                               NaN                         NaN
#
#       production_countries_iso_3166_1_5 production_countries_name_5  \
# 19729                               NaN                         NaN
# 29502                               NaN                         NaN
# 35586                               NaN                         NaN
#
#       production_countries_iso_3166_1_6 production_countries_name_6  \
# 19729                               NaN                         NaN
# 29502                               NaN                         NaN
# 35586                               NaN                         NaN
#
#       production_countries_iso_3166_1_7 production_countries_name_7  \
# 19729                               NaN                         NaN
# 29502                               NaN                         NaN
# 35586                               NaN                         NaN
#
#       production_countries_iso_3166_1_8 production_countries_name_8  \
# 19729                               NaN                         NaN
# 29502                               NaN                         NaN
# 35586                               NaN                         NaN
#
#       production_countries_iso_3166_1_9 production_countries_name_9  \
# 19729                               NaN                         NaN
# 29502                               NaN                         NaN
# 35586                               NaN                         NaN
#
#       production_countries_iso_3166_1_10 production_countries_name_10  \
# 19729                                NaN                          NaN
# 29502                                NaN                          NaN
# 35586                                NaN                          NaN
#
#       production_countries_iso_3166_1_11 production_countries_name_11  \
# 19729                                NaN                          NaN
# 29502                                NaN                          NaN
# 35586                                NaN                          NaN
#
#       production_countries_iso_3166_1_12 production_countries_name_12  \
# 19729                                NaN                          NaN
# 29502                                NaN                          NaN
# 35586                                NaN                          NaN
#
#       production_countries_iso_3166_1_13 production_countries_name_13  \
# 19729                                NaN                          NaN
# 29502                                NaN                          NaN
# 35586                                NaN                          NaN
#
#       production_countries_iso_3166_1_14 production_countries_name_14  \
# 19729                                NaN                          NaN
# 29502                                NaN                          NaN
# 35586                                NaN                          NaN
#
#       production_countries_iso_3166_1_15 production_countries_name_15  \
# 19729                                NaN                          NaN
# 29502                                NaN                          NaN
# 35586                                NaN                          NaN
#
#       production_countries_iso_3166_1_16 production_countries_name_16  \
# 19729                                NaN                          NaN
# 29502                                NaN                          NaN
# 35586                                NaN                          NaN
#
#       production_countries_iso_3166_1_17 production_countries_name_17  \
# 19729                                NaN                          NaN
# 29502                                NaN                          NaN
# 35586                                NaN                          NaN
#
#       production_countries_iso_3166_1_18 production_countries_name_18  \
# 19729                                NaN                          NaN
# 29502                                NaN                          NaN
# 35586                                NaN                          NaN
#
#       production_countries_iso_3166_1_19 production_countries_name_19  \
# 19729                                NaN                          NaN
# 29502                                NaN                          NaN
# 35586                                NaN                          NaN
#
#       production_countries_iso_3166_1_20 production_countries_name_20  \
# 19729                                NaN                          NaN
# 29502                                NaN                          NaN
# 35586                                NaN                          NaN
#
#       production_countries_iso_3166_1_21 production_countries_name_21  \
# 19729                                NaN                          NaN
# 29502                                NaN                          NaN
# 35586                                NaN                          NaN
#
#       production_countries_iso_3166_1_22 production_countries_name_22  \
# 19729                                NaN                          NaN
# 29502                                NaN                          NaN
# 35586                                NaN                          NaN
#
#       production_countries_iso_3166_1_23 production_countries_name_23  \
# 19729                                NaN                          NaN
# 29502                                NaN                          NaN
# 35586                                NaN                          NaN
#
#       production_countries_iso_3166_1_24 production_countries_name_24  \
# 19729                                NaN                          NaN
# 29502                                NaN                          NaN
# 35586                                NaN                          NaN
#
#       spoken_languages_iso_639_1_0 spoken_languages_name_0  \
# 19729                          NaN                     NaN
# 29502                          NaN                     NaN
# 35586                          NaN                     NaN
#
#       spoken_languages_iso_639_1_1 spoken_languages_name_1  \
# 19729                          NaN                     NaN
# 29502                          NaN                     NaN
# 35586                          NaN                     NaN
#
#       spoken_languages_iso_639_1_2 spoken_languages_name_2  \
# 19729                          NaN                     NaN
# 29502                          NaN                     NaN
# 35586                          NaN                     NaN
#
#       spoken_languages_iso_639_1_3 spoken_languages_name_3  \
# 19729                          NaN                     NaN
# 29502                          NaN                     NaN
# 35586                          NaN                     NaN
#
#       spoken_languages_iso_639_1_4 spoken_languages_name_4  \
# 19729                          NaN                     NaN
# 29502                          NaN                     NaN
# 35586                          NaN                     NaN
#
#       spoken_languages_iso_639_1_5 spoken_languages_name_5  \
# 19729                          NaN                     NaN
# 29502                          NaN                     NaN
# 35586                          NaN                     NaN
#
#       spoken_languages_iso_639_1_6 spoken_languages_name_6  \
# 19729                          NaN                     NaN
# 29502                          NaN                     NaN
# 35586                          NaN                     NaN
#
#       spoken_languages_iso_639_1_7 spoken_languages_name_7  \
# 19729                          NaN                     NaN
# 29502                          NaN                     NaN
# 35586                          NaN                     NaN
#
#       spoken_languages_iso_639_1_8 spoken_languages_name_8  \
# 19729                          NaN                     NaN
# 29502                          NaN                     NaN
# 35586                          NaN                     NaN
#
#       spoken_languages_iso_639_1_9 spoken_languages_name_9  \
# 19729                          NaN                     NaN
# 29502                          NaN                     NaN
# 35586                          NaN                     NaN
#
#       spoken_languages_iso_639_1_10 spoken_languages_name_10  \
# 19729                           NaN                      NaN
# 29502                           NaN                      NaN
# 35586                           NaN                      NaN
#
#       spoken_languages_iso_639_1_11 spoken_languages_name_11  \
# 19729                           NaN                      NaN
# 29502                           NaN                      NaN
# 35586                           NaN                      NaN
#
#       spoken_languages_iso_639_1_12 spoken_languages_name_12  \
# 19729                           NaN                      NaN
# 29502                           NaN                      NaN
# 35586                           NaN                      NaN
#
#       spoken_languages_iso_639_1_13 spoken_languages_name_13  \
# 19729                           NaN                      NaN
# 29502                           NaN                      NaN
# 35586                           NaN                      NaN
#
#       spoken_languages_iso_639_1_14 spoken_languages_name_14  \
# 19729                           NaN                      NaN
# 29502                           NaN                      NaN
# 35586                           NaN                      NaN
#
#       spoken_languages_iso_639_1_15 spoken_languages_name_15  \
# 19729                           NaN                      NaN
# 29502                           NaN                      NaN
# 35586                           NaN                      NaN
#
#       spoken_languages_iso_639_1_16 spoken_languages_name_16  \
# 19729                           NaN                      NaN
# 29502                           NaN                      NaN
# 35586                           NaN                      NaN
#
#       spoken_languages_iso_639_1_17 spoken_languages_name_17  \
# 19729                           NaN                      NaN
# 29502                           NaN                      NaN
# 35586                           NaN                      NaN
#
#       spoken_languages_iso_639_1_18 spoken_languages_name_18
# 19729                           NaN                      NaN
# 29502                           NaN                      NaN
# 35586                           NaN                      NaN

# %% [markdown]
# <font size="3">We have enough data to drop some rows that have incomplete data in the first columns (adult ~ vote_count)</font>

# %%
nulls_todrop = nulls[nulls.between(1, max(nulls))].index
for col in nulls_todrop:
    todrop = movies[movies[col].isnull()]
    movies = movies.drop(index = todrop.index)
print('Our dataset now has {} entries compared to {} in the beginning.'.format(len(movies), start_num_rows))
# Out:
# Our dataset now has 45043 entries compared to 45466 in the beginning.

# %%
# Convert boolean columns to integers (False = 0, True = 1)
bool_col = movies.dtypes[movies.dtypes == 'bool'].index
movies[bool_col] = movies[bool_col].astype(int)

# %%
# replace release date by the year and month, we don't care about the day
movies['release_year'] = pd.DatetimeIndex(movies['release_date']).year
movies['release_year'] = movies['release_year'].astype('int')
movies['release_month'] = pd.DatetimeIndex(movies['release_date']).month
movies['release_month'] = movies['release_month'].astype('int')
# drop release date
movies = movies.drop(columns = 'release_date')

# %%
# count number of possibilities of status
print(movies['status'].value_counts())
# Rumored, post production, in production and planned movies can be removed as they only 
# represent a small fraction of all movies. We keep only released
movies = movies[movies['status'] == 'Released']
# Out:
# Released           44686
# Rumored              229
# Post Production       97
# In Production         17
# Planned               13
# Canceled               1
# Name: status, dtype: int64

# %% [markdown]
# <font size="3">Indeed, this is a good assumption. Movies like Avatar 2 who are in production do not have sufficient data in terms of revenue and budget to actually be useful.</font>

# %%
# we drop status column
movies = movies.drop(columns = 'status')

# %% [markdown]
# # Info of dataset

# %%
to_describe = movies.drop(columns = movies.filter(regex = 'genres|production|language|collection|title|id').columns)
to_describe.describe()
# Out:
#               adult        budget    popularity       revenue       runtime  \
# count  44686.000000  4.468600e+04  44686.000000  4.468600e+04  44686.000000
# mean       0.269368  4.295965e+06      2.959225  1.140190e+07     94.323099
# std        0.443637  1.756607e+07      6.040798  6.487003e+07     38.297097
# min        0.000000  0.000000e+00      0.000000  0.000000e+00      0.000000
# 25%        0.000000  0.000000e+00      0.402182  0.000000e+00     85.000000
# 50%        0.000000  0.000000e+00      1.151609  0.000000e+00     95.000000
# 75%        1.000000  0.000000e+00      3.777141  0.000000e+00    107.000000
# max        1.000000  3.800000e+08    547.488298  2.787965e+09   1256.000000
#
#        vote_average    vote_count  release_year  release_month
# count  44686.000000  44686.000000  44686.000000   44686.000000
# mean       5.640326    111.685897   1991.794947       6.463322
# std        1.892305    495.349516     24.086647       3.624150
# min        0.000000      0.000000   1874.000000       1.000000
# 25%        5.000000      3.000000   1978.000000       3.000000
# 50%        6.000000     10.000000   2001.000000       7.000000
# 75%        6.800000     35.000000   2010.000000      10.000000
# max       10.000000  14075.000000   2017.000000      12.000000

# %% [markdown]
# <font size="3">Unusual data: popularity with low quantiles with at least one outlier (max at 547). Same thing for runtime (one movie lasts 21 hours!). For the revenue and budget columns, the 25 to 75% percentiles are close to 0, this is because there are A LOT of movies that have no budget and/or generated no revenue.</font>

# %%
max_popularity = movies.sort_values('popularity', ascending = False)
max_popularity.head() # actually the popularity seems normal
# Out:
#        adult       budget      id  imdb_id original_language  \
# 30700      1   74000000.0  211672   229364                en
# 33356      1  149000000.0  297762   451279                en
# 42222      0  160000000.0  321612    27712                en
# 43644      0   34000000.0  339403   389016                en
# 24455      0  165000000.0  177572  2245084                en
#
#              original_title  popularity       revenue  runtime  \
# 30700               Minions  547.488298  1.156731e+09     91.0
# 33356          Wonder Woman  294.337037  8.205804e+08    141.0
# 42222  Beauty and the Beast  287.253654  1.262886e+09    129.0
# 43644           Baby Driver  228.032744  2.245113e+08    113.0
# 24455            Big Hero 6  213.849907  6.521054e+08    102.0
#
#                       title  video  vote_average  vote_count  \
# 30700               Minions      0           6.4      4729.0
# 33356          Wonder Woman      0           7.2      5025.0
# 42222  Beauty and the Beast      0           6.8      5530.0
# 43644           Baby Driver      0           7.2      2083.0
# 24455            Big Hero 6      0           7.8      6289.0
#
#        belongs_to_collection_id belongs_to_collection_name  genres_id_0  \
# 30700                     86066   Despicable Me Collection        10751
# 33356                    468552    Wonder Woman Collection           28
# 42222                        -1                        NaN        10751
# 43644                        -1                        NaN           28
# 24455                        -1                        NaN           12
#
#       genres_name_0  genres_id_1 genres_name_1  genres_id_2 genres_name_2  \
# 30700        Family           16     Animation           12     Adventure
# 33356        Action           12     Adventure           14       Fantasy
# 42222        Family           14       Fantasy        10749       Romance
# 43644        Action           80         Crime           -1           NaN
# 24455     Adventure        10751        Family           16     Animation
#
#        genres_id_3 genres_name_3  genres_id_4 genres_name_4  genres_id_5  \
# 30700           35        Comedy           -1           NaN           -1
# 33356           -1           NaN           -1           NaN           -1
# 42222           -1           NaN           -1           NaN           -1
# 43644           -1           NaN           -1           NaN           -1
# 24455           28        Action           35        Comedy           -1
#
#       genres_name_5  genres_id_6 genres_name_6  genres_id_7 genres_name_7  \
# 30700           NaN           -1           NaN           -1           NaN
# 33356           NaN           -1           NaN           -1           NaN
# 42222           NaN           -1           NaN           -1           NaN
# 43644           NaN           -1           NaN           -1           NaN
# 24455           NaN           -1           NaN           -1           NaN
#
#        production_companies_id_0 production_companies_name_0  \
# 30700                         33          Universal Pictures
# 33356                        444          Dune Entertainment
# 42222                          2        Walt Disney Pictures
# 43644                        443        Big Talk Productions
# 24455                          2        Walt Disney Pictures
#
#        production_companies_id_1    production_companies_name_1  \
# 30700                       6704     Illumination Entertainment
# 33356                        507            Atlas Entertainment
# 42222                      10227               Mandeville Films
# 43644                        559               TriStar Pictures
# 24455                       6125  Walt Disney Animation Studios
#
#        production_companies_id_2 production_companies_name_2  \
# 30700                         -1                         NaN
# 33356                       6194                Warner Bros.
# 42222                         -1                         NaN
# 43644                       2531        Media Rights Capital
# 24455                         -1                         NaN
#
#        production_companies_id_3 production_companies_name_3  \
# 30700                         -1                         NaN
# 33356                       9993            DC Entertainment
# 42222                         -1                         NaN
# 43644                      10163         Working Title Films
# 24455                         -1                         NaN
#
#        production_companies_id_4 production_companies_name_4  \
# 30700                         -1                         NaN
# 33356                       9995       Cruel & Unusual Films
# 42222                         -1                         NaN
# 43644                      31922             Double Negative
# 24455                         -1                         NaN
#
#        production_companies_id_5 production_companies_name_5  \
# 30700                         -1                         NaN
# 33356                      81620            TENCENT PICTURES
# 42222                         -1                         NaN
# 43644                         -1                         NaN
# 24455                         -1                         NaN
#
#        production_companies_id_6 production_companies_name_6  \
# 30700                         -1                         NaN
# 33356                      83838              Wanda Pictures
# 42222                         -1                         NaN
# 43644                         -1                         NaN
# 24455                         -1                         NaN
#
#        production_companies_id_7 production_companies_name_7  \
# 30700                         -1                         NaN
# 33356                         -1                         NaN
# 42222                         -1                         NaN
# 43644                         -1                         NaN
# 24455                         -1                         NaN
#
#        production_companies_id_8 production_companies_name_8  \
# 30700                         -1                         NaN
# 33356                         -1                         NaN
# 42222                         -1                         NaN
# 43644                         -1                         NaN
# 24455                         -1                         NaN
#
#        production_companies_id_9 production_companies_name_9  \
# 30700                         -1                         NaN
# 33356                         -1                         NaN
# 42222                         -1                         NaN
# 43644                         -1                         NaN
# 24455                         -1                         NaN
#
#        production_companies_id_10 production_companies_name_10  \
# 30700                          -1                          NaN
# 33356                          -1                          NaN
# 42222                          -1                          NaN
# 43644                          -1                          NaN
# 24455                          -1                          NaN
#
#        production_companies_id_11 production_companies_name_11  \
# 30700                          -1                          NaN
# 33356                          -1                          NaN
# 42222                          -1                          NaN
# 43644                          -1                          NaN
# 24455                          -1                          NaN
#
#        production_companies_id_12 production_companies_name_12  \
# 30700                          -1                          NaN
# 33356                          -1                          NaN
# 42222                          -1                          NaN
# 43644                          -1                          NaN
# 24455                          -1                          NaN
#
#        production_companies_id_13 production_companies_name_13  \
# 30700                          -1                          NaN
# 33356                          -1                          NaN
# 42222                          -1                          NaN
# 43644                          -1                          NaN
# 24455                          -1                          NaN
#
#        production_companies_id_14 production_companies_name_14  \
# 30700                          -1                          NaN
# 33356                          -1                          NaN
# 42222                          -1                          NaN
# 43644                          -1                          NaN
# 24455                          -1                          NaN
#
#        production_companies_id_15 production_companies_name_15  \
# 30700                          -1                          NaN
# 33356                          -1                          NaN
# 42222                          -1                          NaN
# 43644                          -1                          NaN
# 24455                          -1                          NaN
#
#        production_companies_id_16 production_companies_name_16  \
# 30700                          -1                          NaN
# 33356                          -1                          NaN
# 42222                          -1                          NaN
# 43644                          -1                          NaN
# 24455                          -1                          NaN
#
#        production_companies_id_17 production_companies_name_17  \
# 30700                          -1                          NaN
# 33356                          -1                          NaN
# 42222                          -1                          NaN
# 43644                          -1                          NaN
# 24455                          -1                          NaN
#
#        production_companies_id_18 production_companies_name_18  \
# 30700                          -1                          NaN
# 33356                          -1                          NaN
# 42222                          -1                          NaN
# 43644                          -1                          NaN
# 24455                          -1                          NaN
#
#        production_companies_id_19 production_companies_name_19  \
# 30700                          -1                          NaN
# 33356                          -1                          NaN
# 42222                          -1                          NaN
# 43644                          -1                          NaN
# 24455                          -1                          NaN
#
#        production_companies_id_20 production_companies_name_20  \
# 30700                          -1                          NaN
# 33356                          -1                          NaN
# 42222                          -1                          NaN
# 43644                          -1                          NaN
# 24455                          -1                          NaN
#
#        production_companies_id_21 production_companies_name_21  \
# 30700                          -1                          NaN
# 33356                          -1                          NaN
# 42222                          -1                          NaN
# 43644                          -1                          NaN
# 24455                          -1                          NaN
#
#        production_companies_id_22 production_companies_name_22  \
# 30700                          -1                          NaN
# 33356                          -1                          NaN
# 42222                          -1                          NaN
# 43644                          -1                          NaN
# 24455                          -1                          NaN
#
#        production_companies_id_23 production_companies_name_23  \
# 30700                          -1                          NaN
# 33356                          -1                          NaN
# 42222                          -1                          NaN
# 43644                          -1                          NaN
# 24455                          -1                          NaN
#
#        production_companies_id_24 production_companies_name_24  \
# 30700                          -1                          NaN
# 33356                          -1                          NaN
# 42222                          -1                          NaN
# 43644                          -1                          NaN
# 24455                          -1                          NaN
#
#        production_companies_id_25 production_companies_name_25  \
# 30700                          -1                          NaN
# 33356                          -1                          NaN
# 42222                          -1                          NaN
# 43644                          -1                          NaN
# 24455                          -1                          NaN
#
#       production_countries_iso_3166_1_0 production_countries_name_0  \
# 30700                                US    United States of America
# 33356                                US    United States of America
# 42222                                GB              United Kingdom
# 43644                                GB              United Kingdom
# 24455                                US    United States of America
#
#       production_countries_iso_3166_1_1 production_countries_name_1  \
# 30700                               NaN                         NaN
# 33356                               NaN                         NaN
# 42222                                US    United States of America
# 43644                                US    United States of America
# 24455                               NaN                         NaN
#
#       production_countries_iso_3166_1_2 production_countries_name_2  \
# 30700                               NaN                         NaN
# 33356                               NaN                         NaN
# 42222                               NaN                         NaN
# 43644                               NaN                         NaN
# 24455                               NaN                         NaN
#
#       production_countries_iso_3166_1_3 production_countries_name_3  \
# 30700                               NaN                         NaN
# 33356                               NaN                         NaN
# 42222                               NaN                         NaN
# 43644                               NaN                         NaN
# 24455                               NaN                         NaN
#
#       production_countries_iso_3166_1_4 production_countries_name_4  \
# 30700                               NaN                         NaN
# 33356                               NaN                         NaN
# 42222                               NaN                         NaN
# 43644                               NaN                         NaN
# 24455                               NaN                         NaN
#
#       production_countries_iso_3166_1_5 production_countries_name_5  \
# 30700                               NaN                         NaN
# 33356                               NaN                         NaN
# 42222                               NaN                         NaN
# 43644                               NaN                         NaN
# 24455                               NaN                         NaN
#
#       production_countries_iso_3166_1_6 production_countries_name_6  \
# 30700                               NaN                         NaN
# 33356                               NaN                         NaN
# 42222                               NaN                         NaN
# 43644                               NaN                         NaN
# 24455                               NaN                         NaN
#
#       production_countries_iso_3166_1_7 production_countries_name_7  \
# 30700                               NaN                         NaN
# 33356                               NaN                         NaN
# 42222                               NaN                         NaN
# 43644                               NaN                         NaN
# 24455                               NaN                         NaN
#
#       production_countries_iso_3166_1_8 production_countries_name_8  \
# 30700                               NaN                         NaN
# 33356                               NaN                         NaN
# 42222                               NaN                         NaN
# 43644                               NaN                         NaN
# 24455                               NaN                         NaN
#
#       production_countries_iso_3166_1_9 production_countries_name_9  \
# 30700                               NaN                         NaN
# 33356                               NaN                         NaN
# 42222                               NaN                         NaN
# 43644                               NaN                         NaN
# 24455                               NaN                         NaN
#
#       production_countries_iso_3166_1_10 production_countries_name_10  \
# 30700                                NaN                          NaN
# 33356                                NaN                          NaN
# 42222                                NaN                          NaN
# 43644                                NaN                          NaN
# 24455                                NaN                          NaN
#
#       production_countries_iso_3166_1_11 production_countries_name_11  \
# 30700                                NaN                          NaN
# 33356                                NaN                          NaN
# 42222                                NaN                          NaN
# 43644                                NaN                          NaN
# 24455                                NaN                          NaN
#
#       production_countries_iso_3166_1_12 production_countries_name_12  \
# 30700                                NaN                          NaN
# 33356                                NaN                          NaN
# 42222                                NaN                          NaN
# 43644                                NaN                          NaN
# 24455                                NaN                          NaN
#
#       production_countries_iso_3166_1_13 production_countries_name_13  \
# 30700                                NaN                          NaN
# 33356                                NaN                          NaN
# 42222                                NaN                          NaN
# 43644                                NaN                          NaN
# 24455                                NaN                          NaN
#
#       production_countries_iso_3166_1_14 production_countries_name_14  \
# 30700                                NaN                          NaN
# 33356                                NaN                          NaN
# 42222                                NaN                          NaN
# 43644                                NaN                          NaN
# 24455                                NaN                          NaN
#
#       production_countries_iso_3166_1_15 production_countries_name_15  \
# 30700                                NaN                          NaN
# 33356                                NaN                          NaN
# 42222                                NaN                          NaN
# 43644                                NaN                          NaN
# 24455                                NaN                          NaN
#
#       production_countries_iso_3166_1_16 production_countries_name_16  \
# 30700                                NaN                          NaN
# 33356                                NaN                          NaN
# 42222                                NaN                          NaN
# 43644                                NaN                          NaN
# 24455                                NaN                          NaN
#
#       production_countries_iso_3166_1_17 production_countries_name_17  \
# 30700                                NaN                          NaN
# 33356                                NaN                          NaN
# 42222                                NaN                          NaN
# 43644                                NaN                          NaN
# 24455                                NaN                          NaN
#
#       production_countries_iso_3166_1_18 production_countries_name_18  \
# 30700                                NaN                          NaN
# 33356                                NaN                          NaN
# 42222                                NaN                          NaN
# 43644                                NaN                          NaN
# 24455                                NaN                          NaN
#
#       production_countries_iso_3166_1_19 production_countries_name_19  \
# 30700                                NaN                          NaN
# 33356                                NaN                          NaN
# 42222                                NaN                          NaN
# 43644                                NaN                          NaN
# 24455                                NaN                          NaN
#
#       production_countries_iso_3166_1_20 production_countries_name_20  \
# 30700                                NaN                          NaN
# 33356                                NaN                          NaN
# 42222                                NaN                          NaN
# 43644                                NaN                          NaN
# 24455                                NaN                          NaN
#
#       production_countries_iso_3166_1_21 production_countries_name_21  \
# 30700                                NaN                          NaN
# 33356                                NaN                          NaN
# 42222                                NaN                          NaN
# 43644                                NaN                          NaN
# 24455                                NaN                          NaN
#
#       production_countries_iso_3166_1_22 production_countries_name_22  \
# 30700                                NaN                          NaN
# 33356                                NaN                          NaN
# 42222                                NaN                          NaN
# 43644                                NaN                          NaN
# 24455                                NaN                          NaN
#
#       production_countries_iso_3166_1_23 production_countries_name_23  \
# 30700                                NaN                          NaN
# 33356                                NaN                          NaN
# 42222                                NaN                          NaN
# 43644                                NaN                          NaN
# 24455                                NaN                          NaN
#
#       production_countries_iso_3166_1_24 production_countries_name_24  \
# 30700                                NaN                          NaN
# 33356                                NaN                          NaN
# 42222                                NaN                          NaN
# 43644                                NaN                          NaN
# 24455                                NaN                          NaN
#
#       spoken_languages_iso_639_1_0 spoken_languages_name_0  \
# 30700                           en                 English
# 33356                           de                 Deutsch
# 42222                           en                 English
# 43644                           en                 English
# 24455                           en                 English
#
#       spoken_languages_iso_639_1_1 spoken_languages_name_1  \
# 30700                          NaN                     NaN
# 33356                           en                 English
# 42222                          NaN                     NaN
# 43644                          NaN                     NaN
# 24455                          NaN                     NaN
#
#       spoken_languages_iso_639_1_2 spoken_languages_name_2  \
# 30700                          NaN                     NaN
# 33356                          NaN                     NaN
# 42222                          NaN                     NaN
# 43644                          NaN                     NaN
# 24455                          NaN                     NaN
#
#       spoken_languages_iso_639_1_3 spoken_languages_name_3  \
# 30700                          NaN                     NaN
# 33356                          NaN                     NaN
# 42222                          NaN                     NaN
# 43644                          NaN                     NaN
# 24455                          NaN                     NaN
#
#       spoken_languages_iso_639_1_4 spoken_languages_name_4  \
# 30700                          NaN                     NaN
# 33356                          NaN                     NaN
# 42222                          NaN                     NaN
# 43644                          NaN                     NaN
# 24455                          NaN                     NaN
#
#       spoken_languages_iso_639_1_5 spoken_languages_name_5  \
# 30700                          NaN                     NaN
# 33356                          NaN                     NaN
# 42222                          NaN                     NaN
# 43644                          NaN                     NaN
# 24455                          NaN                     NaN
#
#       spoken_languages_iso_639_1_6 spoken_languages_name_6  \
# 30700                          NaN                     NaN
# 33356                          NaN                     NaN
# 42222                          NaN                     NaN
# 43644                          NaN                     NaN
# 24455                          NaN                     NaN
#
#       spoken_languages_iso_639_1_7 spoken_languages_name_7  \
# 30700                          NaN                     NaN
# 33356                          NaN                     NaN
# 42222                          NaN                     NaN
# 43644                          NaN                     NaN
# 24455                          NaN                     NaN
#
#       spoken_languages_iso_639_1_8 spoken_languages_name_8  \
# 30700                          NaN                     NaN
# 33356                          NaN                     NaN
# 42222                          NaN                     NaN
# 43644                          NaN                     NaN
# 24455                          NaN                     NaN
#
#       spoken_languages_iso_639_1_9 spoken_languages_name_9  \
# 30700                          NaN                     NaN
# 33356                          NaN                     NaN
# 42222                          NaN                     NaN
# 43644                          NaN                     NaN
# 24455                          NaN                     NaN
#
#       spoken_languages_iso_639_1_10 spoken_languages_name_10  \
# 30700                           NaN                      NaN
# 33356                           NaN                      NaN
# 42222                           NaN                      NaN
# 43644                           NaN                      NaN
# 24455                           NaN                      NaN
#
#       spoken_languages_iso_639_1_11 spoken_languages_name_11  \
# 30700                           NaN                      NaN
# 33356                           NaN                      NaN
# 42222                           NaN                      NaN
# 43644                           NaN                      NaN
# 24455                           NaN                      NaN
#
#       spoken_languages_iso_639_1_12 spoken_languages_name_12  \
# 30700                           NaN                      NaN
# 33356                           NaN                      NaN
# 42222                           NaN                      NaN
# 43644                           NaN                      NaN
# 24455                           NaN                      NaN
#
#       spoken_languages_iso_639_1_13 spoken_languages_name_13  \
# 30700                           NaN                      NaN
# 33356                           NaN                      NaN
# 42222                           NaN                      NaN
# 43644                           NaN                      NaN
# 24455                           NaN                      NaN
#
#       spoken_languages_iso_639_1_14 spoken_languages_name_14  \
# 30700                           NaN                      NaN
# 33356                           NaN                      NaN
# 42222                           NaN                      NaN
# 43644                           NaN                      NaN
# 24455                           NaN                      NaN
#
#       spoken_languages_iso_639_1_15 spoken_languages_name_15  \
# 30700                           NaN                      NaN
# 33356                           NaN                      NaN
# 42222                           NaN                      NaN
# 43644                           NaN                      NaN
# 24455                           NaN                      NaN
#
#       spoken_languages_iso_639_1_16 spoken_languages_name_16  \
# 30700                           NaN                      NaN
# 33356                           NaN                      NaN
# 42222                           NaN                      NaN
# 43644                           NaN                      NaN
# 24455                           NaN                      NaN
#
#       spoken_languages_iso_639_1_17 spoken_languages_name_17  \
# 30700                           NaN                      NaN
# 33356                           NaN                      NaN
# 42222                           NaN                      NaN
# 43644                           NaN                      NaN
# 24455                           NaN                      NaN
#
#       spoken_languages_iso_639_1_18 spoken_languages_name_18  release_year  \
# 30700                           NaN                      NaN          2015
# 33356                           NaN                      NaN          2017
# 42222                           NaN                      NaN          2017
# 43644                           NaN                      NaN          2017
# 24455                           NaN                      NaN          2014
#
#        release_month
# 30700              6
# 33356              5
# 42222              3
# 43644              6
# 24455             10

# %%
max_runtime = movies.sort_values('runtime', ascending = False)
max_runtime.head() # actually the runtime is also normal, Centennial is actually a very lengthy miniseries!
# Out:
#        adult  budget      id  imdb_id original_language  \
# 24178      0     0.0   67493    76993                en
# 40938      0     0.0  126820     1087                en
# 19965      1     0.0  142051     2213                en
# 13767      0     0.0   45560    80196                de
# 13953      0     0.0   67463      874                de
#
#                       original_title  popularity  revenue  runtime  \
# 24178                     Centennial    0.664727      0.0   1256.0
# 40938                       Baseball    0.145073      0.0   1140.0
# 19965                           Jazz    1.507756      0.0   1140.0
# 13767          Berlin Alexanderplatz    2.255785      0.0    931.0
# 13953  Heimat: Eine deutsche Chronik    0.016204      0.0    925.0
#
#                                 title  video  vote_average  vote_count  \
# 24178                      Centennial      0           7.9         8.0
# 40938                        Baseball      0           8.5         4.0
# 19965                            Jazz      0           5.7         3.0
# 13767           Berlin Alexanderplatz      0           8.4         5.0
# 13953  Heimat: A Chronicle of Germany      0           9.0         1.0
#
#        belongs_to_collection_id belongs_to_collection_name  genres_id_0  \
# 24178                        -1                        NaN           18
# 40938                        -1                        NaN           99
# 19965                        -1                        NaN           99
# 13767                        -1                        NaN           18
# 13953                        -1                        NaN           18
#
#       genres_name_0  genres_id_1 genres_name_1  genres_id_2 genres_name_2  \
# 24178         Drama           36       History           -1           NaN
# 40938   Documentary           -1           NaN           -1           NaN
# 19965   Documentary           -1           NaN           -1           NaN
# 13767         Drama           -1           NaN           -1           NaN
# 13953         Drama           36       History           -1           NaN
#
#        genres_id_3 genres_name_3  genres_id_4 genres_name_4  genres_id_5  \
# 24178           -1           NaN           -1           NaN           -1
# 40938           -1           NaN           -1           NaN           -1
# 19965           -1           NaN           -1           NaN           -1
# 13767           -1           NaN           -1           NaN           -1
# 13953           -1           NaN           -1           NaN           -1
#
#       genres_name_5  genres_id_6 genres_name_6  genres_id_7 genres_name_7  \
# 24178           NaN           -1           NaN           -1           NaN
# 40938           NaN           -1           NaN           -1           NaN
# 19965           NaN           -1           NaN           -1           NaN
# 13767           NaN           -1           NaN           -1           NaN
# 13953           NaN           -1           NaN           -1           NaN
#
#        production_companies_id_0 production_companies_name_0  \
# 24178                      26727        Universal Television
# 40938                         -1                         NaN
# 19965                         -1                         NaN
# 13767                       1704                Bavaria Film
# 13953                         -1                         NaN
#
#        production_companies_id_1   production_companies_name_1  \
# 24178                         -1                           NaN
# 40938                         -1                           NaN
# 19965                         -1                           NaN
# 13767                       7025  Westdeutscher Rundfunk (WDR)
# 13953                         -1                           NaN
#
#        production_companies_id_2    production_companies_name_2  \
# 24178                         -1                            NaN
# 40938                         -1                            NaN
# 19965                         -1                            NaN
# 13767                      20091  RAI Radiotelevisione Italiana
# 13953                         -1                            NaN
#
#        production_companies_id_3 production_companies_name_3  \
# 24178                         -1                         NaN
# 40938                         -1                         NaN
# 19965                         -1                         NaN
# 13767                         -1                         NaN
# 13953                         -1                         NaN
#
#        production_companies_id_4 production_companies_name_4  \
# 24178                         -1                         NaN
# 40938                         -1                         NaN
# 19965                         -1                         NaN
# 13767                         -1                         NaN
# 13953                         -1                         NaN
#
#        production_companies_id_5 production_companies_name_5  \
# 24178                         -1                         NaN
# 40938                         -1                         NaN
# 19965                         -1                         NaN
# 13767                         -1                         NaN
# 13953                         -1                         NaN
#
#        production_companies_id_6 production_companies_name_6  \
# 24178                         -1                         NaN
# 40938                         -1                         NaN
# 19965                         -1                         NaN
# 13767                         -1                         NaN
# 13953                         -1                         NaN
#
#        production_companies_id_7 production_companies_name_7  \
# 24178                         -1                         NaN
# 40938                         -1                         NaN
# 19965                         -1                         NaN
# 13767                         -1                         NaN
# 13953                         -1                         NaN
#
#        production_companies_id_8 production_companies_name_8  \
# 24178                         -1                         NaN
# 40938                         -1                         NaN
# 19965                         -1                         NaN
# 13767                         -1                         NaN
# 13953                         -1                         NaN
#
#        production_companies_id_9 production_companies_name_9  \
# 24178                         -1                         NaN
# 40938                         -1                         NaN
# 19965                         -1                         NaN
# 13767                         -1                         NaN
# 13953                         -1                         NaN
#
#        production_companies_id_10 production_companies_name_10  \
# 24178                          -1                          NaN
# 40938                          -1                          NaN
# 19965                          -1                          NaN
# 13767                          -1                          NaN
# 13953                          -1                          NaN
#
#        production_companies_id_11 production_companies_name_11  \
# 24178                          -1                          NaN
# 40938                          -1                          NaN
# 19965                          -1                          NaN
# 13767                          -1                          NaN
# 13953                          -1                          NaN
#
#        production_companies_id_12 production_companies_name_12  \
# 24178                          -1                          NaN
# 40938                          -1                          NaN
# 19965                          -1                          NaN
# 13767                          -1                          NaN
# 13953                          -1                          NaN
#
#        production_companies_id_13 production_companies_name_13  \
# 24178                          -1                          NaN
# 40938                          -1                          NaN
# 19965                          -1                          NaN
# 13767                          -1                          NaN
# 13953                          -1                          NaN
#
#        production_companies_id_14 production_companies_name_14  \
# 24178                          -1                          NaN
# 40938                          -1                          NaN
# 19965                          -1                          NaN
# 13767                          -1                          NaN
# 13953                          -1                          NaN
#
#        production_companies_id_15 production_companies_name_15  \
# 24178                          -1                          NaN
# 40938                          -1                          NaN
# 19965                          -1                          NaN
# 13767                          -1                          NaN
# 13953                          -1                          NaN
#
#        production_companies_id_16 production_companies_name_16  \
# 24178                          -1                          NaN
# 40938                          -1                          NaN
# 19965                          -1                          NaN
# 13767                          -1                          NaN
# 13953                          -1                          NaN
#
#        production_companies_id_17 production_companies_name_17  \
# 24178                          -1                          NaN
# 40938                          -1                          NaN
# 19965                          -1                          NaN
# 13767                          -1                          NaN
# 13953                          -1                          NaN
#
#        production_companies_id_18 production_companies_name_18  \
# 24178                          -1                          NaN
# 40938                          -1                          NaN
# 19965                          -1                          NaN
# 13767                          -1                          NaN
# 13953                          -1                          NaN
#
#        production_companies_id_19 production_companies_name_19  \
# 24178                          -1                          NaN
# 40938                          -1                          NaN
# 19965                          -1                          NaN
# 13767                          -1                          NaN
# 13953                          -1                          NaN
#
#        production_companies_id_20 production_companies_name_20  \
# 24178                          -1                          NaN
# 40938                          -1                          NaN
# 19965                          -1                          NaN
# 13767                          -1                          NaN
# 13953                          -1                          NaN
#
#        production_companies_id_21 production_companies_name_21  \
# 24178                          -1                          NaN
# 40938                          -1                          NaN
# 19965                          -1                          NaN
# 13767                          -1                          NaN
# 13953                          -1                          NaN
#
#        production_companies_id_22 production_companies_name_22  \
# 24178                          -1                          NaN
# 40938                          -1                          NaN
# 19965                          -1                          NaN
# 13767                          -1                          NaN
# 13953                          -1                          NaN
#
#        production_companies_id_23 production_companies_name_23  \
# 24178                          -1                          NaN
# 40938                          -1                          NaN
# 19965                          -1                          NaN
# 13767                          -1                          NaN
# 13953                          -1                          NaN
#
#        production_companies_id_24 production_companies_name_24  \
# 24178                          -1                          NaN
# 40938                          -1                          NaN
# 19965                          -1                          NaN
# 13767                          -1                          NaN
# 13953                          -1                          NaN
#
#        production_companies_id_25 production_companies_name_25  \
# 24178                          -1                          NaN
# 40938                          -1                          NaN
# 19965                          -1                          NaN
# 13767                          -1                          NaN
# 13953                          -1                          NaN
#
#       production_countries_iso_3166_1_0 production_countries_name_0  \
# 24178                                US    United States of America
# 40938                               NaN                         NaN
# 19965                               NaN                         NaN
# 13767                                DE                     Germany
# 13953                                DE                     Germany
#
#       production_countries_iso_3166_1_1 production_countries_name_1  \
# 24178                               NaN                         NaN
# 40938                               NaN                         NaN
# 19965                               NaN                         NaN
# 13767                                IT                       Italy
# 13953                               NaN                         NaN
#
#       production_countries_iso_3166_1_2 production_countries_name_2  \
# 24178                               NaN                         NaN
# 40938                               NaN                         NaN
# 19965                               NaN                         NaN
# 13767                               NaN                         NaN
# 13953                               NaN                         NaN
#
#       production_countries_iso_3166_1_3 production_countries_name_3  \
# 24178                               NaN                         NaN
# 40938                               NaN                         NaN
# 19965                               NaN                         NaN
# 13767                               NaN                         NaN
# 13953                               NaN                         NaN
#
#       production_countries_iso_3166_1_4 production_countries_name_4  \
# 24178                               NaN                         NaN
# 40938                               NaN                         NaN
# 19965                               NaN                         NaN
# 13767                               NaN                         NaN
# 13953                               NaN                         NaN
#
#       production_countries_iso_3166_1_5 production_countries_name_5  \
# 24178                               NaN                         NaN
# 40938                               NaN                         NaN
# 19965                               NaN                         NaN
# 13767                               NaN                         NaN
# 13953                               NaN                         NaN
#
#       production_countries_iso_3166_1_6 production_countries_name_6  \
# 24178                               NaN                         NaN
# 40938                               NaN                         NaN
# 19965                               NaN                         NaN
# 13767                               NaN                         NaN
# 13953                               NaN                         NaN
#
#       production_countries_iso_3166_1_7 production_countries_name_7  \
# 24178                               NaN                         NaN
# 40938                               NaN                         NaN
# 19965                               NaN                         NaN
# 13767                               NaN                         NaN
# 13953                               NaN                         NaN
#
#       production_countries_iso_3166_1_8 production_countries_name_8  \
# 24178                               NaN                         NaN
# 40938                               NaN                         NaN
# 19965                               NaN                         NaN
# 13767                               NaN                         NaN
# 13953                               NaN                         NaN
#
#       production_countries_iso_3166_1_9 production_countries_name_9  \
# 24178                               NaN                         NaN
# 40938                               NaN                         NaN
# 19965                               NaN                         NaN
# 13767                               NaN                         NaN
# 13953                               NaN                         NaN
#
#       production_countries_iso_3166_1_10 production_countries_name_10  \
# 24178                                NaN                          NaN
# 40938                                NaN                          NaN
# 19965                                NaN                          NaN
# 13767                                NaN                          NaN
# 13953                                NaN                          NaN
#
#       production_countries_iso_3166_1_11 production_countries_name_11  \
# 24178                                NaN                          NaN
# 40938                                NaN                          NaN
# 19965                                NaN                          NaN
# 13767                                NaN                          NaN
# 13953                                NaN                          NaN
#
#       production_countries_iso_3166_1_12 production_countries_name_12  \
# 24178                                NaN                          NaN
# 40938                                NaN                          NaN
# 19965                                NaN                          NaN
# 13767                                NaN                          NaN
# 13953                                NaN                          NaN
#
#       production_countries_iso_3166_1_13 production_countries_name_13  \
# 24178                                NaN                          NaN
# 40938                                NaN                          NaN
# 19965                                NaN                          NaN
# 13767                                NaN                          NaN
# 13953                                NaN                          NaN
#
#       production_countries_iso_3166_1_14 production_countries_name_14  \
# 24178                                NaN                          NaN
# 40938                                NaN                          NaN
# 19965                                NaN                          NaN
# 13767                                NaN                          NaN
# 13953                                NaN                          NaN
#
#       production_countries_iso_3166_1_15 production_countries_name_15  \
# 24178                                NaN                          NaN
# 40938                                NaN                          NaN
# 19965                                NaN                          NaN
# 13767                                NaN                          NaN
# 13953                                NaN                          NaN
#
#       production_countries_iso_3166_1_16 production_countries_name_16  \
# 24178                                NaN                          NaN
# 40938                                NaN                          NaN
# 19965                                NaN                          NaN
# 13767                                NaN                          NaN
# 13953                                NaN                          NaN
#
#       production_countries_iso_3166_1_17 production_countries_name_17  \
# 24178                                NaN                          NaN
# 40938                                NaN                          NaN
# 19965                                NaN                          NaN
# 13767                                NaN                          NaN
# 13953                                NaN                          NaN
#
#       production_countries_iso_3166_1_18 production_countries_name_18  \
# 24178                                NaN                          NaN
# 40938                                NaN                          NaN
# 19965                                NaN                          NaN
# 13767                                NaN                          NaN
# 13953                                NaN                          NaN
#
#       production_countries_iso_3166_1_19 production_countries_name_19  \
# 24178                                NaN                          NaN
# 40938                                NaN                          NaN
# 19965                                NaN                          NaN
# 13767                                NaN                          NaN
# 13953                                NaN                          NaN
#
#       production_countries_iso_3166_1_20 production_countries_name_20  \
# 24178                                NaN                          NaN
# 40938                                NaN                          NaN
# 19965                                NaN                          NaN
# 13767                                NaN                          NaN
# 13953                                NaN                          NaN
#
#       production_countries_iso_3166_1_21 production_countries_name_21  \
# 24178                                NaN                          NaN
# 40938                                NaN                          NaN
# 19965                                NaN                          NaN
# 13767                                NaN                          NaN
# 13953                                NaN                          NaN
#
#       production_countries_iso_3166_1_22 production_countries_name_22  \
# 24178                                NaN                          NaN
# 40938                                NaN                          NaN
# 19965                                NaN                          NaN
# 13767                                NaN                          NaN
# 13953                                NaN                          NaN
#
#       production_countries_iso_3166_1_23 production_countries_name_23  \
# 24178                                NaN                          NaN
# 40938                                NaN                          NaN
# 19965                                NaN                          NaN
# 13767                                NaN                          NaN
# 13953                                NaN                          NaN
#
#       production_countries_iso_3166_1_24 production_countries_name_24  \
# 24178                                NaN                          NaN
# 40938                                NaN                          NaN
# 19965                                NaN                          NaN
# 13767                                NaN                          NaN
# 13953                                NaN                          NaN
#
#       spoken_languages_iso_639_1_0 spoken_languages_name_0  \
# 24178                          NaN                     NaN
# 40938                           en                 English
# 19965                          NaN                     NaN
# 13767                           de                 Deutsch
# 13953                          NaN                     NaN
#
#       spoken_languages_iso_639_1_1 spoken_languages_name_1  \
# 24178                          NaN                     NaN
# 40938                          NaN                     NaN
# 19965                          NaN                     NaN
# 13767                          NaN                     NaN
# 13953                          NaN                     NaN
#
#       spoken_languages_iso_639_1_2 spoken_languages_name_2  \
# 24178                          NaN                     NaN
# 40938                          NaN                     NaN
# 19965                          NaN                     NaN
# 13767                          NaN                     NaN
# 13953                          NaN                     NaN
#
#       spoken_languages_iso_639_1_3 spoken_languages_name_3  \
# 24178                          NaN                     NaN
# 40938                          NaN                     NaN
# 19965                          NaN                     NaN
# 13767                          NaN                     NaN
# 13953                          NaN                     NaN
#
#       spoken_languages_iso_639_1_4 spoken_languages_name_4  \
# 24178                          NaN                     NaN
# 40938                          NaN                     NaN
# 19965                          NaN                     NaN
# 13767                          NaN                     NaN
# 13953                          NaN                     NaN
#
#       spoken_languages_iso_639_1_5 spoken_languages_name_5  \
# 24178                          NaN                     NaN
# 40938                          NaN                     NaN
# 19965                          NaN                     NaN
# 13767                          NaN                     NaN
# 13953                          NaN                     NaN
#
#       spoken_languages_iso_639_1_6 spoken_languages_name_6  \
# 24178                          NaN                     NaN
# 40938                          NaN                     NaN
# 19965                          NaN                     NaN
# 13767                          NaN                     NaN
# 13953                          NaN                     NaN
#
#       spoken_languages_iso_639_1_7 spoken_languages_name_7  \
# 24178                          NaN                     NaN
# 40938                          NaN                     NaN
# 19965                          NaN                     NaN
# 13767                          NaN                     NaN
# 13953                          NaN                     NaN
#
#       spoken_languages_iso_639_1_8 spoken_languages_name_8  \
# 24178                          NaN                     NaN
# 40938                          NaN                     NaN
# 19965                          NaN                     NaN
# 13767                          NaN                     NaN
# 13953                          NaN                     NaN
#
#       spoken_languages_iso_639_1_9 spoken_languages_name_9  \
# 24178                          NaN                     NaN
# 40938                          NaN                     NaN
# 19965                          NaN                     NaN
# 13767                          NaN                     NaN
# 13953                          NaN                     NaN
#
#       spoken_languages_iso_639_1_10 spoken_languages_name_10  \
# 24178                           NaN                      NaN
# 40938                           NaN                      NaN
# 19965                           NaN                      NaN
# 13767                           NaN                      NaN
# 13953                           NaN                      NaN
#
#       spoken_languages_iso_639_1_11 spoken_languages_name_11  \
# 24178                           NaN                      NaN
# 40938                           NaN                      NaN
# 19965                           NaN                      NaN
# 13767                           NaN                      NaN
# 13953                           NaN                      NaN
#
#       spoken_languages_iso_639_1_12 spoken_languages_name_12  \
# 24178                           NaN                      NaN
# 40938                           NaN                      NaN
# 19965                           NaN                      NaN
# 13767                           NaN                      NaN
# 13953                           NaN                      NaN
#
#       spoken_languages_iso_639_1_13 spoken_languages_name_13  \
# 24178                           NaN                      NaN
# 40938                           NaN                      NaN
# 19965                           NaN                      NaN
# 13767                           NaN                      NaN
# 13953                           NaN                      NaN
#
#       spoken_languages_iso_639_1_14 spoken_languages_name_14  \
# 24178                           NaN                      NaN
# 40938                           NaN                      NaN
# 19965                           NaN                      NaN
# 13767                           NaN                      NaN
# 13953                           NaN                      NaN
#
#       spoken_languages_iso_639_1_15 spoken_languages_name_15  \
# 24178                           NaN                      NaN
# 40938                           NaN                      NaN
# 19965                           NaN                      NaN
# 13767                           NaN                      NaN
# 13953                           NaN                      NaN
#
#       spoken_languages_iso_639_1_16 spoken_languages_name_16  \
# 24178                           NaN                      NaN
# 40938                           NaN                      NaN
# 19965                           NaN                      NaN
# 13767                           NaN                      NaN
# 13953                           NaN                      NaN
#
#       spoken_languages_iso_639_1_17 spoken_languages_name_17  \
# 24178                           NaN                      NaN
# 40938                           NaN                      NaN
# 19965                           NaN                      NaN
# 13767                           NaN                      NaN
# 13953                           NaN                      NaN
#
#       spoken_languages_iso_639_1_18 spoken_languages_name_18  release_year  \
# 24178                           NaN                      NaN          1978
# 40938                           NaN                      NaN          1994
# 19965                           NaN                      NaN          2001
# 13767                           NaN                      NaN          1980
# 13953                           NaN                      NaN          1984
#
#        release_month
# 24178             10
# 40938              9
# 19965              1
# 13767              8
# 13953              9

# %%
max_votecount = movies.sort_values('vote_count', ascending = False)
max_votecount.head() # vote count seems normal as well !
# Out:
#        adult       budget      id  imdb_id original_language   original_title  \
# 15480      0  160000000.0   27205  1375666                en        Inception
# 12481      0  185000000.0     155   468569                en  The Dark Knight
# 14551      0  237000000.0   19995   499549                en           Avatar
# 17818      1  220000000.0   24428   848228                en     The Avengers
# 26564      0   58000000.0  293660  1431045                en         Deadpool
#
#        popularity       revenue  runtime            title  video  \
# 15480   29.108149  8.255328e+08    148.0        Inception      0
# 12481  123.167259  1.004558e+09    152.0  The Dark Knight      0
# 14551  185.070892  2.787965e+09    162.0           Avatar      0
# 17818   89.887648  1.519558e+09    143.0     The Avengers      0
# 26564  187.860492  7.831130e+08    108.0         Deadpool      0
#
#        vote_average  vote_count  belongs_to_collection_id  \
# 15480           8.1     14075.0                        -1
# 12481           8.3     12269.0                       263
# 14551           7.2     12114.0                     87096
# 17818           7.4     12000.0                     86311
# 26564           7.4     11444.0                    448150
#
#        belongs_to_collection_name  genres_id_0    genres_name_0  genres_id_1  \
# 15480                         NaN           28           Action           53
# 12481  The Dark Knight Collection           18            Drama           28
# 14551           Avatar Collection           28           Action           12
# 17818     The Avengers Collection          878  Science Fiction           28
# 26564         Deadpool Collection           28           Action           12
#
#       genres_name_1  genres_id_2    genres_name_2  genres_id_3  \
# 15480      Thriller          878  Science Fiction         9648
# 12481        Action           80            Crime           53
# 14551     Adventure           14          Fantasy          878
# 17818        Action           12        Adventure           -1
# 26564     Adventure           35           Comedy           -1
#
#          genres_name_3  genres_id_4 genres_name_4  genres_id_5 genres_name_5  \
# 15480          Mystery           12     Adventure           -1           NaN
# 12481         Thriller           -1           NaN           -1           NaN
# 14551  Science Fiction           -1           NaN           -1           NaN
# 17818              NaN           -1           NaN           -1           NaN
# 26564              NaN           -1           NaN           -1           NaN
#
#        genres_id_6 genres_name_6  genres_id_7 genres_name_7  \
# 15480           -1           NaN           -1           NaN
# 12481           -1           NaN           -1           NaN
# 14551           -1           NaN           -1           NaN
# 17818           -1           NaN           -1           NaN
# 26564           -1           NaN           -1           NaN
#
#        production_companies_id_0             production_companies_name_0  \
# 15480                        923                      Legendary Pictures
# 12481                        429                               DC Comics
# 14551                        289                 Ingenious Film Partners
# 17818                          4                      Paramount Pictures
# 26564                        306  Twentieth Century Fox Film Corporation
#
#        production_companies_id_1             production_companies_name_1  \
# 15480                       6194                            Warner Bros.
# 12481                        923                      Legendary Pictures
# 14551                        306  Twentieth Century Fox Film Corporation
# 17818                        420                          Marvel Studios
# 26564                       7505                    Marvel Entertainment
#
#        production_companies_id_2 production_companies_name_2  \
# 15480                       9996                     Syncopy
# 12481                       6194                Warner Bros.
# 14551                        444          Dune Entertainment
# 17818                         -1                         NaN
# 26564                      11307        The Donners' Company
#
#        production_companies_id_3 production_companies_name_3  \
# 15480                         -1                         NaN
# 12481                       9993            DC Entertainment
# 14551                        574    Lightstorm Entertainment
# 17818                         -1                         NaN
# 26564                      22213           TSG Entertainment
#
#        production_companies_id_4 production_companies_name_4  \
# 15480                         -1                         NaN
# 12481                       9996                     Syncopy
# 14551                         -1                         NaN
# 17818                         -1                         NaN
# 26564                      78091               Kinberg Genre
#
#        production_companies_id_5 production_companies_name_5  \
# 15480                         -1                         NaN
# 12481                         -1                         NaN
# 14551                         -1                         NaN
# 17818                         -1                         NaN
# 26564                         -1                         NaN
#
#        production_companies_id_6 production_companies_name_6  \
# 15480                         -1                         NaN
# 12481                         -1                         NaN
# 14551                         -1                         NaN
# 17818                         -1                         NaN
# 26564                         -1                         NaN
#
#        production_companies_id_7 production_companies_name_7  \
# 15480                         -1                         NaN
# 12481                         -1                         NaN
# 14551                         -1                         NaN
# 17818                         -1                         NaN
# 26564                         -1                         NaN
#
#        production_companies_id_8 production_companies_name_8  \
# 15480                         -1                         NaN
# 12481                         -1                         NaN
# 14551                         -1                         NaN
# 17818                         -1                         NaN
# 26564                         -1                         NaN
#
#        production_companies_id_9 production_companies_name_9  \
# 15480                         -1                         NaN
# 12481                         -1                         NaN
# 14551                         -1                         NaN
# 17818                         -1                         NaN
# 26564                         -1                         NaN
#
#        production_companies_id_10 production_companies_name_10  \
# 15480                          -1                          NaN
# 12481                          -1                          NaN
# 14551                          -1                          NaN
# 17818                          -1                          NaN
# 26564                          -1                          NaN
#
#        production_companies_id_11 production_companies_name_11  \
# 15480                          -1                          NaN
# 12481                          -1                          NaN
# 14551                          -1                          NaN
# 17818                          -1                          NaN
# 26564                          -1                          NaN
#
#        production_companies_id_12 production_companies_name_12  \
# 15480                          -1                          NaN
# 12481                          -1                          NaN
# 14551                          -1                          NaN
# 17818                          -1                          NaN
# 26564                          -1                          NaN
#
#        production_companies_id_13 production_companies_name_13  \
# 15480                          -1                          NaN
# 12481                          -1                          NaN
# 14551                          -1                          NaN
# 17818                          -1                          NaN
# 26564                          -1                          NaN
#
#        production_companies_id_14 production_companies_name_14  \
# 15480                          -1                          NaN
# 12481                          -1                          NaN
# 14551                          -1                          NaN
# 17818                          -1                          NaN
# 26564                          -1                          NaN
#
#        production_companies_id_15 production_companies_name_15  \
# 15480                          -1                          NaN
# 12481                          -1                          NaN
# 14551                          -1                          NaN
# 17818                          -1                          NaN
# 26564                          -1                          NaN
#
#        production_companies_id_16 production_companies_name_16  \
# 15480                          -1                          NaN
# 12481                          -1                          NaN
# 14551                          -1                          NaN
# 17818                          -1                          NaN
# 26564                          -1                          NaN
#
#        production_companies_id_17 production_companies_name_17  \
# 15480                          -1                          NaN
# 12481                          -1                          NaN
# 14551                          -1                          NaN
# 17818                          -1                          NaN
# 26564                          -1                          NaN
#
#        production_companies_id_18 production_companies_name_18  \
# 15480                          -1                          NaN
# 12481                          -1                          NaN
# 14551                          -1                          NaN
# 17818                          -1                          NaN
# 26564                          -1                          NaN
#
#        production_companies_id_19 production_companies_name_19  \
# 15480                          -1                          NaN
# 12481                          -1                          NaN
# 14551                          -1                          NaN
# 17818                          -1                          NaN
# 26564                          -1                          NaN
#
#        production_companies_id_20 production_companies_name_20  \
# 15480                          -1                          NaN
# 12481                          -1                          NaN
# 14551                          -1                          NaN
# 17818                          -1                          NaN
# 26564                          -1                          NaN
#
#        production_companies_id_21 production_companies_name_21  \
# 15480                          -1                          NaN
# 12481                          -1                          NaN
# 14551                          -1                          NaN
# 17818                          -1                          NaN
# 26564                          -1                          NaN
#
#        production_companies_id_22 production_companies_name_22  \
# 15480                          -1                          NaN
# 12481                          -1                          NaN
# 14551                          -1                          NaN
# 17818                          -1                          NaN
# 26564                          -1                          NaN
#
#        production_companies_id_23 production_companies_name_23  \
# 15480                          -1                          NaN
# 12481                          -1                          NaN
# 14551                          -1                          NaN
# 17818                          -1                          NaN
# 26564                          -1                          NaN
#
#        production_companies_id_24 production_companies_name_24  \
# 15480                          -1                          NaN
# 12481                          -1                          NaN
# 14551                          -1                          NaN
# 17818                          -1                          NaN
# 26564                          -1                          NaN
#
#        production_companies_id_25 production_companies_name_25  \
# 15480                          -1                          NaN
# 12481                          -1                          NaN
# 14551                          -1                          NaN
# 17818                          -1                          NaN
# 26564                          -1                          NaN
#
#       production_countries_iso_3166_1_0 production_countries_name_0  \
# 15480                                GB              United Kingdom
# 12481                                GB              United Kingdom
# 14551                                US    United States of America
# 17818                                US    United States of America
# 26564                                US    United States of America
#
#       production_countries_iso_3166_1_1 production_countries_name_1  \
# 15480                                US    United States of America
# 12481                                US    United States of America
# 14551                                GB              United Kingdom
# 17818                               NaN                         NaN
# 26564                               NaN                         NaN
#
#       production_countries_iso_3166_1_2 production_countries_name_2  \
# 15480                               NaN                         NaN
# 12481                               NaN                         NaN
# 14551                               NaN                         NaN
# 17818                               NaN                         NaN
# 26564                               NaN                         NaN
#
#       production_countries_iso_3166_1_3 production_countries_name_3  \
# 15480                               NaN                         NaN
# 12481                               NaN                         NaN
# 14551                               NaN                         NaN
# 17818                               NaN                         NaN
# 26564                               NaN                         NaN
#
#       production_countries_iso_3166_1_4 production_countries_name_4  \
# 15480                               NaN                         NaN
# 12481                               NaN                         NaN
# 14551                               NaN                         NaN
# 17818                               NaN                         NaN
# 26564                               NaN                         NaN
#
#       production_countries_iso_3166_1_5 production_countries_name_5  \
# 15480                               NaN                         NaN
# 12481                               NaN                         NaN
# 14551                               NaN                         NaN
# 17818                               NaN                         NaN
# 26564                               NaN                         NaN
#
#       production_countries_iso_3166_1_6 production_countries_name_6  \
# 15480                               NaN                         NaN
# 12481                               NaN                         NaN
# 14551                               NaN                         NaN
# 17818                               NaN                         NaN
# 26564                               NaN                         NaN
#
#       production_countries_iso_3166_1_7 production_countries_name_7  \
# 15480                               NaN                         NaN
# 12481                               NaN                         NaN
# 14551                               NaN                         NaN
# 17818                               NaN                         NaN
# 26564                               NaN                         NaN
#
#       production_countries_iso_3166_1_8 production_countries_name_8  \
# 15480                               NaN                         NaN
# 12481                               NaN                         NaN
# 14551                               NaN                         NaN
# 17818                               NaN                         NaN
# 26564                               NaN                         NaN
#
#       production_countries_iso_3166_1_9 production_countries_name_9  \
# 15480                               NaN                         NaN
# 12481                               NaN                         NaN
# 14551                               NaN                         NaN
# 17818                               NaN                         NaN
# 26564                               NaN                         NaN
#
#       production_countries_iso_3166_1_10 production_countries_name_10  \
# 15480                                NaN                          NaN
# 12481                                NaN                          NaN
# 14551                                NaN                          NaN
# 17818                                NaN                          NaN
# 26564                                NaN                          NaN
#
#       production_countries_iso_3166_1_11 production_countries_name_11  \
# 15480                                NaN                          NaN
# 12481                                NaN                          NaN
# 14551                                NaN                          NaN
# 17818                                NaN                          NaN
# 26564                                NaN                          NaN
#
#       production_countries_iso_3166_1_12 production_countries_name_12  \
# 15480                                NaN                          NaN
# 12481                                NaN                          NaN
# 14551                                NaN                          NaN
# 17818                                NaN                          NaN
# 26564                                NaN                          NaN
#
#       production_countries_iso_3166_1_13 production_countries_name_13  \
# 15480                                NaN                          NaN
# 12481                                NaN                          NaN
# 14551                                NaN                          NaN
# 17818                                NaN                          NaN
# 26564                                NaN                          NaN
#
#       production_countries_iso_3166_1_14 production_countries_name_14  \
# 15480                                NaN                          NaN
# 12481                                NaN                          NaN
# 14551                                NaN                          NaN
# 17818                                NaN                          NaN
# 26564                                NaN                          NaN
#
#       production_countries_iso_3166_1_15 production_countries_name_15  \
# 15480                                NaN                          NaN
# 12481                                NaN                          NaN
# 14551                                NaN                          NaN
# 17818                                NaN                          NaN
# 26564                                NaN                          NaN
#
#       production_countries_iso_3166_1_16 production_countries_name_16  \
# 15480                                NaN                          NaN
# 12481                                NaN                          NaN
# 14551                                NaN                          NaN
# 17818                                NaN                          NaN
# 26564                                NaN                          NaN
#
#       production_countries_iso_3166_1_17 production_countries_name_17  \
# 15480                                NaN                          NaN
# 12481                                NaN                          NaN
# 14551                                NaN                          NaN
# 17818                                NaN                          NaN
# 26564                                NaN                          NaN
#
#       production_countries_iso_3166_1_18 production_countries_name_18  \
# 15480                                NaN                          NaN
# 12481                                NaN                          NaN
# 14551                                NaN                          NaN
# 17818                                NaN                          NaN
# 26564                                NaN                          NaN
#
#       production_countries_iso_3166_1_19 production_countries_name_19  \
# 15480                                NaN                          NaN
# 12481                                NaN                          NaN
# 14551                                NaN                          NaN
# 17818                                NaN                          NaN
# 26564                                NaN                          NaN
#
#       production_countries_iso_3166_1_20 production_countries_name_20  \
# 15480                                NaN                          NaN
# 12481                                NaN                          NaN
# 14551                                NaN                          NaN
# 17818                                NaN                          NaN
# 26564                                NaN                          NaN
#
#       production_countries_iso_3166_1_21 production_countries_name_21  \
# 15480                                NaN                          NaN
# 12481                                NaN                          NaN
# 14551                                NaN                          NaN
# 17818                                NaN                          NaN
# 26564                                NaN                          NaN
#
#       production_countries_iso_3166_1_22 production_countries_name_22  \
# 15480                                NaN                          NaN
# 12481                                NaN                          NaN
# 14551                                NaN                          NaN
# 17818                                NaN                          NaN
# 26564                                NaN                          NaN
#
#       production_countries_iso_3166_1_23 production_countries_name_23  \
# 15480                                NaN                          NaN
# 12481                                NaN                          NaN
# 14551                                NaN                          NaN
# 17818                                NaN                          NaN
# 26564                                NaN                          NaN
#
#       production_countries_iso_3166_1_24 production_countries_name_24  \
# 15480                                NaN                          NaN
# 12481                                NaN                          NaN
# 14551                                NaN                          NaN
# 17818                                NaN                          NaN
# 26564                                NaN                          NaN
#
#       spoken_languages_iso_639_1_0 spoken_languages_name_0  \
# 15480                           en                 English
# 12481                           en                 English
# 14551                           en                 English
# 17818                           en                 English
# 26564                           en                 English
#
#       spoken_languages_iso_639_1_1 spoken_languages_name_1  \
# 15480                          NaN                     NaN
# 12481                           zh                     普通话
# 14551                           es                 Español
# 17818                          NaN                     NaN
# 26564                          NaN                     NaN
#
#       spoken_languages_iso_639_1_2 spoken_languages_name_2  \
# 15480                          NaN                     NaN
# 12481                          NaN                     NaN
# 14551                          NaN                     NaN
# 17818                          NaN                     NaN
# 26564                          NaN                     NaN
#
#       spoken_languages_iso_639_1_3 spoken_languages_name_3  \
# 15480                          NaN                     NaN
# 12481                          NaN                     NaN
# 14551                          NaN                     NaN
# 17818                          NaN                     NaN
# 26564                          NaN                     NaN
#
#       spoken_languages_iso_639_1_4 spoken_languages_name_4  \
# 15480                          NaN                     NaN
# 12481                          NaN                     NaN
# 14551                          NaN                     NaN
# 17818                          NaN                     NaN
# 26564                          NaN                     NaN
#
#       spoken_languages_iso_639_1_5 spoken_languages_name_5  \
# 15480                          NaN                     NaN
# 12481                          NaN                     NaN
# 14551                          NaN                     NaN
# 17818                          NaN                     NaN
# 26564                          NaN                     NaN
#
#       spoken_languages_iso_639_1_6 spoken_languages_name_6  \
# 15480                          NaN                     NaN
# 12481                          NaN                     NaN
# 14551                          NaN                     NaN
# 17818                          NaN                     NaN
# 26564                          NaN                     NaN
#
#       spoken_languages_iso_639_1_7 spoken_languages_name_7  \
# 15480                          NaN                     NaN
# 12481                          NaN                     NaN
# 14551                          NaN                     NaN
# 17818                          NaN                     NaN
# 26564                          NaN                     NaN
#
#       spoken_languages_iso_639_1_8 spoken_languages_name_8  \
# 15480                          NaN                     NaN
# 12481                          NaN                     NaN
# 14551                          NaN                     NaN
# 17818                          NaN                     NaN
# 26564                          NaN                     NaN
#
#       spoken_languages_iso_639_1_9 spoken_languages_name_9  \
# 15480                          NaN                     NaN
# 12481                          NaN                     NaN
# 14551                          NaN                     NaN
# 17818                          NaN                     NaN
# 26564                          NaN                     NaN
#
#       spoken_languages_iso_639_1_10 spoken_languages_name_10  \
# 15480                           NaN                      NaN
# 12481                           NaN                      NaN
# 14551                           NaN                      NaN
# 17818                           NaN                      NaN
# 26564                           NaN                      NaN
#
#       spoken_languages_iso_639_1_11 spoken_languages_name_11  \
# 15480                           NaN                      NaN
# 12481                           NaN                      NaN
# 14551                           NaN                      NaN
# 17818                           NaN                      NaN
# 26564                           NaN                      NaN
#
#       spoken_languages_iso_639_1_12 spoken_languages_name_12  \
# 15480                           NaN                      NaN
# 12481                           NaN                      NaN
# 14551                           NaN                      NaN
# 17818                           NaN                      NaN
# 26564                           NaN                      NaN
#
#       spoken_languages_iso_639_1_13 spoken_languages_name_13  \
# 15480                           NaN                      NaN
# 12481                           NaN                      NaN
# 14551                           NaN                      NaN
# 17818                           NaN                      NaN
# 26564                           NaN                      NaN
#
#       spoken_languages_iso_639_1_14 spoken_languages_name_14  \
# 15480                           NaN                      NaN
# 12481                           NaN                      NaN
# 14551                           NaN                      NaN
# 17818                           NaN                      NaN
# 26564                           NaN                      NaN
#
#       spoken_languages_iso_639_1_15 spoken_languages_name_15  \
# 15480                           NaN                      NaN
# 12481                           NaN                      NaN
# 14551                           NaN                      NaN
# 17818                           NaN                      NaN
# 26564                           NaN                      NaN
#
#       spoken_languages_iso_639_1_16 spoken_languages_name_16  \
# 15480                           NaN                      NaN
# 12481                           NaN                      NaN
# 14551                           NaN                      NaN
# 17818                           NaN                      NaN
# 26564                           NaN                      NaN
#
#       spoken_languages_iso_639_1_17 spoken_languages_name_17  \
# 15480                           NaN                      NaN
# 12481                           NaN                      NaN
# 14551                           NaN                      NaN
# 17818                           NaN                      NaN
# 26564                           NaN                      NaN
#
#       spoken_languages_iso_639_1_18 spoken_languages_name_18  release_year  \
# 15480                           NaN                      NaN          2010
# 12481                           NaN                      NaN          2008
# 14551                           NaN                      NaN          2009
# 17818                           NaN                      NaN          2012
# 26564                           NaN                      NaN          2016
#
#        release_month
# 15480              7
# 12481              7
# 14551             12
# 17818              4
# 26564              2

# %% [markdown]
# <font size="3">Unusual data: Release year seems normal with first movie to be present in 1874 according to our dataset. Moreover, release months are pretty well distributed (there is no sign that one period is more favorable to release a movie). Adult is between 0 and 1. Vote average seems to range from 0 to 10. Highest budget seems normal. According to Wikipedia, the most expensive movie produced was Pirates of the Caribbean: On Stranger Tides. This coincides with our dataset.</font>

# %%
max_budget = movies.sort_values('budget', ascending = False)
max_budget.head()
# Out:
#        adult       budget     id  imdb_id original_language  \
# 17124      1  380000000.0   1865   129865                en
# 11827      0  300000000.0    285   449088                en
# 26558      0  280000000.0  99861  2395427                en
# 11067      0  270000000.0   1452    34815                en
# 16130      0  260000000.0  38757   398286                en
#
#                                     original_title  popularity       revenue  \
# 17124  Pirates of the Caribbean: On Stranger Tides   27.887720  1.045714e+09
# 11827     Pirates of the Caribbean: At World's End   31.363664  9.610000e+08
# 26558                      Avengers: Age of Ultron   37.379420  1.405404e+09
# 11067                             Superman Returns   13.284712  3.910812e+08
# 16130                                      Tangled   14.684761  5.917949e+08
#
#        runtime                                        title  video  \
# 17124    136.0  Pirates of the Caribbean: On Stranger Tides      0
# 11827    169.0     Pirates of the Caribbean: At World's End      0
# 26558    141.0                      Avengers: Age of Ultron      0
# 11067    154.0                             Superman Returns      0
# 16130    100.0                                      Tangled      0
#
#        vote_average  vote_count  belongs_to_collection_id  \
# 17124           6.4      5068.0                       295
# 11827           6.9      4627.0                       295
# 26558           7.3      6908.0                     86311
# 11067           5.4      1429.0                      8537
# 16130           7.4      3419.0                    463959
#
#                 belongs_to_collection_name  genres_id_0 genres_name_0  \
# 17124  Pirates of the Caribbean Collection           12     Adventure
# 11827  Pirates of the Caribbean Collection           12     Adventure
# 26558              The Avengers Collection           28        Action
# 11067                  Superman Collection           12     Adventure
# 16130                   Tangled Collection           16     Animation
#
#        genres_id_1 genres_name_1  genres_id_2    genres_name_2  genres_id_3  \
# 17124           28        Action           14          Fantasy           -1
# 11827           14       Fantasy           28           Action           -1
# 26558           12     Adventure          878  Science Fiction           -1
# 11067           14       Fantasy           28           Action          878
# 16130        10751        Family           -1              NaN           -1
#
#          genres_name_3  genres_id_4 genres_name_4  genres_id_5 genres_name_5  \
# 17124              NaN           -1           NaN           -1           NaN
# 11827              NaN           -1           NaN           -1           NaN
# 26558              NaN           -1           NaN           -1           NaN
# 11067  Science Fiction           -1           NaN           -1           NaN
# 16130              NaN           -1           NaN           -1           NaN
#
#        genres_id_6 genres_name_6  genres_id_7 genres_name_7  \
# 17124           -1           NaN           -1           NaN
# 11827           -1           NaN           -1           NaN
# 26558           -1           NaN           -1           NaN
# 11067           -1           NaN           -1           NaN
# 16130           -1           NaN           -1           NaN
#
#        production_companies_id_0 production_companies_name_0  \
# 17124                          2        Walt Disney Pictures
# 11827                          2        Walt Disney Pictures
# 26558                        420              Marvel Studios
# 11067                        429                   DC Comics
# 16130                          2        Walt Disney Pictures
#
#        production_companies_id_1    production_companies_name_1  \
# 17124                        130        Jerry Bruckheimer Films
# 11827                        130        Jerry Bruckheimer Films
# 26558                      15357                    Prime Focus
# 11067                        923             Legendary Pictures
# 16130                       6125  Walt Disney Animation Studios
#
#        production_companies_id_2   production_companies_name_2  \
# 17124                      20478  Moving Picture Company (MPC)
# 11827                      19936       Second Mate Productions
# 26558                      76043        Revolution Sun Studios
# 11067                       6194                  Warner Bros.
# 16130                         -1                           NaN
#
#        production_companies_id_3 production_companies_name_3  \
# 17124                         -1                         NaN
# 11827                         -1                         NaN
# 26558                         -1                         NaN
# 11067                       9168   Bad Hat Harry Productions
# 16130                         -1                         NaN
#
#        production_companies_id_4 production_companies_name_4  \
# 17124                         -1                         NaN
# 11827                         -1                         NaN
# 26558                         -1                         NaN
# 11067                         -1                         NaN
# 16130                         -1                         NaN
#
#        production_companies_id_5 production_companies_name_5  \
# 17124                         -1                         NaN
# 11827                         -1                         NaN
# 26558                         -1                         NaN
# 11067                         -1                         NaN
# 16130                         -1                         NaN
#
#        production_companies_id_6 production_companies_name_6  \
# 17124                         -1                         NaN
# 11827                         -1                         NaN
# 26558                         -1                         NaN
# 11067                         -1                         NaN
# 16130                         -1                         NaN
#
#        production_companies_id_7 production_companies_name_7  \
# 17124                         -1                         NaN
# 11827                         -1                         NaN
# 26558                         -1                         NaN
# 11067                         -1                         NaN
# 16130                         -1                         NaN
#
#        production_companies_id_8 production_companies_name_8  \
# 17124                         -1                         NaN
# 11827                         -1                         NaN
# 26558                         -1                         NaN
# 11067                         -1                         NaN
# 16130                         -1                         NaN
#
#        production_companies_id_9 production_companies_name_9  \
# 17124                         -1                         NaN
# 11827                         -1                         NaN
# 26558                         -1                         NaN
# 11067                         -1                         NaN
# 16130                         -1                         NaN
#
#        production_companies_id_10 production_companies_name_10  \
# 17124                          -1                          NaN
# 11827                          -1                          NaN
# 26558                          -1                          NaN
# 11067                          -1                          NaN
# 16130                          -1                          NaN
#
#        production_companies_id_11 production_companies_name_11  \
# 17124                          -1                          NaN
# 11827                          -1                          NaN
# 26558                          -1                          NaN
# 11067                          -1                          NaN
# 16130                          -1                          NaN
#
#        production_companies_id_12 production_companies_name_12  \
# 17124                          -1                          NaN
# 11827                          -1                          NaN
# 26558                          -1                          NaN
# 11067                          -1                          NaN
# 16130                          -1                          NaN
#
#        production_companies_id_13 production_companies_name_13  \
# 17124                          -1                          NaN
# 11827                          -1                          NaN
# 26558                          -1                          NaN
# 11067                          -1                          NaN
# 16130                          -1                          NaN
#
#        production_companies_id_14 production_companies_name_14  \
# 17124                          -1                          NaN
# 11827                          -1                          NaN
# 26558                          -1                          NaN
# 11067                          -1                          NaN
# 16130                          -1                          NaN
#
#        production_companies_id_15 production_companies_name_15  \
# 17124                          -1                          NaN
# 11827                          -1                          NaN
# 26558                          -1                          NaN
# 11067                          -1                          NaN
# 16130                          -1                          NaN
#
#        production_companies_id_16 production_companies_name_16  \
# 17124                          -1                          NaN
# 11827                          -1                          NaN
# 26558                          -1                          NaN
# 11067                          -1                          NaN
# 16130                          -1                          NaN
#
#        production_companies_id_17 production_companies_name_17  \
# 17124                          -1                          NaN
# 11827                          -1                          NaN
# 26558                          -1                          NaN
# 11067                          -1                          NaN
# 16130                          -1                          NaN
#
#        production_companies_id_18 production_companies_name_18  \
# 17124                          -1                          NaN
# 11827                          -1                          NaN
# 26558                          -1                          NaN
# 11067                          -1                          NaN
# 16130                          -1                          NaN
#
#        production_companies_id_19 production_companies_name_19  \
# 17124                          -1                          NaN
# 11827                          -1                          NaN
# 26558                          -1                          NaN
# 11067                          -1                          NaN
# 16130                          -1                          NaN
#
#        production_companies_id_20 production_companies_name_20  \
# 17124                          -1                          NaN
# 11827                          -1                          NaN
# 26558                          -1                          NaN
# 11067                          -1                          NaN
# 16130                          -1                          NaN
#
#        production_companies_id_21 production_companies_name_21  \
# 17124                          -1                          NaN
# 11827                          -1                          NaN
# 26558                          -1                          NaN
# 11067                          -1                          NaN
# 16130                          -1                          NaN
#
#        production_companies_id_22 production_companies_name_22  \
# 17124                          -1                          NaN
# 11827                          -1                          NaN
# 26558                          -1                          NaN
# 11067                          -1                          NaN
# 16130                          -1                          NaN
#
#        production_companies_id_23 production_companies_name_23  \
# 17124                          -1                          NaN
# 11827                          -1                          NaN
# 26558                          -1                          NaN
# 11067                          -1                          NaN
# 16130                          -1                          NaN
#
#        production_companies_id_24 production_companies_name_24  \
# 17124                          -1                          NaN
# 11827                          -1                          NaN
# 26558                          -1                          NaN
# 11067                          -1                          NaN
# 16130                          -1                          NaN
#
#        production_companies_id_25 production_companies_name_25  \
# 17124                          -1                          NaN
# 11827                          -1                          NaN
# 26558                          -1                          NaN
# 11067                          -1                          NaN
# 16130                          -1                          NaN
#
#       production_countries_iso_3166_1_0 production_countries_name_0  \
# 17124                                US    United States of America
# 11827                                US    United States of America
# 26558                                US    United States of America
# 11067                                US    United States of America
# 16130                                US    United States of America
#
#       production_countries_iso_3166_1_1 production_countries_name_1  \
# 17124                               NaN                         NaN
# 11827                               NaN                         NaN
# 26558                               NaN                         NaN
# 11067                               NaN                         NaN
# 16130                               NaN                         NaN
#
#       production_countries_iso_3166_1_2 production_countries_name_2  \
# 17124                               NaN                         NaN
# 11827                               NaN                         NaN
# 26558                               NaN                         NaN
# 11067                               NaN                         NaN
# 16130                               NaN                         NaN
#
#       production_countries_iso_3166_1_3 production_countries_name_3  \
# 17124                               NaN                         NaN
# 11827                               NaN                         NaN
# 26558                               NaN                         NaN
# 11067                               NaN                         NaN
# 16130                               NaN                         NaN
#
#       production_countries_iso_3166_1_4 production_countries_name_4  \
# 17124                               NaN                         NaN
# 11827                               NaN                         NaN
# 26558                               NaN                         NaN
# 11067                               NaN                         NaN
# 16130                               NaN                         NaN
#
#       production_countries_iso_3166_1_5 production_countries_name_5  \
# 17124                               NaN                         NaN
# 11827                               NaN                         NaN
# 26558                               NaN                         NaN
# 11067                               NaN                         NaN
# 16130                               NaN                         NaN
#
#       production_countries_iso_3166_1_6 production_countries_name_6  \
# 17124                               NaN                         NaN
# 11827                               NaN                         NaN
# 26558                               NaN                         NaN
# 11067                               NaN                         NaN
# 16130                               NaN                         NaN
#
#       production_countries_iso_3166_1_7 production_countries_name_7  \
# 17124                               NaN                         NaN
# 11827                               NaN                         NaN
# 26558                               NaN                         NaN
# 11067                               NaN                         NaN
# 16130                               NaN                         NaN
#
#       production_countries_iso_3166_1_8 production_countries_name_8  \
# 17124                               NaN                         NaN
# 11827                               NaN                         NaN
# 26558                               NaN                         NaN
# 11067                               NaN                         NaN
# 16130                               NaN                         NaN
#
#       production_countries_iso_3166_1_9 production_countries_name_9  \
# 17124                               NaN                         NaN
# 11827                               NaN                         NaN
# 26558                               NaN                         NaN
# 11067                               NaN                         NaN
# 16130                               NaN                         NaN
#
#       production_countries_iso_3166_1_10 production_countries_name_10  \
# 17124                                NaN                          NaN
# 11827                                NaN                          NaN
# 26558                                NaN                          NaN
# 11067                                NaN                          NaN
# 16130                                NaN                          NaN
#
#       production_countries_iso_3166_1_11 production_countries_name_11  \
# 17124                                NaN                          NaN
# 11827                                NaN                          NaN
# 26558                                NaN                          NaN
# 11067                                NaN                          NaN
# 16130                                NaN                          NaN
#
#       production_countries_iso_3166_1_12 production_countries_name_12  \
# 17124                                NaN                          NaN
# 11827                                NaN                          NaN
# 26558                                NaN                          NaN
# 11067                                NaN                          NaN
# 16130                                NaN                          NaN
#
#       production_countries_iso_3166_1_13 production_countries_name_13  \
# 17124                                NaN                          NaN
# 11827                                NaN                          NaN
# 26558                                NaN                          NaN
# 11067                                NaN                          NaN
# 16130                                NaN                          NaN
#
#       production_countries_iso_3166_1_14 production_countries_name_14  \
# 17124                                NaN                          NaN
# 11827                                NaN                          NaN
# 26558                                NaN                          NaN
# 11067                                NaN                          NaN
# 16130                                NaN                          NaN
#
#       production_countries_iso_3166_1_15 production_countries_name_15  \
# 17124                                NaN                          NaN
# 11827                                NaN                          NaN
# 26558                                NaN                          NaN
# 11067                                NaN                          NaN
# 16130                                NaN                          NaN
#
#       production_countries_iso_3166_1_16 production_countries_name_16  \
# 17124                                NaN                          NaN
# 11827                                NaN                          NaN
# 26558                                NaN                          NaN
# 11067                                NaN                          NaN
# 16130                                NaN                          NaN
#
#       production_countries_iso_3166_1_17 production_countries_name_17  \
# 17124                                NaN                          NaN
# 11827                                NaN                          NaN
# 26558                                NaN                          NaN
# 11067                                NaN                          NaN
# 16130                                NaN                          NaN
#
#       production_countries_iso_3166_1_18 production_countries_name_18  \
# 17124                                NaN                          NaN
# 11827                                NaN                          NaN
# 26558                                NaN                          NaN
# 11067                                NaN                          NaN
# 16130                                NaN                          NaN
#
#       production_countries_iso_3166_1_19 production_countries_name_19  \
# 17124                                NaN                          NaN
# 11827                                NaN                          NaN
# 26558                                NaN                          NaN
# 11067                                NaN                          NaN
# 16130                                NaN                          NaN
#
#       production_countries_iso_3166_1_20 production_countries_name_20  \
# 17124                                NaN                          NaN
# 11827                                NaN                          NaN
# 26558                                NaN                          NaN
# 11067                                NaN                          NaN
# 16130                                NaN                          NaN
#
#       production_countries_iso_3166_1_21 production_countries_name_21  \
# 17124                                NaN                          NaN
# 11827                                NaN                          NaN
# 26558                                NaN                          NaN
# 11067                                NaN                          NaN
# 16130                                NaN                          NaN
#
#       production_countries_iso_3166_1_22 production_countries_name_22  \
# 17124                                NaN                          NaN
# 11827                                NaN                          NaN
# 26558                                NaN                          NaN
# 11067                                NaN                          NaN
# 16130                                NaN                          NaN
#
#       production_countries_iso_3166_1_23 production_countries_name_23  \
# 17124                                NaN                          NaN
# 11827                                NaN                          NaN
# 26558                                NaN                          NaN
# 11067                                NaN                          NaN
# 16130                                NaN                          NaN
#
#       production_countries_iso_3166_1_24 production_countries_name_24  \
# 17124                                NaN                          NaN
# 11827                                NaN                          NaN
# 26558                                NaN                          NaN
# 11067                                NaN                          NaN
# 16130                                NaN                          NaN
#
#       spoken_languages_iso_639_1_0 spoken_languages_name_0  \
# 17124                           en                 English
# 11827                           en                 English
# 26558                           en                 English
# 11067                           en                 English
# 16130                           en                 English
#
#       spoken_languages_iso_639_1_1 spoken_languages_name_1  \
# 17124                           es                 Español
# 11827                          NaN                     NaN
# 26558                          NaN                     NaN
# 11067                           fr                Français
# 16130                          NaN                     NaN
#
#       spoken_languages_iso_639_1_2 spoken_languages_name_2  \
# 17124                          NaN                     NaN
# 11827                          NaN                     NaN
# 26558                          NaN                     NaN
# 11067                           de                 Deutsch
# 16130                          NaN                     NaN
#
#       spoken_languages_iso_639_1_3 spoken_languages_name_3  \
# 17124                          NaN                     NaN
# 11827                          NaN                     NaN
# 26558                          NaN                     NaN
# 11067                          NaN                     NaN
# 16130                          NaN                     NaN
#
#       spoken_languages_iso_639_1_4 spoken_languages_name_4  \
# 17124                          NaN                     NaN
# 11827                          NaN                     NaN
# 26558                          NaN                     NaN
# 11067                          NaN                     NaN
# 16130                          NaN                     NaN
#
#       spoken_languages_iso_639_1_5 spoken_languages_name_5  \
# 17124                          NaN                     NaN
# 11827                          NaN                     NaN
# 26558                          NaN                     NaN
# 11067                          NaN                     NaN
# 16130                          NaN                     NaN
#
#       spoken_languages_iso_639_1_6 spoken_languages_name_6  \
# 17124                          NaN                     NaN
# 11827                          NaN                     NaN
# 26558                          NaN                     NaN
# 11067                          NaN                     NaN
# 16130                          NaN                     NaN
#
#       spoken_languages_iso_639_1_7 spoken_languages_name_7  \
# 17124                          NaN                     NaN
# 11827                          NaN                     NaN
# 26558                          NaN                     NaN
# 11067                          NaN                     NaN
# 16130                          NaN                     NaN
#
#       spoken_languages_iso_639_1_8 spoken_languages_name_8  \
# 17124                          NaN                     NaN
# 11827                          NaN                     NaN
# 26558                          NaN                     NaN
# 11067                          NaN                     NaN
# 16130                          NaN                     NaN
#
#       spoken_languages_iso_639_1_9 spoken_languages_name_9  \
# 17124                          NaN                     NaN
# 11827                          NaN                     NaN
# 26558                          NaN                     NaN
# 11067                          NaN                     NaN
# 16130                          NaN                     NaN
#
#       spoken_languages_iso_639_1_10 spoken_languages_name_10  \
# 17124                           NaN                      NaN
# 11827                           NaN                      NaN
# 26558                           NaN                      NaN
# 11067                           NaN                      NaN
# 16130                           NaN                      NaN
#
#       spoken_languages_iso_639_1_11 spoken_languages_name_11  \
# 17124                           NaN                      NaN
# 11827                           NaN                      NaN
# 26558                           NaN                      NaN
# 11067                           NaN                      NaN
# 16130                           NaN                      NaN
#
#       spoken_languages_iso_639_1_12 spoken_languages_name_12  \
# 17124                           NaN                      NaN
# 11827                           NaN                      NaN
# 26558                           NaN                      NaN
# 11067                           NaN                      NaN
# 16130                           NaN                      NaN
#
#       spoken_languages_iso_639_1_13 spoken_languages_name_13  \
# 17124                           NaN                      NaN
# 11827                           NaN                      NaN
# 26558                           NaN                      NaN
# 11067                           NaN                      NaN
# 16130                           NaN                      NaN
#
#       spoken_languages_iso_639_1_14 spoken_languages_name_14  \
# 17124                           NaN                      NaN
# 11827                           NaN                      NaN
# 26558                           NaN                      NaN
# 11067                           NaN                      NaN
# 16130                           NaN                      NaN
#
#       spoken_languages_iso_639_1_15 spoken_languages_name_15  \
# 17124                           NaN                      NaN
# 11827                           NaN                      NaN
# 26558                           NaN                      NaN
# 11067                           NaN                      NaN
# 16130                           NaN                      NaN
#
#       spoken_languages_iso_639_1_16 spoken_languages_name_16  \
# 17124                           NaN                      NaN
# 11827                           NaN                      NaN
# 26558                           NaN                      NaN
# 11067                           NaN                      NaN
# 16130                           NaN                      NaN
#
#       spoken_languages_iso_639_1_17 spoken_languages_name_17  \
# 17124                           NaN                      NaN
# 11827                           NaN                      NaN
# 26558                           NaN                      NaN
# 11067                           NaN                      NaN
# 16130                           NaN                      NaN
#
#       spoken_languages_iso_639_1_18 spoken_languages_name_18  release_year  \
# 17124                           NaN                      NaN          2011
# 11827                           NaN                      NaN          2007
# 26558                           NaN                      NaN          2015
# 11067                           NaN                      NaN          2006
# 16130                           NaN                      NaN          2010
#
#        release_month
# 17124              5
# 11827              5
# 26558              4
# 11067              6
# 16130             11

# %%
max_revenue = movies.sort_values('revenue', ascending = False)
max_revenue.head() # seems normal as well, Avatar, Start Wars, and Titanic are the movies with the most revenue
# as of whatever year this dataset was released. Today, the highest-grossing movie is The Avengers and not Avatar 
# anymore.
# Out:
#        adult       budget      id  imdb_id original_language  \
# 14551      0  237000000.0   19995   499549                en
# 26555      0  245000000.0  140607  2488496                en
# 1639       0  200000000.0     597   120338                en
# 17818      1  220000000.0   24428   848228                en
# 25084      0  150000000.0  135397    36961                en
#
#                      original_title  popularity       revenue  runtime  \
# 14551                        Avatar  185.070892  2.787965e+09    162.0
# 26555  Star Wars: The Force Awakens   31.626013  2.068224e+09    136.0
# 1639                        Titanic   26.889070  1.845034e+09    194.0
# 17818                  The Avengers   89.887648  1.519558e+09    143.0
# 25084                Jurassic World   32.790475  1.513529e+09    124.0
#
#                               title  video  vote_average  vote_count  \
# 14551                        Avatar      0           7.2     12114.0
# 26555  Star Wars: The Force Awakens      0           7.5      7993.0
# 1639                        Titanic      0           7.5      7770.0
# 17818                  The Avengers      0           7.4     12000.0
# 25084                Jurassic World      0           6.5      8842.0
#
#        belongs_to_collection_id belongs_to_collection_name  genres_id_0  \
# 14551                     87096          Avatar Collection           28
# 26555                        10       Star Wars Collection           28
# 1639                         -1                        NaN           18
# 17818                     86311    The Avengers Collection          878
# 25084                       328   Jurassic Park Collection           28
#
#          genres_name_0  genres_id_1 genres_name_1  genres_id_2  \
# 14551           Action           12     Adventure           14
# 26555           Action           12     Adventure          878
# 1639             Drama        10749       Romance           53
# 17818  Science Fiction           28        Action           12
# 25084           Action           12     Adventure          878
#
#          genres_name_2  genres_id_3    genres_name_3  genres_id_4  \
# 14551          Fantasy          878  Science Fiction           -1
# 26555  Science Fiction           14          Fantasy           -1
# 1639          Thriller           -1              NaN           -1
# 17818        Adventure           -1              NaN           -1
# 25084  Science Fiction           53         Thriller           -1
#
#       genres_name_4  genres_id_5 genres_name_5  genres_id_6 genres_name_6  \
# 14551           NaN           -1           NaN           -1           NaN
# 26555           NaN           -1           NaN           -1           NaN
# 1639            NaN           -1           NaN           -1           NaN
# 17818           NaN           -1           NaN           -1           NaN
# 25084           NaN           -1           NaN           -1           NaN
#
#        genres_id_7 genres_name_7  production_companies_id_0  \
# 14551           -1           NaN                        289
# 26555           -1           NaN                          1
# 1639            -1           NaN                          4
# 17818           -1           NaN                          4
# 25084           -1           NaN                         13
#
#       production_companies_name_0  production_companies_id_1  \
# 14551     Ingenious Film Partners                        306
# 26555                   Lucasfilm                       1634
# 1639           Paramount Pictures                        306
# 17818          Paramount Pictures                        420
# 25084           Universal Studios                         56
#
#                   production_companies_name_1  production_companies_id_2  \
# 14551  Twentieth Century Fox Film Corporation                        444
# 26555                   Truenorth Productions                      11461
# 1639   Twentieth Century Fox Film Corporation                        574
# 17818                          Marvel Studios                         -1
# 25084                    Amblin Entertainment                        923
#
#       production_companies_name_2  production_companies_id_3  \
# 14551          Dune Entertainment                        574
# 26555                   Bad Robot                         -1
# 1639     Lightstorm Entertainment                         -1
# 17818                         NaN                         -1
# 25084          Legendary Pictures                       3341
#
#       production_companies_name_3  production_companies_id_4  \
# 14551    Lightstorm Entertainment                         -1
# 26555                         NaN                         -1
# 1639                          NaN                         -1
# 17818                         NaN                         -1
# 25084     Fuji Television Network                       6452
#
#       production_companies_name_4  production_companies_id_5  \
# 14551                         NaN                         -1
# 26555                         NaN                         -1
# 1639                          NaN                         -1
# 17818                         NaN                         -1
# 25084                      Dentsu                         -1
#
#       production_companies_name_5  production_companies_id_6  \
# 14551                         NaN                         -1
# 26555                         NaN                         -1
# 1639                          NaN                         -1
# 17818                         NaN                         -1
# 25084                         NaN                         -1
#
#       production_companies_name_6  production_companies_id_7  \
# 14551                         NaN                         -1
# 26555                         NaN                         -1
# 1639                          NaN                         -1
# 17818                         NaN                         -1
# 25084                         NaN                         -1
#
#       production_companies_name_7  production_companies_id_8  \
# 14551                         NaN                         -1
# 26555                         NaN                         -1
# 1639                          NaN                         -1
# 17818                         NaN                         -1
# 25084                         NaN                         -1
#
#       production_companies_name_8  production_companies_id_9  \
# 14551                         NaN                         -1
# 26555                         NaN                         -1
# 1639                          NaN                         -1
# 17818                         NaN                         -1
# 25084                         NaN                         -1
#
#       production_companies_name_9  production_companies_id_10  \
# 14551                         NaN                          -1
# 26555                         NaN                          -1
# 1639                          NaN                          -1
# 17818                         NaN                          -1
# 25084                         NaN                          -1
#
#       production_companies_name_10  production_companies_id_11  \
# 14551                          NaN                          -1
# 26555                          NaN                          -1
# 1639                           NaN                          -1
# 17818                          NaN                          -1
# 25084                          NaN                          -1
#
#       production_companies_name_11  production_companies_id_12  \
# 14551                          NaN                          -1
# 26555                          NaN                          -1
# 1639                           NaN                          -1
# 17818                          NaN                          -1
# 25084                          NaN                          -1
#
#       production_companies_name_12  production_companies_id_13  \
# 14551                          NaN                          -1
# 26555                          NaN                          -1
# 1639                           NaN                          -1
# 17818                          NaN                          -1
# 25084                          NaN                          -1
#
#       production_companies_name_13  production_companies_id_14  \
# 14551                          NaN                          -1
# 26555                          NaN                          -1
# 1639                           NaN                          -1
# 17818                          NaN                          -1
# 25084                          NaN                          -1
#
#       production_companies_name_14  production_companies_id_15  \
# 14551                          NaN                          -1
# 26555                          NaN                          -1
# 1639                           NaN                          -1
# 17818                          NaN                          -1
# 25084                          NaN                          -1
#
#       production_companies_name_15  production_companies_id_16  \
# 14551                          NaN                          -1
# 26555                          NaN                          -1
# 1639                           NaN                          -1
# 17818                          NaN                          -1
# 25084                          NaN                          -1
#
#       production_companies_name_16  production_companies_id_17  \
# 14551                          NaN                          -1
# 26555                          NaN                          -1
# 1639                           NaN                          -1
# 17818                          NaN                          -1
# 25084                          NaN                          -1
#
#       production_companies_name_17  production_companies_id_18  \
# 14551                          NaN                          -1
# 26555                          NaN                          -1
# 1639                           NaN                          -1
# 17818                          NaN                          -1
# 25084                          NaN                          -1
#
#       production_companies_name_18  production_companies_id_19  \
# 14551                          NaN                          -1
# 26555                          NaN                          -1
# 1639                           NaN                          -1
# 17818                          NaN                          -1
# 25084                          NaN                          -1
#
#       production_companies_name_19  production_companies_id_20  \
# 14551                          NaN                          -1
# 26555                          NaN                          -1
# 1639                           NaN                          -1
# 17818                          NaN                          -1
# 25084                          NaN                          -1
#
#       production_companies_name_20  production_companies_id_21  \
# 14551                          NaN                          -1
# 26555                          NaN                          -1
# 1639                           NaN                          -1
# 17818                          NaN                          -1
# 25084                          NaN                          -1
#
#       production_companies_name_21  production_companies_id_22  \
# 14551                          NaN                          -1
# 26555                          NaN                          -1
# 1639                           NaN                          -1
# 17818                          NaN                          -1
# 25084                          NaN                          -1
#
#       production_companies_name_22  production_companies_id_23  \
# 14551                          NaN                          -1
# 26555                          NaN                          -1
# 1639                           NaN                          -1
# 17818                          NaN                          -1
# 25084                          NaN                          -1
#
#       production_companies_name_23  production_companies_id_24  \
# 14551                          NaN                          -1
# 26555                          NaN                          -1
# 1639                           NaN                          -1
# 17818                          NaN                          -1
# 25084                          NaN                          -1
#
#       production_companies_name_24  production_companies_id_25  \
# 14551                          NaN                          -1
# 26555                          NaN                          -1
# 1639                           NaN                          -1
# 17818                          NaN                          -1
# 25084                          NaN                          -1
#
#       production_companies_name_25 production_countries_iso_3166_1_0  \
# 14551                          NaN                                US
# 26555                          NaN                                US
# 1639                           NaN                                US
# 17818                          NaN                                US
# 25084                          NaN                                US
#
#       production_countries_name_0 production_countries_iso_3166_1_1  \
# 14551    United States of America                                GB
# 26555    United States of America                               NaN
# 1639     United States of America                               NaN
# 17818    United States of America                               NaN
# 25084    United States of America                               NaN
#
#       production_countries_name_1 production_countries_iso_3166_1_2  \
# 14551              United Kingdom                               NaN
# 26555                         NaN                               NaN
# 1639                          NaN                               NaN
# 17818                         NaN                               NaN
# 25084                         NaN                               NaN
#
#       production_countries_name_2 production_countries_iso_3166_1_3  \
# 14551                         NaN                               NaN
# 26555                         NaN                               NaN
# 1639                          NaN                               NaN
# 17818                         NaN                               NaN
# 25084                         NaN                               NaN
#
#       production_countries_name_3 production_countries_iso_3166_1_4  \
# 14551                         NaN                               NaN
# 26555                         NaN                               NaN
# 1639                          NaN                               NaN
# 17818                         NaN                               NaN
# 25084                         NaN                               NaN
#
#       production_countries_name_4 production_countries_iso_3166_1_5  \
# 14551                         NaN                               NaN
# 26555                         NaN                               NaN
# 1639                          NaN                               NaN
# 17818                         NaN                               NaN
# 25084                         NaN                               NaN
#
#       production_countries_name_5 production_countries_iso_3166_1_6  \
# 14551                         NaN                               NaN
# 26555                         NaN                               NaN
# 1639                          NaN                               NaN
# 17818                         NaN                               NaN
# 25084                         NaN                               NaN
#
#       production_countries_name_6 production_countries_iso_3166_1_7  \
# 14551                         NaN                               NaN
# 26555                         NaN                               NaN
# 1639                          NaN                               NaN
# 17818                         NaN                               NaN
# 25084                         NaN                               NaN
#
#       production_countries_name_7 production_countries_iso_3166_1_8  \
# 14551                         NaN                               NaN
# 26555                         NaN                               NaN
# 1639                          NaN                               NaN
# 17818                         NaN                               NaN
# 25084                         NaN                               NaN
#
#       production_countries_name_8 production_countries_iso_3166_1_9  \
# 14551                         NaN                               NaN
# 26555                         NaN                               NaN
# 1639                          NaN                               NaN
# 17818                         NaN                               NaN
# 25084                         NaN                               NaN
#
#       production_countries_name_9 production_countries_iso_3166_1_10  \
# 14551                         NaN                                NaN
# 26555                         NaN                                NaN
# 1639                          NaN                                NaN
# 17818                         NaN                                NaN
# 25084                         NaN                                NaN
#
#       production_countries_name_10 production_countries_iso_3166_1_11  \
# 14551                          NaN                                NaN
# 26555                          NaN                                NaN
# 1639                           NaN                                NaN
# 17818                          NaN                                NaN
# 25084                          NaN                                NaN
#
#       production_countries_name_11 production_countries_iso_3166_1_12  \
# 14551                          NaN                                NaN
# 26555                          NaN                                NaN
# 1639                           NaN                                NaN
# 17818                          NaN                                NaN
# 25084                          NaN                                NaN
#
#       production_countries_name_12 production_countries_iso_3166_1_13  \
# 14551                          NaN                                NaN
# 26555                          NaN                                NaN
# 1639                           NaN                                NaN
# 17818                          NaN                                NaN
# 25084                          NaN                                NaN
#
#       production_countries_name_13 production_countries_iso_3166_1_14  \
# 14551                          NaN                                NaN
# 26555                          NaN                                NaN
# 1639                           NaN                                NaN
# 17818                          NaN                                NaN
# 25084                          NaN                                NaN
#
#       production_countries_name_14 production_countries_iso_3166_1_15  \
# 14551                          NaN                                NaN
# 26555                          NaN                                NaN
# 1639                           NaN                                NaN
# 17818                          NaN                                NaN
# 25084                          NaN                                NaN
#
#       production_countries_name_15 production_countries_iso_3166_1_16  \
# 14551                          NaN                                NaN
# 26555                          NaN                                NaN
# 1639                           NaN                                NaN
# 17818                          NaN                                NaN
# 25084                          NaN                                NaN
#
#       production_countries_name_16 production_countries_iso_3166_1_17  \
# 14551                          NaN                                NaN
# 26555                          NaN                                NaN
# 1639                           NaN                                NaN
# 17818                          NaN                                NaN
# 25084                          NaN                                NaN
#
#       production_countries_name_17 production_countries_iso_3166_1_18  \
# 14551                          NaN                                NaN
# 26555                          NaN                                NaN
# 1639                           NaN                                NaN
# 17818                          NaN                                NaN
# 25084                          NaN                                NaN
#
#       production_countries_name_18 production_countries_iso_3166_1_19  \
# 14551                          NaN                                NaN
# 26555                          NaN                                NaN
# 1639                           NaN                                NaN
# 17818                          NaN                                NaN
# 25084                          NaN                                NaN
#
#       production_countries_name_19 production_countries_iso_3166_1_20  \
# 14551                          NaN                                NaN
# 26555                          NaN                                NaN
# 1639                           NaN                                NaN
# 17818                          NaN                                NaN
# 25084                          NaN                                NaN
#
#       production_countries_name_20 production_countries_iso_3166_1_21  \
# 14551                          NaN                                NaN
# 26555                          NaN                                NaN
# 1639                           NaN                                NaN
# 17818                          NaN                                NaN
# 25084                          NaN                                NaN
#
#       production_countries_name_21 production_countries_iso_3166_1_22  \
# 14551                          NaN                                NaN
# 26555                          NaN                                NaN
# 1639                           NaN                                NaN
# 17818                          NaN                                NaN
# 25084                          NaN                                NaN
#
#       production_countries_name_22 production_countries_iso_3166_1_23  \
# 14551                          NaN                                NaN
# 26555                          NaN                                NaN
# 1639                           NaN                                NaN
# 17818                          NaN                                NaN
# 25084                          NaN                                NaN
#
#       production_countries_name_23 production_countries_iso_3166_1_24  \
# 14551                          NaN                                NaN
# 26555                          NaN                                NaN
# 1639                           NaN                                NaN
# 17818                          NaN                                NaN
# 25084                          NaN                                NaN
#
#       production_countries_name_24 spoken_languages_iso_639_1_0  \
# 14551                          NaN                           en
# 26555                          NaN                           en
# 1639                           NaN                           en
# 17818                          NaN                           en
# 25084                          NaN                           en
#
#       spoken_languages_name_0 spoken_languages_iso_639_1_1  \
# 14551                 English                           es
# 26555                 English                          NaN
# 1639                  English                           fr
# 17818                 English                          NaN
# 25084                 English                          NaN
#
#       spoken_languages_name_1 spoken_languages_iso_639_1_2  \
# 14551                 Español                          NaN
# 26555                     NaN                          NaN
# 1639                 Français                           de
# 17818                     NaN                          NaN
# 25084                     NaN                          NaN
#
#       spoken_languages_name_2 spoken_languages_iso_639_1_3  \
# 14551                     NaN                          NaN
# 26555                     NaN                          NaN
# 1639                  Deutsch                           sv
# 17818                     NaN                          NaN
# 25084                     NaN                          NaN
#
#       spoken_languages_name_3 spoken_languages_iso_639_1_4  \
# 14551                     NaN                          NaN
# 26555                     NaN                          NaN
# 1639                  svenska                           it
# 17818                     NaN                          NaN
# 25084                     NaN                          NaN
#
#       spoken_languages_name_4 spoken_languages_iso_639_1_5  \
# 14551                     NaN                          NaN
# 26555                     NaN                          NaN
# 1639                 Italiano                           ru
# 17818                     NaN                          NaN
# 25084                     NaN                          NaN
#
#       spoken_languages_name_5 spoken_languages_iso_639_1_6  \
# 14551                     NaN                          NaN
# 26555                     NaN                          NaN
# 1639                  Pусский                          NaN
# 17818                     NaN                          NaN
# 25084                     NaN                          NaN
#
#       spoken_languages_name_6 spoken_languages_iso_639_1_7  \
# 14551                     NaN                          NaN
# 26555                     NaN                          NaN
# 1639                      NaN                          NaN
# 17818                     NaN                          NaN
# 25084                     NaN                          NaN
#
#       spoken_languages_name_7 spoken_languages_iso_639_1_8  \
# 14551                     NaN                          NaN
# 26555                     NaN                          NaN
# 1639                      NaN                          NaN
# 17818                     NaN                          NaN
# 25084                     NaN                          NaN
#
#       spoken_languages_name_8 spoken_languages_iso_639_1_9  \
# 14551                     NaN                          NaN
# 26555                     NaN                          NaN
# 1639                      NaN                          NaN
# 17818                     NaN                          NaN
# 25084                     NaN                          NaN
#
#       spoken_languages_name_9 spoken_languages_iso_639_1_10  \
# 14551                     NaN                           NaN
# 26555                     NaN                           NaN
# 1639                      NaN                           NaN
# 17818                     NaN                           NaN
# 25084                     NaN                           NaN
#
#       spoken_languages_name_10 spoken_languages_iso_639_1_11  \
# 14551                      NaN                           NaN
# 26555                      NaN                           NaN
# 1639                       NaN                           NaN
# 17818                      NaN                           NaN
# 25084                      NaN                           NaN
#
#       spoken_languages_name_11 spoken_languages_iso_639_1_12  \
# 14551                      NaN                           NaN
# 26555                      NaN                           NaN
# 1639                       NaN                           NaN
# 17818                      NaN                           NaN
# 25084                      NaN                           NaN
#
#       spoken_languages_name_12 spoken_languages_iso_639_1_13  \
# 14551                      NaN                           NaN
# 26555                      NaN                           NaN
# 1639                       NaN                           NaN
# 17818                      NaN                           NaN
# 25084                      NaN                           NaN
#
#       spoken_languages_name_13 spoken_languages_iso_639_1_14  \
# 14551                      NaN                           NaN
# 26555                      NaN                           NaN
# 1639                       NaN                           NaN
# 17818                      NaN                           NaN
# 25084                      NaN                           NaN
#
#       spoken_languages_name_14 spoken_languages_iso_639_1_15  \
# 14551                      NaN                           NaN
# 26555                      NaN                           NaN
# 1639                       NaN                           NaN
# 17818                      NaN                           NaN
# 25084                      NaN                           NaN
#
#       spoken_languages_name_15 spoken_languages_iso_639_1_16  \
# 14551                      NaN                           NaN
# 26555                      NaN                           NaN
# 1639                       NaN                           NaN
# 17818                      NaN                           NaN
# 25084                      NaN                           NaN
#
#       spoken_languages_name_16 spoken_languages_iso_639_1_17  \
# 14551                      NaN                           NaN
# 26555                      NaN                           NaN
# 1639                       NaN                           NaN
# 17818                      NaN                           NaN
# 25084                      NaN                           NaN
#
#       spoken_languages_name_17 spoken_languages_iso_639_1_18  \
# 14551                      NaN                           NaN
# 26555                      NaN                           NaN
# 1639                       NaN                           NaN
# 17818                      NaN                           NaN
# 25084                      NaN                           NaN
#
#       spoken_languages_name_18  release_year  release_month
# 14551                      NaN          2009             12
# 26555                      NaN          2015             12
# 1639                       NaN          1997             11
# 17818                      NaN          2012              4
# 25084                      NaN          2015              6

# %% [markdown]
# ## Analysis of genres

# %%
# we can drop the id of genres and re-econde later
genres_id = movies.filter(regex = 'genres_id_.*')
movies = movies.drop(columns = genres_id.columns)

# %%
# identify movies without a genre
nulls = movies.filter(regex = 'genres_name_.*').isnull().sum(axis = 0)
print('There are {} movies without a genre. Can we can drop them.?'.format(nulls[0]))
# movies = movies[movies['genres_name_0'].notna()]
# Out:
# There are 2260 movies without a genre. Can we can drop them.?

# %%
# let's see how many genres movies have on average
genres_name = movies.filter(regex = 'genres_name_.*')
avg_genres = genres_name.count(axis = 1).mean()
print('Number of genres on average over all movies: {}'.format(avg_genres))
# Out:
# Number of genres on average over all movies: 2.014590699547957

# %%
# we identify all possible values for genres
genres_name = movies.filter(regex = 'genres_name_.*')
genres_name_stacked = genres_name.stack().reset_index(drop = True)
genres_name_unique = genres_name_stacked.drop_duplicates().reset_index(drop = True)
display(pd.DataFrame(genres_name_unique).T)
print('There are {} different genres'.format(len(genres_name_unique)))
# Out:
#            0       1       2          3        4        5      6       7  \
# 0  Animation  Comedy  Family  Adventure  Fantasy  Romance  Drama  Action
#
#        8         9      10       11               12       13   14       15  \
# 0  Crime  Thriller  Horror  History  Science Fiction  Mystery  War  Foreign
#
#       16           17       18        19
# 0  Music  Documentary  Western  TV Movie
# There are 20 different genres

# %%
# distribution of genres
genres_name_stacked.value_counts()
# Out:
# Drama              20017
# Comedy             12991
# Thriller            7560
# Romance             6654
# Action              6536
# Horror              4633
# Crime               4276
# Documentary         3849
# Adventure           3467
# Science Fiction     3006
# Family              2730
# Mystery             2451
# Fantasy             2283
# Animation           1909
# Music               1587
# Foreign             1587
# History             1388
# War                 1314
# Western             1037
# TV Movie             749
# dtype: int64

# %%
fig, ax = plt.subplots(figsize = (16, 6))
genres_palette = sns.color_palette('cubehelix', len(genres_name_unique))
g = sns.countplot(genres_name_stacked, ax = ax, order = genres_name_stacked.value_counts().index,
                 palette = genres_palette)
ax.set(xlabel = 'Genres', ylabel = 'Number of occurences among all movies')
ax.set_title('Movies Genre distribution')
_ = plt.xticks(rotation = 45)

# %%
# we add a column of genres per movie as a weight, the more the movie has popular genres, the higher 
# the weighted value (in terms of genres) of the movie
# compute weights
genres_weight = genres_name_stacked.value_counts(normalize = True)
genres_name_weighted = genres_name.replace(genres_weight)
movies['genres_weight'] = genres_name_weighted.sum(axis = 1)

# %%
# we also add column with number of genres for each movie
genres_name = movies.filter(regex = 'genres_name_.*')
movies['genres_num'] = genres_name.count(axis = 1)
for i, c in movies['genres_num'].value_counts().sort_index().iteritems():
    print('{} movies have {} genres'.format(c, i))
# some nice plot
fig, ax = plt.subplots(figsize = (12, 6))
_ = sns.countplot(movies['genres_num'], 
                  palette = sns.color_palette("Blues", len(movies['genres_num'].value_counts())))
_ = ax.set(xlabel = 'Number of genres', ylabel = 'Movies count')
_ = ax.set_title('Count of movies vs. number of genres')
# Out:
# 2260 movies have 0 genres
# 14257 movies have 1 genres
# 14322 movies have 2 genres
# 9487 movies have 3 genres
# 3349 movies have 4 genres
# 830 movies have 5 genres
# 154 movies have 6 genres
# 24 movies have 7 genres
# 3 movies have 8 genres

# %%
# plot some data on genres
fig, ax = plt.subplots(figsize = (16, 6))
genres_name_year = movies.filter(regex = '(genres_name_.*)|release_year') 
genres_name = movies.filter(regex = 'genres_name_.*')
for i, genre in enumerate(genres_name_stacked.value_counts().index):
    temp = genres_name_year[(genres_name_year[genres_name.columns] == genre).any(axis = 1)]
    ax.hist(temp['release_year'], 120, stacked = True, color = genres_palette[i], label = genre,
            range = (temp['release_year'].min(), temp['release_year'].max()))
_ = plt.legend()
_ = ax.set_xlabel('Releas year')
_ = ax.set_ylabel('Genre occurences')
_ = ax.set_title('Genre distribution by release year')

# %% [markdown]
# <font size="3">We observe that all genres have gained popularity over the years except maybe War and Western genres which have decreased and had a peak of popularity after World War 2. We also see that movies production has increased in the past years.</font>

# %% [markdown]
# ## Analysis of production companies

# %%
# we can drop the id of production companies and re-econde later
company_id = movies.filter(regex = 'production_companies_id_.*')
movies = movies.drop(columns = company_id.columns)

# %%
# identify movies without a production company
nulls = movies.filter(regex = 'production_companies_name_.*').isnull().sum(axis = 0)
print('There are {} movies without a production company. Can we drop them?'.format(nulls[0]))
# Out:
# There are 11403 movies without a production company. Can we drop them?

# %%
# let's see how many production companies movies have on average
company_name = movies.filter(regex = 'production_companies_name_.*')
avg_company = company_name.count(axis = 1).mean()
print('Number of production companies on average over all movies: {}'.format(avg_company))
# Out:
# Number of production companies on average over all movies: 1.5649420400125318

# %%
# we identify all possible values for production companies
company_name = movies.filter(regex = 'production_companies_name_.*')
company_name_stacked = company_name.stack().reset_index(drop = True)
company_name_unique = company_name_stacked.drop_duplicates().reset_index(drop = True)
print('There are {} different production companies!'.format(len(company_name_unique)))
# Out:
# There are 23361 different production companies!

# %%
# get most popular production companies
num_most_popular = 30
print('{} most popular production companies (values: produced films)'.format(num_most_popular))
pd.DataFrame(company_name_stacked.value_counts()[:num_most_popular])
# Out:
# 30 most popular production companies (values: produced films)
#                                                 0
# Warner Bros.                                 1247
# Metro-Goldwyn-Mayer (MGM)                    1075
# Paramount Pictures                            997
# Twentieth Century Fox Film Corporation        834
# Universal Pictures                            827
# Columbia Pictures Corporation                 447
# Canal+                                        435
# Columbia Pictures                             429
# RKO Radio Pictures                            290
# United Artists                                276
# New Line Cinema                               276
# Walt Disney Pictures                          262
# Touchstone Pictures                           224
# TriStar Pictures                              197
# Mosfilm                                       185
# Miramax Films                                 183
# France 2 Cinéma                               166
# Centre National de la Cinématographie (CNC)   161
# Toho Company                                  142
# BBC Films                                     130
# Gaumont                                       124
# StudioCanal                                   121
# Relativity Media                              119
# British Broadcasting Corporation (BBC)        116
# Walt Disney Productions                       116
# TF1 Films Production                          115
# Orion Pictures                                111
# Village Roadshow Pictures                     106
# Regency Enterprises                           105
# Universal International Pictures (UI)          97

# %% [markdown]
# <font size="3">We see that some companies appear two times (Walt Disney Productions and Walt Disney Pictures). Is this a rebranding factor or really two studios? Moreover, we saw that Pixar Animation Studios appeared in the beginning of the EDA. They are now a subsidiary of Walt Disney Studios and were part of Lucas Film in the past (which is also now part of Walt Disney). We do not have more information on how production companies are counted for each movie over time.</font>

# %%
# plot some data on production companies (change company index)
fig, ax = plt.subplots(figsize = (16, 6))
company_index = 0
this_company = company_name_stacked.value_counts().index[0]
genres_company = movies.filter(regex = '(genres_name_.*)|(production_companies_name_.*)')
company_name = movies.filter(regex = 'production_companies_name_.*')
genres_name = movies.filter(regex = 'genres_name_.*')
genres_this_company = genres_company[(genres_company[company_name.columns] == this_company).any(axis = 1)]
genres_this_company = genres_this_company[genres_name.columns]
genres_count = pd.Series(index = genres_name_stacked.value_counts().index, data = 0)
for col in genres_this_company:
    temp = genres_this_company[col].value_counts()
    genres_count = pd.concat([genres_count, temp], axis = 1)
genres_count = genres_count.sum(axis = 1).sort_values(ascending = False)
_ = genres_count.plot.bar(genres_count, ax = ax, color = genres_palette, rot = 45, width = 0.8)
_ = ax.set(xlabel = 'Genres', ylabel = 'Number of occurences among all movies', title = this_company)

# %% [markdown]
# <font size="3">The most popular companies seems to follow the general trend, which is normal since they are the ones to create the trend. Production companies such as Arte (around index 100) is an outlier of the trend with noticeable amount of documenaries.</font>

# %%
# we add column with number of production companies for each movie
company_name = movies.filter(regex = 'production_companies_name_.*')
movies['production_companies_num'] = company_name.count(axis = 1)
for i, c in movies['production_companies_num'].value_counts().sort_index().iteritems():
    print('{} movies have {} production companies'.format(c, i))
# some nice plot
fig, ax = plt.subplots(figsize = (12, 6))
_ = sns.countplot(movies['production_companies_num'], 
                  palette = sns.color_palette("Blues", 8))
_ = ax.set(xlabel = 'Number of production companies', ylabel = 'Movies count', title ='Count of movies vs. number of production companies')
# Out:
# 11403 movies have 0 production companies
# 16424 movies have 1 production companies
# 7890 movies have 2 production companies
# 4676 movies have 3 production companies
# 1931 movies have 4 production companies
# 942 movies have 5 production companies
# 561 movies have 6 production companies
# 309 movies have 7 production companies
# 177 movies have 8 production companies
# 133 movies have 9 production companies
# 67 movies have 10 production companies
# 42 movies have 11 production companies
# 35 movies have 12 production companies
# 19 movies have 13 production companies
# 16 movies have 14 production companies
# 9 movies have 15 production companies
# 20 movies have 16 production companies
# 7 movies have 17 production companies
# 3 movies have 18 production companies
# 5 movies have 19 production companies
# 5 movies have 20 production companies
# 4 movies have 21 production companies
# 3 movies have 22 production companies
# 1 movies have 24 production companies
# 1 movies have 25 production companies
# 3 movies have 26 production companies

# %%
# print some interesting information
max_company = movies[movies['production_companies_num'] == movies['production_companies_num'].max()]
print('There are {} movies with {} production companies!'.format(len(max_company), 
                                                                 movies['production_companies_num'].max()))
max_company
# Out:
# There are 3 movies with 26 production companies!
#        adult      budget      id  imdb_id original_language  \
# 3786       0  12800000.0      16   168629                en
# 22235      0   2000000.0    8985   425624                en
# 36122      1         0.0  345775  2262345                da
#
#               original_title  popularity     revenue  runtime  \
# 3786      Dancer in the Dark   10.684806  40031879.0    140.0
# 22235      Visions of Europe    0.958683         0.0    140.0
# 36122  Tout en haut du monde    2.528348         0.0     80.0
#
#                     title  video  vote_average  vote_count  \
# 3786   Dancer in the Dark      0           7.7       392.0
# 22235   Visions of Europe      0           3.7         3.0
# 36122      Long Way North      0           7.7        35.0
#
#        belongs_to_collection_id belongs_to_collection_name genres_name_0  \
# 3786                        498   Heart of Gold Collection         Drama
# 22235                        -1                        NaN        Comedy
# 36122                        -1                        NaN     Adventure
#
#       genres_name_1 genres_name_2 genres_name_3 genres_name_4 genres_name_5  \
# 3786          Crime         Music           NaN           NaN           NaN
# 22235         Drama           NaN           NaN           NaN           NaN
# 36122     Animation           NaN           NaN           NaN           NaN
#
#       genres_name_6 genres_name_7 production_companies_name_0  \
# 3786            NaN           NaN          Fine Line Features
# 22235           NaN           NaN     Zentropa Entertainments
# 36122           NaN           NaN     Det Danske Filminstitut
#
#       production_companies_name_1 production_companies_name_2  \
# 3786      Zentropa Entertainments         Danmarks Radio (DR)
# 22235                     Coop 99       Corazón International
# 36122                Angoa-Agicoa                    Procirep
#
#                  production_companies_name_3 production_companies_name_4  \
# 3786                               SVT Drama                        Arte
# 22235                             Sputnik Oy       Kasander Film Company
# 36122  MEDIA Programme of the European Union                      Canal+
#
#       production_companies_name_5 production_companies_name_6  \
# 3786                  Memfis Film             France 3 Cinéma
# 22235    MMG Film & TV Production          Column Productions
# 36122                       Ciné+          France Télévisions
#
#                              production_companies_name_7  \
# 3786                                         Angel films
# 22235                                            Negativ
# 36122  Société des Auteurs et Compositeurs Dramatique...
#
#       production_companies_name_8  \
# 3786                      TV 1000
# 22235              Filmes do Tejo
# 36122             France 3 Cinema
#
#                        production_companies_name_9  \
# 3786                                        Canal+
# 22235                              Fantastic Films
# 36122  Centre National de la Cinématographie (CNC)
#
#        production_companies_name_10 production_companies_name_11  \
# 3786     Constantin Film Produktion             Yleisradio (YLE)
# 22235       Rattlesnake Productions                  Bianca Film
# 36122  Fondation GAN pour le Cinéma                 Maybe Movies
#
#       production_companies_name_12  production_companies_name_13  \
# 3786            Arte France Cinéma  Westdeutscher Rundfunk (WDR)
# 22235             Maestranza Films                 E-motion Film
# 36122             Région Aquitaine                     2 minutes
#
#       production_companies_name_14  \
# 3786        Blind Spot Pictures Oy
# 22235              Athena Film A/S
# 36122              Noerlum Studios
#
#                       production_companies_name_15  \
# 3786   Vrijzinnig Protestantse Radio Omroep (VPRO)
# 22235                                Princes Films
# 36122          Département de la Charente-Maritime
#
#       production_companies_name_16 production_companies_name_17  \
# 3786                         Film4        Liberator Productions
# 22235                TT Filmműhely              Cumulus Projekt
# 36122           Palatine Étoile 11                Région Alsace
#
#       production_companies_name_18 production_companies_name_19  \
# 3786                Icelandic Film                  Film i Väst
# 22235  Drunken Angel Entertainment     Goran Production Company
# 36122  Eurométropole de Strasbourg  Conseil Général de Lorraine
#
#              production_companies_name_20 production_companies_name_21  \
# 3786   Pain Unlimited GmbH Filmproduktion           Trust Film Svenska
# 22235                      Hargla Company             Inkas Production
# 36122             Région Poitou-Charentes   Département de la Charente
#
#           production_companies_name_22      production_companies_name_23  \
# 3786                 Cinematograph A/S                    What Else? B.V
# 22235             Lychnari Productions  Public Institution Kinemos Grupe
# 36122  Académie Franco-Russe du Cinéma             West Danish Film Fund
#
#       production_companies_name_24 production_companies_name_25  \
# 3786                    Filmek A/S  Lantia Cinema & Audiovisivi
# 22235                        SHOTS               Titanic s.r.o.
# 36122                CPH Film Fund     Association Beaumarchais
#
#       production_countries_iso_3166_1_0 production_countries_name_0  \
# 3786                                 AR                   Argentina
# 22235                                AT                     Austria
# 36122                                DK                     Denmark
#
#       production_countries_iso_3166_1_1 production_countries_name_1  \
# 3786                                 DK                     Denmark
# 22235                                BE                     Belgium
# 36122                                FR                      France
#
#       production_countries_iso_3166_1_2 production_countries_name_2  \
# 3786                                 FI                     Finland
# 22235                                CY                      Cyprus
# 36122                               NaN                         NaN
#
#       production_countries_iso_3166_1_3 production_countries_name_3  \
# 3786                                 FR                      France
# 22235                                CZ              Czech Republic
# 36122                               NaN                         NaN
#
#       production_countries_iso_3166_1_4 production_countries_name_4  \
# 3786                                 DE                     Germany
# 22235                                DK                     Denmark
# 36122                               NaN                         NaN
#
#       production_countries_iso_3166_1_5 production_countries_name_5  \
# 3786                                 IS                     Iceland
# 22235                                EE                     Estonia
# 36122                               NaN                         NaN
#
#       production_countries_iso_3166_1_6 production_countries_name_6  \
# 3786                                 IT                       Italy
# 22235                                FI                     Finland
# 36122                               NaN                         NaN
#
#       production_countries_iso_3166_1_7 production_countries_name_7  \
# 3786                                 NL                 Netherlands
# 22235                                FR                      France
# 36122                               NaN                         NaN
#
#       production_countries_iso_3166_1_8 production_countries_name_8  \
# 3786                                 NO                      Norway
# 22235                                DE                     Germany
# 36122                               NaN                         NaN
#
#       production_countries_iso_3166_1_9 production_countries_name_9  \
# 3786                                 SE                      Sweden
# 22235                                GR                      Greece
# 36122                               NaN                         NaN
#
#       production_countries_iso_3166_1_10 production_countries_name_10  \
# 3786                                  GB               United Kingdom
# 22235                                 HU                      Hungary
# 36122                                NaN                          NaN
#
#       production_countries_iso_3166_1_11 production_countries_name_11  \
# 3786                                  US     United States of America
# 22235                                 IE                      Ireland
# 36122                                NaN                          NaN
#
#       production_countries_iso_3166_1_12 production_countries_name_12  \
# 3786                                 NaN                          NaN
# 22235                                 IT                        Italy
# 36122                                NaN                          NaN
#
#       production_countries_iso_3166_1_13 production_countries_name_13  \
# 3786                                 NaN                          NaN
# 22235                                 LV                       Latvia
# 36122                                NaN                          NaN
#
#       production_countries_iso_3166_1_14 production_countries_name_14  \
# 3786                                 NaN                          NaN
# 22235                                 LT                    Lithuania
# 36122                                NaN                          NaN
#
#       production_countries_iso_3166_1_15 production_countries_name_15  \
# 3786                                 NaN                          NaN
# 22235                                 LU                   Luxembourg
# 36122                                NaN                          NaN
#
#       production_countries_iso_3166_1_16 production_countries_name_16  \
# 3786                                 NaN                          NaN
# 22235                                 MT                        Malta
# 36122                                NaN                          NaN
#
#       production_countries_iso_3166_1_17 production_countries_name_17  \
# 3786                                 NaN                          NaN
# 22235                                 NL                  Netherlands
# 36122                                NaN                          NaN
#
#       production_countries_iso_3166_1_18 production_countries_name_18  \
# 3786                                 NaN                          NaN
# 22235                                 PL                       Poland
# 36122                                NaN                          NaN
#
#       production_countries_iso_3166_1_19 production_countries_name_19  \
# 3786                                 NaN                          NaN
# 22235                                 PT                     Portugal
# 36122                                NaN                          NaN
#
#       production_countries_iso_3166_1_20 production_countries_name_20  \
# 3786                                 NaN                          NaN
# 22235                                 SK                     Slovakia
# 36122                                NaN                          NaN
#
#       production_countries_iso_3166_1_21 production_countries_name_21  \
# 3786                                 NaN                          NaN
# 22235                                 SI                     Slovenia
# 36122                                NaN                          NaN
#
#       production_countries_iso_3166_1_22 production_countries_name_22  \
# 3786                                 NaN                          NaN
# 22235                                 ES                        Spain
# 36122                                NaN                          NaN
#
#       production_countries_iso_3166_1_23 production_countries_name_23  \
# 3786                                 NaN                          NaN
# 22235                                 SE                       Sweden
# 36122                                NaN                          NaN
#
#       production_countries_iso_3166_1_24 production_countries_name_24  \
# 3786                                 NaN                          NaN
# 22235                                 GB               United Kingdom
# 36122                                NaN                          NaN
#
#       spoken_languages_iso_639_1_0 spoken_languages_name_0  \
# 3786                            en                 English
# 22235                           cs                   Český
# 36122                           da                   Dansk
#
#       spoken_languages_iso_639_1_1 spoken_languages_name_1  \
# 3786                           NaN                     NaN
# 22235                           da                   Dansk
# 36122                           nl              Nederlands
#
#       spoken_languages_iso_639_1_2 spoken_languages_name_2  \
# 3786                           NaN                     NaN
# 22235                           de                 Deutsch
# 36122                           fr                Français
#
#       spoken_languages_iso_639_1_3 spoken_languages_name_3  \
# 3786                           NaN                     NaN
# 22235                           fi                   suomi
# 36122                          NaN                     NaN
#
#       spoken_languages_iso_639_1_4 spoken_languages_name_4  \
# 3786                           NaN                     NaN
# 22235                           fr                Français
# 36122                          NaN                     NaN
#
#       spoken_languages_iso_639_1_5 spoken_languages_name_5  \
# 3786                           NaN                     NaN
# 22235                           it                Italiano
# 36122                          NaN                     NaN
#
#       spoken_languages_iso_639_1_6 spoken_languages_name_6  \
# 3786                           NaN                     NaN
# 22235                           lt             Lietuvikai
# 36122                          NaN                     NaN
#
#       spoken_languages_iso_639_1_7 spoken_languages_name_7  \
# 3786                           NaN                     NaN
# 22235                           lb                     NaN
# 36122                          NaN                     NaN
#
#       spoken_languages_iso_639_1_8 spoken_languages_name_8  \
# 3786                           NaN                     NaN
# 22235                           mt                   Malti
# 36122                          NaN                     NaN
#
#       spoken_languages_iso_639_1_9 spoken_languages_name_9  \
# 3786                           NaN                     NaN
# 22235                           nl              Nederlands
# 36122                          NaN                     NaN
#
#       spoken_languages_iso_639_1_10 spoken_languages_name_10  \
# 3786                            NaN                      NaN
# 22235                            pl                   Polski
# 36122                           NaN                      NaN
#
#       spoken_languages_iso_639_1_11 spoken_languages_name_11  \
# 3786                            NaN                      NaN
# 22235                            pt                Português
# 36122                           NaN                      NaN
#
#       spoken_languages_iso_639_1_12 spoken_languages_name_12  \
# 3786                            NaN                      NaN
# 22235                            sk               Slovenčina
# 36122                           NaN                      NaN
#
#       spoken_languages_iso_639_1_13 spoken_languages_name_13  \
# 3786                            NaN                      NaN
# 22235                            sl              Slovenščina
# 36122                           NaN                      NaN
#
#       spoken_languages_iso_639_1_14 spoken_languages_name_14  \
# 3786                            NaN                      NaN
# 22235                            es                  Español
# 36122                           NaN                      NaN
#
#       spoken_languages_iso_639_1_15 spoken_languages_name_15  \
# 3786                            NaN                      NaN
# 22235                            sv                  svenska
# 36122                           NaN                      NaN
#
#       spoken_languages_iso_639_1_16 spoken_languages_name_16  \
# 3786                            NaN                      NaN
# 22235                            tr                   Türkçe
# 36122                           NaN                      NaN
#
#       spoken_languages_iso_639_1_17 spoken_languages_name_17  \
# 3786                            NaN                      NaN
# 22235                            el                 ελληνικά
# 36122                           NaN                      NaN
#
#       spoken_languages_iso_639_1_18 spoken_languages_name_18  release_year  \
# 3786                            NaN                      NaN          2000
# 22235                            en                  English          2004
# 36122                           NaN                      NaN          2015
#
#        release_month  genres_weight  genres_num  production_companies_num
# 3786               5       0.287479           3                        26
# 22235              5       0.366658           2                        26
# 36122             12       0.059717           2                        26

# %% [markdown]
# <font size="3">These movies seem to be European collaborations that group various countries and various production companies.</font>

# %% [markdown]
# ## Analysis of production countries

# %%
# we can drop the iso certification name of production countries and re-econde later
country_iso = movies.filter(regex = 'production_countries_iso_.*')
movies = movies.drop(columns = country_iso.columns)

# %%
# identify movies without a production country
nulls = movies.filter(regex = 'production_countries_name_.*').isnull().sum(axis = 0)
print('There are {} movies without a production country. Can we can drop them?'.format(nulls[0]))
# Out:
# There are 5981 movies without a production country. Can we can drop them?

# %%
# let's see how many production countries movies have on average
country_name = movies.filter(regex = 'production_countries_name_.*')
avg_country = country_name.count(axis = 1).mean()
print('Number of production countries on average over all movies: {}'.format(avg_country))
# Out:
# Number of production countries on average over all movies: 1.0932954392874725

# %%
# we identify all possible values for production countries
country_name = movies.filter(regex = 'production_countries_name_.*')
country_name_stacked = country_name.stack().reset_index(drop = True)
country_name_unique = country_name_stacked.drop_duplicates().reset_index(drop = True)
print('There are {} different production countries!'.format(len(country_name_unique)))
# Out:
# There are 160 different production countries!

# %%
# get most popular production countries
num_most_popular = 10
print('{} most popular production countries (values: produced films)'.format(num_most_popular))
country_name_value_counts = country_name_stacked.value_counts()
country_name_value_counts_norm = country_name_stacked.value_counts()/sum(country_name_value_counts)
pd.DataFrame(country_name_value_counts[:num_most_popular])
# Out:
# 10 most popular production countries (values: produced films)
#                               0
# United States of America  21006
# United Kingdom             4070
# France                     3882
# Germany                    2203
# Italy                      2115
# Canada                     1742
# Japan                      1639
# Spain                       938
# Russia                      898
# India                       820

# %% [markdown]
# <font size="3">As one could guess, the most popular production countries are the USA, UK, and France, among other big nations. </font>

# %%
# plot map with number of movies produced
fig, ax = plt.subplots(figsize = (18, 9))
fig.suptitle('All-time number of movies produced in countries', fontsize = 14, y = 0.95)

m = Basemap(projection = 'mill', llcrnrlon = -140, llcrnrlat = -60, urcrnrlon = 180, urcrnrlat = 80, 
            resolution = 'c')

m.drawmapboundary(fill_color = '#ffffff', linewidth = 0, ax = ax)
m.fillcontinents(color = '#dbdbdb', alpha = 0.25, lake_color = '#ffffff')
m.drawcoastlines(linewidth = 0.1, color = "black")
m.drawcountries(linewidth = 0.05, color = 'black')

# read gps coordinates first
with open('gps_coordinates.json') as f:
    gps_coordinates = json.load(f)

# get gps coordinates of countries
geolocator = Nominatim(user_agent = 'specify_your_app_name_here', timeout = 10)
for country in country_name_value_counts[:160].index:
    if country in gps_coordinates:
        x, y = gps_coordinates[country]
    else:
        location = geolocator.geocode(country)
        try:
            coordinates = (location.latitude, location.longitude)
            x, y = m(coordinates[1], coordinates[0])
            gps_coordinates[country] = (x, y)
        except: # if the country does not exist?
            continue
    
    plt.scatter(x, y, color = 'blue', s = country_name_value_counts_norm[country]*4e4, 
                alpha = 1, marker = 'o', linewidth = 1, edgecolors = 'black')
    
# write gps coordinates
with open('gps_coordinates.json', 'w') as f:
    json.dump(gps_coordinates, f)
# Out:
# /Users/williammartin/anaconda3/envs/epfl/lib/python3.7/site-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#
# /Users/williammartin/anaconda3/envs/epfl/lib/python3.7/site-packages/ipykernel_launcher.py:11: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   # This is added back by InteractiveShellApp.init_path()
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/anaconda3/envs/epfl/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#
# ~/anaconda3/envs/epfl/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# ~/anaconda3/envs/epfl/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~/anaconda3/envs/epfl/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#
# ~/anaconda3/envs/epfl/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# ~/anaconda3/envs/epfl/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#
# HTTPError: HTTP Error 403: Forbidden
#
# During handling of the above exception, another exception occurred:
#
# GeocoderInsufficientPrivileges            Traceback (most recent call last)
# <ipython-input-45-5c79838f39ca> in <module>
#      21         x, y = gps_coordinates[country]
#      22     else:
# ---> 23         location = geolocator.geocode(country)
#      24         try:
#      25             coordinates = (location.latitude, location.longitude)
#
# ~/anaconda3/envs/epfl/lib/python3.7/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     404
#     405         return self._parse_json(
# --> 406             self._call_geocoder(url, timeout=timeout), exactly_one
#     407         )
#     408
#
# ~/anaconda3/envs/epfl/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     371                                 exc_info=False)
#     372                 try:
# --> 373                     raise ERROR_CODE_MAP[code](message)
#     374                 except KeyError:
#     375                     raise GeocoderServiceError(message)
#
# GeocoderInsufficientPrivileges: HTTP Error 403: Forbidden

# %% [markdown]
# <font size="3">There are a lot of countries where a small number of movies have been produced. This is either independently or in colloboration with a country that is knowledgable in film production and wanted an exotic/genuine movie set. For example, Beauty and the Beast (2017) was filmed entirely in Great Britain but was produced by American film production companies (both countries appear in the column production_countries). </font>

# %%
# plot map of countries and average popularity
# get average popularity per country
popularity_country = movies.filter(regex = '(production_countries_name_.*)|(popularity)')
country_name = movies.filter(regex = 'production_countries_name_.*')
popularity = movies.filter(regex = 'popularity')
avg_popularity_countries = {}
for country in country_name_value_counts.index:
    popularity_this_country = popularity_country[(popularity_country[country_name.columns] == country).\
                                             any(axis = 1)]
    popularity_this_country = popularity_this_country[popularity.columns]
    if len(popularity_this_country) > 10: # remove outliers, countries that have high popularity with little movies
        avg_popularity_this_country = popularity_this_country.mean().values[0]
        avg_popularity_countries[country] = avg_popularity_this_country

max_pop = max(avg_popularity_countries.values())
min_pop = min(avg_popularity_countries.values())

# %%
# useful color selector from gradient of colors
def color_fader(c1, c2, mix = 0):
    c1 = np.array(mpl.colors.to_rgb(c1))
    c2 = np.array(mpl.colors.to_rgb(c2))
    return mpl.colors.to_hex((1-mix)*c1 + mix*c2)

# %%
# the actual plot
shapefile = 'ne_10m_admin_0_countries_lakes'

# read shapes
fig, ax = plt.subplots(figsize = (18, 9))
fig.suptitle('Average popularity of movies produced in countries', 
             fontsize = 14, y = 0.95)

m = Basemap(projection = 'mill', llcrnrlon = -140, llcrnrlat = -60, urcrnrlon = 180, urcrnrlat = 80, 
            resolution = 'c')

m.drawmapboundary(fill_color = '#ffffff', linewidth = 0, ax = ax)
m.fillcontinents(color = '#dbdbdb', alpha = 0.25, lake_color = '#ffffff')
m.drawcoastlines(linewidth = 0.1, color = "black")
m.drawcountries(linewidth = 0.05, color = 'black')

# read shapes
m.readshapefile(shapefile, 'units', color = '#444444', linewidth = 0.05)

# define start and end colors
c_start = '#e1e3f2'
c_end = '#0013e0'

for info, shape in zip(m.units_info, m.units):
    country = info['NAME'] # some countries not found???
    
    if country in avg_popularity_countries:
        c_factor = (avg_popularity_countries[country] - min_pop)/(max_pop - min_pop)
        patches = [Polygon(np.array(shape), True)]
        pc = PatchCollection(patches)
        pc.set_facecolor(color_fader(c_start, c_end, c_factor))
        ax.add_collection(pc)
        
num_bound = 10
ax.axhspan(0, 1000 * 1800, facecolor = 'w', edgecolor = 'w', zorder = 2)
ax_legend = fig.add_axes([0.35, 0.14, 0.3, 0.03], zorder=3)
scheme = [color_fader(c_start, c_end, i/num_bound) for i in range(0,num_bound+1)]
cmap = mpl.colors.ListedColormap(scheme)
bins = np.linspace(min_pop, max_pop, num_bound)
cb = mpl.colorbar.ColorbarBase(ax_legend, cmap = cmap, ticks = bins, boundaries = bins, 
                               orientation = 'horizontal')
_ = cb.ax.set_xticklabels([str(round(i, 1)) for i in bins])
# Out:
# /Users/williammartin/anaconda3/envs/epfl/lib/python3.7/site-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   # Remove the CWD from sys.path while we load stuff.
# /Users/williammartin/anaconda3/envs/epfl/lib/python3.7/site-packages/ipykernel_launcher.py:15: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   from ipykernel import kernelapp as app
# /Users/williammartin/anaconda3/envs/epfl/lib/python3.7/site-packages/ipykernel_launcher.py:18: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.

# %% [markdown]
# <font size="3">We have filtered out countries which have produced 10 or less movies since they can easily deceive the scale if they produced one block-buster (perhaps in collaboration with a country that has produced numerous movies). Countries that have produced a lot of movies are not the most popular on average. This is logical from the fact that they will produce many bad movies as well. Some countries are very popular, for example New Zealand which is probably due to the Lord of the Rings trilogy. Another popular country like South Africa might be due to safety and beautiful landscapes. Indeed, movies such as Avengers, District 9, Mad Max were (partly) set in South Africa. This is the same for the UAE, popular movies that are (partly) set there are Mission Impossible: Fallout, Star Trek Beyond, Furious 7, Star Wars: The Force Awaken among other popular movies.</font>

# %%
# we add a column of production countries per movie as a weight, the more the movie has popular production countries, the higher 
# the total weight of the movie
# compute weights
country_weight = country_name_stacked.value_counts(normalize = True)
country_name_weighted = country_name.replace(country_weight)
movies['production_countries_weight'] = country_name_weighted.sum(axis = 1)

# %%
# we add column with number of production countries for each movie
country_name = movies.filter(regex = 'production_countries_name_.*')
movies['production_countries_num'] = country_name.count(axis = 1)
for i, c in movies['production_countries_num'].value_counts().sort_index().iteritems():
    print('{} movies have {} production countries'.format(c, i))
# some nice plot
fig, ax = plt.subplots(figsize = (12, 6))
_ = sns.countplot(movies['production_countries_num'], 
                  palette = sns.color_palette("Blues", 8))
_ = ax.set(xlabel = 'Number of production countries', ylabel = 'Movies count', title ='Count of movies vs. number of production countries')
# Out:
# 5981 movies have 0 production countries
# 31744 movies have 1 production countries
# 4830 movies have 2 production countries
# 1451 movies have 3 production countries
# 461 movies have 4 production countries
# 150 movies have 5 production countries
# 39 movies have 6 production countries
# 12 movies have 7 production countries
# 6 movies have 8 production countries
# 6 movies have 9 production countries
# 1 movies have 10 production countries
# 2 movies have 11 production countries
# 1 movies have 12 production countries
# 1 movies have 15 production countries
# 1 movies have 25 production countries

# %% [markdown]
# <font size="3">Below another interesting plot of average budget among all movies per country. We assume the budget column is in American dollars and the same for all movies. </font>

# %%
# plot countries by average budget
# get average budget per country
budget_country = movies.filter(regex = '(production_countries_name_.*)|(budget)')
country_name = movies.filter(regex = 'production_countries_name_.*')
budget = movies.filter(regex = 'budget')
avg_budget_countries = {}
for country in country_name_value_counts.index:
    budget_this_country = budget_country[(budget_country[country_name.columns] == country).\
                                         any(axis = 1)]
    budget_this_country = budget_this_country[budget.columns]
    if len(budget_this_country) > 10: # keep small outliers out
        budget_this_country = budget_this_country[budget_this_country > 1e6] # keep only budget above a threshold
        avg_budget_this_country = budget_this_country.mean().values[0]
        avg_budget_countries[country] = avg_budget_this_country
    
max_budget = max(avg_budget_countries.values())
min_budget = min(avg_budget_countries.values())

# %%
# the actual plot
shapefile = 'ne_10m_admin_0_countries_lakes'

# read shapes
fig, ax = plt.subplots(figsize = (18, 9))
fig.suptitle('Average budget of movies produced in countries (in millions of US dollars)', 
             fontsize = 14, y = 0.95)

m = Basemap(projection = 'mill', llcrnrlon = -140, llcrnrlat = -60, urcrnrlon = 180, urcrnrlat = 80, 
            resolution = 'c')

m.drawmapboundary(fill_color = '#ffffff', linewidth = 0, ax = ax)
m.fillcontinents(color = '#dbdbdb', alpha = 0.25, lake_color = '#ffffff')
m.drawcoastlines(linewidth = 0.1, color = "black")
m.drawcountries(linewidth = 0.05, color = 'black')

# read shapes
m.readshapefile(shapefile, 'units', color = '#444444', linewidth = 0.05)

# define start and end colors
c_start = '#edffeb'
c_end = '#0b7000'

for info, shape in zip(m.units_info, m.units):
    country = info['NAME'] # some countries not found???
    
    if country in avg_budget_countries and not pd.isnull(avg_budget_countries[country]):
        c_factor = (avg_budget_countries[country] - min_budget)/(max_budget - min_budget)
        patches = [Polygon(np.array(shape), True)]
        pc = PatchCollection(patches)
        pc.set_facecolor(color_fader(c_start, c_end, c_factor))
        ax.add_collection(pc)
        
num_bound = 10
ax.axhspan(0, 1000 * 1800, facecolor = 'w', edgecolor = 'w', zorder = 2)
ax_legend = fig.add_axes([0.35, 0.14, 0.3, 0.03], zorder=3)
scheme = [color_fader(c_start, c_end, i/num_bound) for i in range(0,num_bound+1)]
cmap = mpl.colors.ListedColormap(scheme)
bins = np.linspace(min_budget, max_budget, num_bound)
cb = mpl.colorbar.ColorbarBase(ax_legend, cmap = cmap, ticks = bins, boundaries = bins, 
                               orientation = 'horizontal')
_ = cb.ax.set_xticklabels([str(round(i/1e6, 1)) for i in bins])
# Out:
# /Users/williammartin/anaconda3/envs/epfl/lib/python3.7/site-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   # Remove the CWD from sys.path while we load stuff.
# /Users/williammartin/anaconda3/envs/epfl/lib/python3.7/site-packages/ipykernel_launcher.py:15: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   from ipykernel import kernelapp as app
# /Users/williammartin/anaconda3/envs/epfl/lib/python3.7/site-packages/ipykernel_launcher.py:18: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.

# %% [markdown]
# ## Analysis of translated languages

# %%
# we can drop the iso certification name of spoken languages and re-econde later
language_iso = movies.filter(regex = 'spoken_languages_iso_.*')
movies = movies.drop(columns = language_iso.columns)

# %%
# we add column with number of spoken languages for each movie
language_name = movies.filter(regex = 'spoken_languages_name_.*')
movies['spoken_languages_num'] = language_name.count(axis = 1)
for i, c in movies['spoken_languages_num'].value_counts().sort_index().iteritems():
    print('{} movies have been translated to {} languages'.format(c, i))
# some nice plot
fig, ax = plt.subplots(figsize = (12, 6))
_ = sns.countplot(movies['spoken_languages_num'], 
                  palette = sns.color_palette("Blues", 8))
_ = ax.set(xlabel = 'Number of languages translated to ', ylabel = 'Movies count', title ='Count of movies vs. number of languages translated to')
# Out:
# 3720 movies have been translated to 0 languages
# 33283 movies have been translated to 1 languages
# 5291 movies have been translated to 2 languages
# 1648 movies have been translated to 3 languages
# 503 movies have been translated to 4 languages
# 163 movies have been translated to 5 languages
# 51 movies have been translated to 6 languages
# 13 movies have been translated to 7 languages
# 7 movies have been translated to 8 languages
# 3 movies have been translated to 9 languages
# 1 movies have been translated to 10 languages
# 1 movies have been translated to 11 languages
# 1 movies have been translated to 13 languages
# 1 movies have been translated to 18 languages

# %% [markdown]
# ## Runtime analysis

# %%
# plot runtime by removing outliers with z-score
fig, ax = plt.subplots(figsize = (14, 10))
x = 'runtime'
df_toplot = movies[(np.abs(stats.zscore(movies[[x]])) < 3).all(axis=1)]

# group movies by genres in genres_name_0 column and in order of most popular genre to least popular
grouper = {genre: df for genre, df in df_toplot.groupby('genres_name_0', sort = False)}
# sort the grouper
grouper = {genre : grouper[genre] for genre in genres_name_stacked.value_counts().index}
for i, (genre, df) in enumerate(grouper.items()):
    ax.hist(df[x], 120, stacked = True, color = genres_palette[i], label = genre,
           range = (df[x].min(), df[x].max()))
_ = ax.legend(bbox_to_anchor = (1, 0.5), loc = 'center left')
_ = ax.set(xlabel = 'Runtime in minutes ', ylabel = 'Genre occurences', title ='Distribution of movies runtime by genre')

# %% [markdown]
# <font size="3">We see that most movies, across all genres, last around one hour and a half (slightly less than 100 minutes) </font>

# %% [markdown]
# ## Budget and revenue analysis

# %%
# plot budget vs revenue by removing outliers with z-score
fig, ax = plt.subplots(figsize = (14, 10))
df_toplot = movies[(np.abs(stats.zscore(movies[['revenue', 'budget']])) < 3).all(axis=1)]
# filter revenue and budget above 0?
df_toplot = df_toplot[df_toplot['budget'] > 1e4] 
df_toplot = df_toplot[df_toplot['revenue'] > 1e4]

# group movies by genres in genres_name_0 column and in order of most popular genre to least popular
grouper = {genre: df for genre, df in df_toplot.groupby('genres_name_0', sort = False)}
# sort the grouper
grouper = {genre : grouper[genre] for genre in genres_name_stacked.value_counts().index}
for i, (genre, df) in enumerate(grouper.items()):
    df.plot.scatter('budget', 'revenue', label = genre, color = genres_palette[i], ax = ax)
    
ax.set_xscale('log')
ax.set_yscale('log')
_ = ax.legend(bbox_to_anchor = (1, 0.5), loc = 'center left')
_ = ax.set(xlabel = 'Budget in US dollars ', ylabel = 'Revenu in US dollars')

# %% [markdown]
# <font size="3">We do not see any clusters in Genre, meaning there is no obvious correlation between Genre and Revenue and Budget. </font>

# %% [markdown]
#  <font color=blue> JE SUIS PAS SURE DE L'INTERPRETATION DU GRAPH -M</font>

# %%
# plot budget vs revenue vs. popularity by removing outliers with z-score
fig, ax = plt.subplots(figsize = (16, 10))
x = 'budget'
y = 'revenue'
z = 'popularity' # try vote_count as well
df_toplot = movies[(np.abs(stats.zscore(movies[[x, y, z]])) < 3).all(axis=1)]
# filter revenue and budget above 0?
df_toplot = df_toplot[df_toplot[x] > 1e4] 
df_toplot = df_toplot[df_toplot[y] > 1e4]

chart = ax.scatter(df_toplot[x], df_toplot[y], c = df_toplot[z],
                   cmap='viridis')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(x)
ax.set_ylabel(y)
_ = fig.colorbar(chart, ax = ax)
_ = ax.set(xlabel = 'Budget in US dollars ', ylabel = 'Revenu in US dollars', title = 'Popularity vs. Revenue vs. Budget')

# %%
# plot budget vs revenue vs. popularity by removing outliers with z-score
fig, ax = plt.subplots(figsize = (16, 10))
x = 'budget'
y = 'revenue'
z = 'vote_average' 
df_toplot = movies[(np.abs(stats.zscore(movies[[x, y, z]])) < 3).all(axis=1)]
# filter revenue and budget above 0?
df_toplot = df_toplot[df_toplot[x] > 1e4] 
df_toplot = df_toplot[df_toplot[y] > 1e4]

chart = ax.scatter(df_toplot[x], df_toplot[y], c = df_toplot[z],
                   cmap='viridis')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(x)
ax.set_ylabel(y)
_ = fig.colorbar(chart, ax = ax)
_ = ax.set(xlabel = 'Budget in US dollars ', ylabel = 'Revenu in US dollars', title = 'IMDB score vs. Revenue vs. Budget')

# %% [markdown]
# <font size="3">We see that most movies have an IMDB score between 5 and 7. Interestingly there are no real clusters of scores as we have movies with low budget and revenue with scores similar to movies with high budget and revenue. </font>

# %% [markdown]
# ## Popularity and vote count analysis

# %%
# plot popularity vs vote count vs. budget by removing outliers with z-score
fig, ax = plt.subplots(figsize = (16, 10))
x = 'vote_count'
y = 'popularity'
z = 'budget' # try other columns
df_toplot = movies[(np.abs(stats.zscore(movies[[x, y, z]])) < 3).all(axis=1)]

chart = ax.scatter(df_toplot[x], df_toplot[y], c = df_toplot[z],
                   cmap='viridis')
ax.set_xlabel(x)
ax.set_ylabel(y)
fig.suptitle('{} vs. {} vs. {}'.format(z, y, x))
_ = fig.colorbar(chart, ax = ax)

# %% [markdown]
#  <font color=blue> JE COMPRENDS PAS CE GRAPH -M</font>

# %% [markdown]
# ## Collection analysis

# %%
# create a new column belongs to collection (True 1, False 0)
movies['belongs_to_collection'] = movies['belongs_to_collection_name'].notnull().astype('int')

# %%
movies
# Out:
#        adult      budget      id  imdb_id original_language  \
# 0          0  30000000.0     862   114709                en
# 1          0  65000000.0    8844   113497                en
# 2          0         0.0   15602   113228                en
# 3          0  16000000.0   31357   114885                en
# 4          0         0.0   11862   113041                en
# ...      ...         ...     ...      ...               ...
# 45460      0         0.0   30840   102797                en
# 45462      0         0.0  111109   202855                tl
# 45463      0         0.0   67758   303758                en
# 45464      0         0.0  227506     8536                en
# 45465      0         0.0  461257  6980792                en
#
#                     original_title  popularity      revenue  runtime  \
# 0                        Toy Story   21.946943  373554033.0     81.0
# 1                          Jumanji   17.015539  262797249.0    104.0
# 2                 Grumpier Old Men   11.712900          0.0    101.0
# 3                Waiting to Exhale    3.859495   81452156.0    127.0
# 4      Father of the Bride Part II    8.387519   76578911.0    106.0
# ...                            ...         ...          ...      ...
# 45460                   Robin Hood    5.683753          0.0    104.0
# 45462          Siglo ng Pagluluwal    0.178241          0.0    360.0
# 45463                     Betrayal    0.903007          0.0     90.0
# 45464          Satana likuyushchiy    0.003503          0.0     87.0
# 45465                     Queerama    0.163015          0.0     75.0
#
#                              title  video  vote_average  vote_count  \
# 0                        Toy Story      0           7.7      5415.0
# 1                          Jumanji      0           6.9      2413.0
# 2                 Grumpier Old Men      0           6.5        92.0
# 3                Waiting to Exhale      0           6.1        34.0
# 4      Father of the Bride Part II      0           5.7       173.0
# ...                            ...    ...           ...         ...
# 45460                   Robin Hood      0           5.7        26.0
# 45462          Century of Birthing      0           9.0         3.0
# 45463                     Betrayal      0           3.8         6.0
# 45464             Satan Triumphant      0           0.0         0.0
# 45465                     Queerama      0           0.0         0.0
#
#        belongs_to_collection_id      belongs_to_collection_name genres_name_0  \
# 0                         10194            Toy Story Collection     Animation
# 1                            -1                             NaN     Adventure
# 2                        119050       Grumpy Old Men Collection       Romance
# 3                            -1                             NaN        Comedy
# 4                         96871  Father of the Bride Collection        Comedy
# ...                         ...                             ...           ...
# 45460                        -1                             NaN         Drama
# 45462                        -1                             NaN         Drama
# 45463                        -1                             NaN        Action
# 45464                        -1                             NaN           NaN
# 45465                        -1                             NaN           NaN
#
#       genres_name_1 genres_name_2 genres_name_3 genres_name_4 genres_name_5  \
# 0            Comedy        Family           NaN           NaN           NaN
# 1           Fantasy        Family           NaN           NaN           NaN
# 2            Comedy           NaN           NaN           NaN           NaN
# 3             Drama       Romance           NaN           NaN           NaN
# 4               NaN           NaN           NaN           NaN           NaN
# ...             ...           ...           ...           ...           ...
# 45460        Action       Romance           NaN           NaN           NaN
# 45462           NaN           NaN           NaN           NaN           NaN
# 45463         Drama      Thriller           NaN           NaN           NaN
# 45464           NaN           NaN           NaN           NaN           NaN
# 45465           NaN           NaN           NaN           NaN           NaN
#
#       genres_name_6 genres_name_7             production_companies_name_0  \
# 0               NaN           NaN                 Pixar Animation Studios
# 1               NaN           NaN                        TriStar Pictures
# 2               NaN           NaN                            Warner Bros.
# 3               NaN           NaN  Twentieth Century Fox Film Corporation
# 4               NaN           NaN                   Sandollar Productions
# ...             ...           ...                                     ...
# 45460           NaN           NaN            Westdeutscher Rundfunk (WDR)
# 45462           NaN           NaN                             Sine Olivia
# 45463           NaN           NaN                 American World Pictures
# 45464           NaN           NaN                               Yermoliev
# 45465           NaN           NaN                                     NaN
#
#       production_companies_name_1  production_companies_name_2  \
# 0                             NaN                          NaN
# 1                    Teitler Film    Interscope Communications
# 2                  Lancaster Gate                          NaN
# 3                             NaN                          NaN
# 4             Touchstone Pictures                          NaN
# ...                           ...                          ...
# 45460         Working Title Films  20th Century Fox Television
# 45462                         NaN                          NaN
# 45463                         NaN                          NaN
# 45464                         NaN                          NaN
# 45465                         NaN                          NaN
#
#          production_companies_name_3 production_companies_name_4  \
# 0                                NaN                         NaN
# 1                                NaN                         NaN
# 2                                NaN                         NaN
# 3                                NaN                         NaN
# 4                                NaN                         NaN
# ...                              ...                         ...
# 45460  CanWest Global Communications                         NaN
# 45462                            NaN                         NaN
# 45463                            NaN                         NaN
# 45464                            NaN                         NaN
# 45465                            NaN                         NaN
#
#       production_companies_name_5 production_companies_name_6  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
# ...                           ...                         ...
# 45460                         NaN                         NaN
# 45462                         NaN                         NaN
# 45463                         NaN                         NaN
# 45464                         NaN                         NaN
# 45465                         NaN                         NaN
#
#       production_companies_name_7 production_companies_name_8  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
# ...                           ...                         ...
# 45460                         NaN                         NaN
# 45462                         NaN                         NaN
# 45463                         NaN                         NaN
# 45464                         NaN                         NaN
# 45465                         NaN                         NaN
#
#       production_companies_name_9 production_companies_name_10  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
# ...                           ...                          ...
# 45460                         NaN                          NaN
# 45462                         NaN                          NaN
# 45463                         NaN                          NaN
# 45464                         NaN                          NaN
# 45465                         NaN                          NaN
#
#       production_companies_name_11 production_companies_name_12  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# ...                            ...                          ...
# 45460                          NaN                          NaN
# 45462                          NaN                          NaN
# 45463                          NaN                          NaN
# 45464                          NaN                          NaN
# 45465                          NaN                          NaN
#
#       production_companies_name_13 production_companies_name_14  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# ...                            ...                          ...
# 45460                          NaN                          NaN
# 45462                          NaN                          NaN
# 45463                          NaN                          NaN
# 45464                          NaN                          NaN
# 45465                          NaN                          NaN
#
#       production_companies_name_15 production_companies_name_16  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# ...                            ...                          ...
# 45460                          NaN                          NaN
# 45462                          NaN                          NaN
# 45463                          NaN                          NaN
# 45464                          NaN                          NaN
# 45465                          NaN                          NaN
#
#       production_companies_name_17 production_companies_name_18  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# ...                            ...                          ...
# 45460                          NaN                          NaN
# 45462                          NaN                          NaN
# 45463                          NaN                          NaN
# 45464                          NaN                          NaN
# 45465                          NaN                          NaN
#
#       production_companies_name_19 production_companies_name_20  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# ...                            ...                          ...
# 45460                          NaN                          NaN
# 45462                          NaN                          NaN
# 45463                          NaN                          NaN
# 45464                          NaN                          NaN
# 45465                          NaN                          NaN
#
#       production_companies_name_21 production_companies_name_22  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# ...                            ...                          ...
# 45460                          NaN                          NaN
# 45462                          NaN                          NaN
# 45463                          NaN                          NaN
# 45464                          NaN                          NaN
# 45465                          NaN                          NaN
#
#       production_companies_name_23 production_companies_name_24  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# ...                            ...                          ...
# 45460                          NaN                          NaN
# 45462                          NaN                          NaN
# 45463                          NaN                          NaN
# 45464                          NaN                          NaN
# 45465                          NaN                          NaN
#
#       production_companies_name_25 production_countries_name_0  \
# 0                              NaN    United States of America
# 1                              NaN    United States of America
# 2                              NaN    United States of America
# 3                              NaN    United States of America
# 4                              NaN    United States of America
# ...                            ...                         ...
# 45460                          NaN                      Canada
# 45462                          NaN                 Philippines
# 45463                          NaN    United States of America
# 45464                          NaN                      Russia
# 45465                          NaN              United Kingdom
#
#       production_countries_name_1 production_countries_name_2  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
# ...                           ...                         ...
# 45460                     Germany              United Kingdom
# 45462                         NaN                         NaN
# 45463                         NaN                         NaN
# 45464                         NaN                         NaN
# 45465                         NaN                         NaN
#
#       production_countries_name_3 production_countries_name_4  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
# ...                           ...                         ...
# 45460    United States of America                         NaN
# 45462                         NaN                         NaN
# 45463                         NaN                         NaN
# 45464                         NaN                         NaN
# 45465                         NaN                         NaN
#
#       production_countries_name_5 production_countries_name_6  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
# ...                           ...                         ...
# 45460                         NaN                         NaN
# 45462                         NaN                         NaN
# 45463                         NaN                         NaN
# 45464                         NaN                         NaN
# 45465                         NaN                         NaN
#
#       production_countries_name_7 production_countries_name_8  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
# ...                           ...                         ...
# 45460                         NaN                         NaN
# 45462                         NaN                         NaN
# 45463                         NaN                         NaN
# 45464                         NaN                         NaN
# 45465                         NaN                         NaN
#
#       production_countries_name_9 production_countries_name_10  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
# ...                           ...                          ...
# 45460                         NaN                          NaN
# 45462                         NaN                          NaN
# 45463                         NaN                          NaN
# 45464                         NaN                          NaN
# 45465                         NaN                          NaN
#
#       production_countries_name_11 production_countries_name_12  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# ...                            ...                          ...
# 45460                          NaN                          NaN
# 45462                          NaN                          NaN
# 45463                          NaN                          NaN
# 45464                          NaN                          NaN
# 45465                          NaN                          NaN
#
#       production_countries_name_13 production_countries_name_14  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# ...                            ...                          ...
# 45460                          NaN                          NaN
# 45462                          NaN                          NaN
# 45463                          NaN                          NaN
# 45464                          NaN                          NaN
# 45465                          NaN                          NaN
#
#       production_countries_name_15 production_countries_name_16  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# ...                            ...                          ...
# 45460                          NaN                          NaN
# 45462                          NaN                          NaN
# 45463                          NaN                          NaN
# 45464                          NaN                          NaN
# 45465                          NaN                          NaN
#
#       production_countries_name_17 production_countries_name_18  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# ...                            ...                          ...
# 45460                          NaN                          NaN
# 45462                          NaN                          NaN
# 45463                          NaN                          NaN
# 45464                          NaN                          NaN
# 45465                          NaN                          NaN
#
#       production_countries_name_19 production_countries_name_20  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# ...                            ...                          ...
# 45460                          NaN                          NaN
# 45462                          NaN                          NaN
# 45463                          NaN                          NaN
# 45464                          NaN                          NaN
# 45465                          NaN                          NaN
#
#       production_countries_name_21 production_countries_name_22  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# ...                            ...                          ...
# 45460                          NaN                          NaN
# 45462                          NaN                          NaN
# 45463                          NaN                          NaN
# 45464                          NaN                          NaN
# 45465                          NaN                          NaN
#
#       production_countries_name_23 production_countries_name_24  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# ...                            ...                          ...
# 45460                          NaN                          NaN
# 45462                          NaN                          NaN
# 45463                          NaN                          NaN
# 45464                          NaN                          NaN
# 45465                          NaN                          NaN
#
#       spoken_languages_name_0 spoken_languages_name_1 spoken_languages_name_2  \
# 0                     English                     NaN                     NaN
# 1                     English                Français                     NaN
# 2                     English                     NaN                     NaN
# 3                     English                     NaN                     NaN
# 4                     English                     NaN                     NaN
# ...                       ...                     ...                     ...
# 45460                 English                     NaN                     NaN
# 45462                     NaN                     NaN                     NaN
# 45463                 English                     NaN                     NaN
# 45464                     NaN                     NaN                     NaN
# 45465                 English                     NaN                     NaN
#
#       spoken_languages_name_3 spoken_languages_name_4 spoken_languages_name_5  \
# 0                         NaN                     NaN                     NaN
# 1                         NaN                     NaN                     NaN
# 2                         NaN                     NaN                     NaN
# 3                         NaN                     NaN                     NaN
# 4                         NaN                     NaN                     NaN
# ...                       ...                     ...                     ...
# 45460                     NaN                     NaN                     NaN
# 45462                     NaN                     NaN                     NaN
# 45463                     NaN                     NaN                     NaN
# 45464                     NaN                     NaN                     NaN
# 45465                     NaN                     NaN                     NaN
#
#       spoken_languages_name_6 spoken_languages_name_7 spoken_languages_name_8  \
# 0                         NaN                     NaN                     NaN
# 1                         NaN                     NaN                     NaN
# 2                         NaN                     NaN                     NaN
# 3                         NaN                     NaN                     NaN
# 4                         NaN                     NaN                     NaN
# ...                       ...                     ...                     ...
# 45460                     NaN                     NaN                     NaN
# 45462                     NaN                     NaN                     NaN
# 45463                     NaN                     NaN                     NaN
# 45464                     NaN                     NaN                     NaN
# 45465                     NaN                     NaN                     NaN
#
#       spoken_languages_name_9 spoken_languages_name_10  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4                         NaN                      NaN
# ...                       ...                      ...
# 45460                     NaN                      NaN
# 45462                     NaN                      NaN
# 45463                     NaN                      NaN
# 45464                     NaN                      NaN
# 45465                     NaN                      NaN
#
#       spoken_languages_name_11 spoken_languages_name_12  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ...                        ...                      ...
# 45460                      NaN                      NaN
# 45462                      NaN                      NaN
# 45463                      NaN                      NaN
# 45464                      NaN                      NaN
# 45465                      NaN                      NaN
#
#       spoken_languages_name_13 spoken_languages_name_14  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ...                        ...                      ...
# 45460                      NaN                      NaN
# 45462                      NaN                      NaN
# 45463                      NaN                      NaN
# 45464                      NaN                      NaN
# 45465                      NaN                      NaN
#
#       spoken_languages_name_15 spoken_languages_name_16  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ...                        ...                      ...
# 45460                      NaN                      NaN
# 45462                      NaN                      NaN
# 45463                      NaN                      NaN
# 45464                      NaN                      NaN
# 45465                      NaN                      NaN
#
#       spoken_languages_name_17 spoken_languages_name_18  release_year  \
# 0                          NaN                      NaN          1995
# 1                          NaN                      NaN          1995
# 2                          NaN                      NaN          1995
# 3                          NaN                      NaN          1995
# 4                          NaN                      NaN          1995
# ...                        ...                      ...           ...
# 45460                      NaN                      NaN          1991
# 45462                      NaN                      NaN          2011
# 45463                      NaN                      NaN          2003
# 45464                      NaN                      NaN          1917
# 45465                      NaN                      NaN          2017
#
#        release_month  genres_weight  genres_num  production_companies_num  \
# 0                 10       0.195837           3                         1
# 1                 12       0.094197           3                         3
# 2                 12       0.218220           2                         2
# 3                 12       0.440571           3                         1
# 4                  2       0.144306           1                         2
# ...              ...            ...         ...                       ...
# 45460              5       0.368868           3                         4
# 45462             11       0.222352           1                         1
# 45463              8       0.378932           3                         1
# 45464             10       0.000000           0                         1
# 45465              6       0.000000           0                         0
#
#        production_countries_weight  production_countries_num  \
# 0                         0.429966                         1
# 1                         0.429966                         1
# 2                         0.429966                         1
# 3                         0.429966                         1
# 4                         0.429966                         1
# ...                            ...                       ...
# 45460                     0.594023                         4
# 45462                     0.001637                         1
# 45463                     0.429966                         1
# 45464                     0.018381                         1
# 45465                     0.083308                         1
#
#        spoken_languages_num  belongs_to_collection
# 0                         1                      1
# 1                         2                      0
# 2                         1                      1
# 3                         1                      0
# 4                         1                      1
# ...                     ...                    ...
# 45460                     1                      0
# 45462                     0                      0
# 45463                     1                      0
# 45464                     0                      0
# 45465                     1                      0
#
# [44686 rows x 102 columns]

# %% [markdown]
# # Save EDA data

# %%
#movies.to_csv('movies_metadata_eda.csv', index = False)
